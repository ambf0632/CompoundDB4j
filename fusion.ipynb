# %%
import pandas as pd

# %%
### find common based on name between compounds  DB and chembl  and write to csv 
import pandas as pd
dfdb2 =pd.read_csv('drugbank_drug.tsv',delimiter='\t',encoding='utf-8')

print(dfdb2.columns[2]) #2=name
print(len(dfdb2.columns))

listNames_compoundDB=[]
listExactMatchNames_compoundDB=[]
listChemblNames=[]
dictExactMatchNames_compoundDB={}

listNames_compoundDB=[x.lower() for x in dfdb2[dfdb2.columns[2].lower()]]

print("total",len(dfdb2[dfdb2.columns[2]]))                    
print(len(listNames_compoundDB))

dfChemblNames =pd.read_csv('chembl24prefnames_ids.csv',delimiter=',',encoding='utf-8') #chembl24prefnames.csv
print(dfChemblNames.shape)

#add to list only contains names
listChemblNames= [str(x).lower() for x in dfChemblNames[dfChemblNames.columns[0]]]

print(len(listChemblNames))

print(type(listChemblNames))

count=0
for item in listNames_compoundDB:     
    count=count+1   
    if item in listChemblNames :
        listExactMatchNames_compoundDB.append(item)
        
print(len(listExactMatchNames_compoundDB))



#add to dict chembl id as value and name as key
listChemblNames= [str(x).lower() for x in dfChemblNames[dfChemblNames.columns[0]]]
listChemblIds=[str(x) for x in dfChemblNames[dfChemblNames.columns[1]]]
dictChemblNamesIds=dict(zip(listChemblNames,listChemblIds))

#consider checking names in drugbank to synonmys in chembl
dfChemblSynonyms =pd.read_csv('chembl24_synonyms_ids.csv',delimiter=',',encoding='utf-8')#chembl24_synonyms
listChemblSNames= [str(x).lower() for x in dfChemblSynonyms[dfChemblSynonyms.columns[0]]]
listChemblSIds=[str(x) for x in dfChemblSynonyms[dfChemblSynonyms.columns[1]]]
dictChemblSIds=dict(zip(listChemblSNames,listChemblSIds))


for key, value in dictChemblNamesIds.items() :
    print(key, value)
    break
    

        
for item in listNames_compoundDB:   
    if item in dictChemblNamesIds:
        dictExactMatchNames_compoundDB[item]= dictChemblNamesIds[item]  
    if item in dictChemblSIds:
        dictExactMatchNames_compoundDB[item]= dictChemblSIds[item] 
      
       
print(len(dictExactMatchNames_compoundDB))
# Out:
# name
# 55
# total 13339
# 13339
# (1828820, 2)
# 1828820
# <class 'list'>
# 5388
# nan CHEMBL3991472
# 5903

# %%
for key, value in dictExactMatchNames_compoundDB.items() :
    print(key, value)
    break
print(listExactMatchNames_compoundDB[0])
# Out:
# lepirudin CHEMBL1201666
# lepirudin

# %%
print(listChemblNames[1801523])
print(listNames_compoundDB[0])
print(type(listChemblNames))
# Out:
# nan
# lepirudin
# <class 'list'>

# %%
import csv

count=0
dataArr=dfdb2.values
for idx in range(len(dfdb2.values)):
    print("ss")
    break



#add chembl id also to csv matches file 
with open("outmatches_names_drugnames_chemblids.tsv",'w') as outcsv2: 
    writer2=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')  
    with open("outmatches_names_chemblids.tsv",'w') as outcsv: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        for idd in range(len(dfdb2.values)):
            dbname=str(dataArr[idd][2]).lower()
            if dbname in dictExactMatchNames_compoundDB.keys():
                for name, idval in dictExactMatchNames_compoundDB.items():   
                    if dbname == name:                    
                        item=dataArr[idd]  
                        chemblid=idval
                        writer.writerow([ chemblid,item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                        writer2.writerow([chemblid, item[0], item[2]])
# Out:
# ss

# %%
### find common based on synonmys  between compounds  DB and chembl  and write to csv 
import pandas as pd
dfdb2 =pd.read_csv('drugbank_drug.tsv',delimiter='\t',encoding='utf-8')

print(dfdb2.columns[28]) #2=name
print(len(dfdb2.columns))

listsynonyms_compoundDB=[]
listsynonyms_compoundDB_all=[]
listExactMatchSynonyms_compoundDB=[]
listChemblSynonyms=[]
dictExactMatchSynonyms_compoundDB={}


listsynonyms_compoundDB=[str(x).lower() for x in dfdb2[dfdb2.columns[28]]]

print("total",len(dfdb2[dfdb2.columns[28]]))                    
print(len(listsynonyms_compoundDB))
print(listsynonyms_compoundDB[0])


dfChemblSynonyms =pd.read_csv('chembl24_synonyms_ids.csv',delimiter=',',encoding='utf-8')#chembl24_synonyms
print(dfChemblSynonyms.shape)
listChemblSynonyms= [str(x).lower() for x in dfChemblSynonyms[dfChemblSynonyms.columns[0]]]

print(len(listChemblSynonyms))

print(type(listChemblSynonyms))

count=0
for item in listChemblSynonyms:     
    count=count+1   
    if item in listsynonyms_compoundDB :
        listExactMatchSynonyms_compoundDB.append(item)
        
print(len(listExactMatchSynonyms_compoundDB))

#add to dict chembl id as value and synonyms as key
listChemblSNames= [str(x).lower() for x in dfChemblSynonyms[dfChemblSynonyms.columns[0]]]
listChemblSIds=[str(x) for x in dfChemblSynonyms[dfChemblSynonyms.columns[1]]]
dictChemblSIds=dict(zip(listChemblSNames,listChemblSIds))

#consider checking drugbank synonyms to names in chembl
dfChemblNames =pd.read_csv('chembl24prefnames_ids.csv',delimiter=',',encoding='utf-8') #chembl24prefnames.csv
listChemblNames= [str(x).lower() for x in dfChemblNames[dfChemblNames.columns[0]]]
listChemblIds=[str(x) for x in dfChemblNames[dfChemblNames.columns[1]]]
dictChemblNamesIds=dict(zip(listChemblNames,listChemblIds))


for key, value in dictChemblSIds.items() :
    print(key, value)
    break
    
#db synonmys contains  formate |a||||aa||||bb||||b|
for x in listsynonyms_compoundDB:
    x=str(x)
    if '|' in x:
        xall = x.replace('||||','|')
        xarr = xall.split("|")
        for m in xarr:
            if m!= '':
                listsynonyms_compoundDB_all.append(m)
    else:
        if x!= '':
            m=x
            listsynonyms_compoundDB_all.append(m)

for item in listsynonyms_compoundDB_all:   
    if item in dictChemblSIds:
        dictExactMatchSynonyms_compoundDB[item]= dictChemblSIds[item] 
    if item in dictChemblNamesIds:
        dictExactMatchSynonyms_compoundDB[item]= dictChemblNamesIds[item] 

        
print(len(dictExactMatchSynonyms_compoundDB))
# Out:
# synonyms
# 55
# total 13339
# 13339
# lepirudin recombinant||ith1_hirme||hirudin variant-1
# (155331, 2)
# 155331
# <class 'list'>
# 1133
# bromoenol lactone CHEMBL1256018
# 3821

# %%
import csv

count=0
dataArr=dfdb2.values
for idx in range(len(dfdb2.values)):
    print("ss")
    break
         
            
            

#add chembl id also to csv synonym matches file 
with open("outmatches_synonyms_drugnames_chemblids.tsv",'w') as outcsv2: 
    writer2=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')  
    with open("outmatches_synonyms_chemblids.tsv",'w') as outcsv: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        for idd in range(len(dfdb2.values)):
            synonyms=str(dataArr[idd][28]).lower()
            if '|' in synonyms:
                xall = synonyms.replace('||||','|')
                xarr = xall.split("|")              
                for arr in xarr:                
                    if arr in dictExactMatchSynonyms_compoundDB.keys():
                        chemblid=dictExactMatchSynonyms_compoundDB[arr]                               
                        item=dataArr[idd]  
            else:
                arr=synonyms
                if arr in dictExactMatchSynonyms_compoundDB.keys():
                        chemblid=dictExactMatchSynonyms_compoundDB[arr]                               
                        item=dataArr[idd]  
                        
                
            writer.writerow([ chemblid,item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
            writer2.writerow([chemblid, item[0], item[2]])
# Out:
# ss

# %%
### ### ### ### #not in use###  ### ### ### ### 

#find if partial match exists between overall non matches and chembl for name and synonmys 
import pandas as pd #outnonmatches_allfields
dfdbs = pd.read_csv('outnonmatches_allfields__.tsv', header=None, delimiter='\t',encoding='utf-8')

print(dfdbs.columns[2]) #2=name
print(dfdbs.columns[28]) 
print(len(dfdbs.columns))

listPartialMatchSynonyms_dfdbs=[]
listPartialMatchSynonyms2_dfdbs=[]
listSynonyms_dfdbs=[]
listChemblSynonyms=[]
listNames_dfdbs=[]

listNames_dfdbs=[str(x).lower() for x in dfdbs[dfdbs.columns[2]]]

print("total",len(dfdbs[dfdbs.columns[2]]))                    
print(len(listNames_dfdbs))
print(listNames_dfdbs[0])


dfChemblSynonyms =pd.read_csv('chembl24_synonyms.csv',delimiter='\t',encoding='utf-8')
print(dfChemblSynonyms.shape)
listChemblSynonyms= [str(x).lower() for x in dfChemblSynonyms[dfChemblSynonyms.columns[0]]]

print(len(listChemblSynonyms))

print(type(listChemblSynonyms))

count=0
for item in listChemblSynonyms:  
    if item in listNames_dfdbs :        
        listPartialMatchSynonyms_dfdbs.append(item)
    else:
        arrAll = item.split(' ')
        for i in arrAll:            
            if i in listNames_dfdbs :                
                listPartialMatchSynonyms_dfdbs.append(i)
    
        
print(len(listPartialMatchSynonyms_dfdbs))
print(listPartialMatchSynonyms_dfdbs)

for x in dfdbs[dfdbs.columns[28]]:
    x=str(x)
    if '|' in x:
        xall = x.replace('||||','|')
        xarr = xall.split("|")
        for m in xarr:
            if m!= '':
                listSynonyms_dfdbs.append(m.lower())
    else:
        if x!= '':
            m=x
            listSynonyms_dfdbs.append(m.lower())


for item in listChemblSynonyms:    
    if item in listSynonyms_dfdbs :        
        listPartialMatchSynonyms2_dfdbs.append(item)
    else:
        arrAll = item.split(' ')
        for i in arrAll:            
            if i in listSynonyms_dfdbs :                
                listPartialMatchSynonyms2_dfdbs.append(i)
        
print(len(listPartialMatchSynonyms2_dfdbs))
print(listPartialMatchSynonyms2_dfdbs)
# Out:
# 2
# 28
# 56
# total 1755
# 1755
# name
# (155331, 1)
# 155331
# <class 'list'>
# 26
# ['vitamin d', 'alpha-tocopherol acetate', 'rauwolfia serpentina root', 'acriflavinium chloride', 'vitamin d', 'bryostatin 1', 'albumin iodinated i-131 serum', 'albumin iodinated i-131 serum', 'human interleukin-2', 'invert sugar', 'invert sugar', 'invert sugar', 'alpha-hydroxy glycineamide', 'acriflavinium chloride', 'acriflavinium chloride', 'ingn 201', 'technetium tc-99m tilmanocept', 'technetium tc-99m tilmanocept', 'coconut oil', 'medical air', 'carbopol 974p', 'sodium apolate', 'sodium apolate', 'sodium apolate', 'rauwolfia serpentina root', 'alpha-tocopherol acetate']
# 22
# ['rauwolfia', 'calciferol', 'calciferol', 'calciferol', 'iodinated (131i) human serum albumin', 'interleukin-2', 'alseroxylon', 'alseroxylon', 'alseroxylon', 'acriflavine hydrochloride', 'acriflavine hydrochloride', 'technetium (99mtc) tilmanocept', 'air', 'air, compressed', 'lyapolate sodium', 'lyapolate sodium', 'rauwolfia', 'rauwolfia', 'rauwolfia serpentina', 'rauwolfia serpentina', 'tocopheryl acetate', 'tocopherol acetate']

# %%
### ### ### ### #not in use###  ### ### ### ### 
#partial matches based on synonyms between non matched and chembl in a separate csv
import csv

count=0
dataArr2=dfdbs.values
for idx in range(len(dfdbs.values)):
    print("ss")
    break
print(dfdbs.values[0][2])
            
with open("outmatches_names_nonmatches_chembl_3.tsv",'w') as outcsv: 
    with open("outmatches_names_nonmatches_chembl_drugnames_3.csv",'w') as outcsv2: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        writer2=csv.writer(outcsv2,delimiter=';',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')

        for idd in range(len(dfdbs.values)): 
            namedb=dfdbs.values[idd][2].lower()            
            if namedb in listPartialMatchSynonyms_dfdbs:                       
                item=dataArr2[idd]            
                writer.writerow([item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                writer2.writerow([item[0], item[2]]) 
            
            
with open("outmatches_synonyms_nonmatches_chembl_3.tsv",'w') as outcsv: 
    with open("outmatches_synonyms_nonmatches_chembl_drugnames_3.csv",'w') as outcsv2: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        writer2=csv.writer(outcsv2,delimiter=';',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')

        for idd in range(len(dfdbs.values)):            
            bExists=False
            synonyms=str(dfdbs.values[idd][28]).lower()  
            if '|' in synonyms:
                xall = synonyms.replace('||||','|')
                xarr = xall.split("|")
                
                print(xarr)
                for arr in xarr:                    
                    if arr!= '':
                        if 'ergoloid' in arr:
                            print("arr",arr)
                            print("listPartialMatchSynonyms2_dfdbs",listPartialMatchSynonyms2_dfdbs)
                        if str(arr) in listPartialMatchSynonyms2_dfdbs:
                            print("adding",arr)
                            item=dataArr2[idd]            
                            writer.writerow([item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                            writer2.writerow([item[0], item[2]])
            else:
                if synonyms in listPartialMatchSynonyms2_dfdbs:                   
                    item=dataArr2[idd]            
                    writer.writerow([item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                    writer2.writerow([item[0], item[2]])
# Out:
# ss
# name
# ['', 'ephedra root (ephedra sinica)', 'ephedra', 'ma huang gen (ephedra sinica)', 'ephedra sinica root', 'mahuanggen (ephedra sinica)', 'hemp yellow root', 'chinese jointfir', 'cao ma huang root', 'ephedra ma-huang root', 'chinese ephedra root (ephedra sinica)', 'ephedrae radix', '']
# ['', 'gastrin 17 immunogen', 'antigastrin 17', 'gastrin 17 vaccine', '']
# ['', 'rthrombin', 'recothrom', 'recombinant thrombin', 'rhthrombin', '']
# ['', 'dce2_human', 'recombinant human glutamic acid decarboxylase', 'recombinant human gad65', '']
# ['', 'pyy(3-36)', 'pyy 3-36', 'pyy3-36', 'pyy (3-36) peptide', '']
# ['', 'rhmbp', 'recombinant human mannose-binding lectin', 'mbl2_human', 'recombinant human mannan-binding protein', '']
# ['', 'human ciliary neurotrophic factor', 'ciliary neurotrophic factor (human)', 'human cntf', '']
# ['', 'carbomer 974 (p)', 'buffergel', 'carbomer-974p', 'carbomer homopolymer type b', 'carbopol polymer', 'carbomer homopolymer type b (allyl pentaerythritol crosslinked)', 'carbomer 974p', '']
# ['', 'naphthalene 2-sulfonate polymer', 'polynaphthalene sulphonate', '']
# ['', 'rigscan cr49', 'rigscan cr', '']
# ['', 'infecton', 'technetium tc 99m ciprofloxacin', 'technetium (99mtc) ciprofloxacin', '99mtc-ciprofloxacin', '']
# ['', 'nf-kb decoy', 'nf-kappab decoy', '']
# ['', 'acidic fibroblast growth factor', 'acidic fibroblast growth factor (afgf)', 'fibroblast growth factor, acidic', '']
# ['', 'xg-102 c-terminal acid', 'd-jnki 1 peptide', '']
# ['', 'peg inf alfacon-1', 'pegylated interferon alfacon-1', 'peg-alfacon', 'peg-interferon alfacon-1', 'peg-infergen', '']
# ['', 'yspsl', 'rpsgl-ig', '']
# ['', 'rspsma', 'recombinant soluble prostate-specific membrane antigen (rspsma) vaccine', '']
# ['', 'calcitonin gene related peptide', 'cgrp', 'calcitonin-gene-related peptide', 'lab cgrp', '']
# ['', 'c1 inhibitor', 'c1-esterase inhibitor, human', 'c1-inhibiting factor', 'c1 esterase inhibitor (human)', 'ic1_human', 'human c1 inhibitor', 'human c1-esterase inhibitor', 'c1-inhibitor, plasma derived', 'plasma protease c1 inhibitor', 'c1 inhibitor (human)', 'c1 inhibitor human', 'c1-inh', '']
# ['', 'recombinant human endostatin', 'endostatins', '']
# ['', 'd2s', 'dextrin sulphate', '']
# ['', 'osteoprotegerin recombinant', 'tr11b_human', 'ropg', 'osteoclastogenesis inhibitory factor', '']
# ['', 'recombinant nematode anticoagulant protein c2', 'recombinant nematode anticoagulant protein-2', '']
# ['', 'αhga', 'alpha-hga', 'alpha-hydroxy-glycineamide', 'alphahga', 'ahga', 'alfahga', '']
# ['', 'bacillus anthracis immune globulin human', 'anthrax immune globulin human', 'anthrax immune globulin (human)', '']
# ['', 'pig thyroid', 'porcine thyroid', 'sus scrofa thyroid', 'thyroid (pork)', 'thyroid extract, porcine', '']
# ['', 'technetium tc 99m tilmanocept', 'technetium tc99 tilmanocept', 'technetium (99mtc) tilmanocept', '']
# adding technetium (99mtc) tilmanocept
# ['', 'antihemophilic factor (recombinant), pegylated-aucl', 'antihemophilic factor (recombinant), pegylated', '']
# ['', 'air, compressed', 'air, synthetic medicinal', 'air, medicinal', 'air', '']
# adding air, compressed
# adding air
# ['', 'rauwolfia serpentina alseroxylon', 'rauvolfia serpentina root', 'alseroxylon', 'snakeroot', 'rauwolfia', 'rauwolfia root', 'rauwolfia serpentina', 'alkaloids, rauwolfia', 'rauwolfia alkaloids', '']
# adding alseroxylon
# adding rauwolfia
# adding rauwolfia serpentina
# ['', 'technetium polyphosphate', 'technetium (99mtc) polyphosphate', 'technetium tc 99m polyphosphate', '']
# ['', 'albumin,iodinated serum,i-131', 'albumin, iodinated i-131 serum', 'iodinated i-131 serum albumin', 'albumin, blood serum, labeled with iodine-131', 'albumin, iodinated i 131 serum', 'iodinated i 131 serum albumin', 'human serum albumin i-131', 'albumin,iodinated i-131 serum', 'iodinated (131i) human serum albumin', 'human albumin i-131', '']
# adding iodinated (131i) human serum albumin
# ['', 'clostridium tetani whole', 'bacillus tetani whole', 'clostridium tetani', '']
# ['', 'rabies virus vaccine wistar strain pm-1503-3m (human)', 'rabies virus strain pm-1503-3m antigen (propiolactone inactivated)', '']
# ['', 'rotavirus vaccine, live, oral', 'rota virus, live attenuated', '']
# ['', 'rabies virus vaccine flury-lep strain', 'rabies virus strain flury lep antigen (propiolactone inactivated)', '']
# ['', 'recombinant human papillomavirus type 6 l1 protein', 'l1 protein, human papillomavirus type 6 vaccine', '']
# ['', 'l1 protein, human papillomavirus type 11 vaccine', 'recombinant human papillomavirus type 11 l1 protein', '']
# ['', 'recombinant human papillomavirus type 16 l1 protein', 'l1 protein, human papillomavirus type 16 vaccine', '']
# ['', 'l1 protein, human papillomavirus type 18 vaccine', 'recombinant human papillomavirus type 18 l1 protein', '']
# ['', 'recombinant human papillomavirus type 31 l1 protein', 'l1 protein, human papillomavirus type 31 vaccine', '']
# ['', 'recombinant human papillomavirus type 33 l1 protein', 'l1 protein, human papillomavirus type 33 vaccine', '']
# ['', 'recombinant human papillomavirus type 45 l1 protein', 'l1 protein, human papillomavirus type 45 vaccine', '']
# ['', 'recombinant human papillomavirus type 52 l1 protein', 'l1 protein, human papillomavirus type 52 vaccine', '']
# ['', 'recombinant human papillomavirus type 58 l1 protein', 'l1 protein, human papillomavirus type 58 vaccine', '']
# ['', 'rubivirus rubella virus wistar ra 27/3 whole', 'rubella virus strain wistar ra 27/3 live (attenuated) antigen', 'rubella virus vaccine,live', 'rubella virus live antigen, a', 'rubella virus strain wistar ra 27/3 live antigen', 'rubella, live attenuated', 'rubella virus vaccine live (wistar ra 27-3 strain)', 'rubella virus (vaccine strain ra27/3) live antigen', '']
# ['', 'varicella-zoster virus strain oka/merck live antigen', 'varicella vaccine', 'varicella zoster live (attenuated) antigen', 'varicella virus vaccine live (oka-merck) strain', 'chickenpox vaccine', 'human herpesvirus 3 live (attenuated) antigen', 'varicella-zoster virus strain oka/merck live (attenuated) antigen', 'varicella zoster live(attenuated) antigen', 'varicella-zoster virus (live, attenuated)', '']
# ['', 'pneumococcal capsular polysaccharide type 4 vaccine', 'pneumococcal polysaccharide serotype 4', '']
# ['', 'pneumococcal polysaccharide serotype 6b', 'pneumococcal capsular polysaccharide type 6b vaccine', '']
# ['', 'pneumococcal polysaccharide serotype 9v', 'pneumococcal capsular polysaccharide type 9v vaccine', '']
# ['', 'pneumococcal polysaccharide serotype 14', 'pneumococcal capsular polysaccharide type 14 vaccine', '']
# ['', 'pneumococcal capsular polysaccharide type 18c vaccine', 'pneumococcal polysaccharide serotype 18c', '']
# ['', 'pneumococcal capsular polysaccharide type 19f vaccine', 'pneumococcal polysaccharide serotype 19f', '']
# ['', 'pneumococcal capsular polysaccharide type 23f vaccine', 'pneumococcal polysaccharide serotype 23f', '']
# ['', 'motie molulu pollen', 'panicum dactylon pollen', 'standardized bermuda grass pollen', 'devilgrass pollen', 'allergen pack bermuda grass', 'grama-seda pollen', 'ae-bermuda grass', 'capriola dactylon pollen', 'common bermudagrass pollen', 'allergenic extract, bermuda grass', 'bermuda grass pollen extract', 'bermudagrass pollen', 'bermuda grass pollen', 'manienie pollen', 'allergenic extract- bermuda grass cynodon dactylon', 'allergenic extract,grass,bermuda', 'cynodon dactylon', '']
# ['', 'cocklebur pollen extract', 'rough cocklebur pollen extract', '']
# ['', 'meadowgrass pollen extract', 'kentucky bluegrass pollen extract', 'standardized kentucky blue/june grass pollen', 'poa pratensis', '']
# ['', 'festuca pratensis', 'standardized meadow fescue grass pollen', 'meadow fescue grass pollen extract', '']
# ['', 'orchard grass pollen extract', 'cocksfoot grass pollen', 'allergenic extract- orchard grass dactylis glomerata', 'dactylis glomerata', 'standardized orchard grass pollen', '']
# ['', 'juglans rubra pollen', 'juglans angustifolia pollen', 'juglans illinoinensis pollen', 'carya pecan pollen', 'hicoria pecan pollen', 'carya oliviformis pollen', 'juglans cylindrica pollen', 'hicorius diguetii pollen', 'carya diguetii pollen', 'hicorius tetraptera pollen', 'juglans oliviformis pollen', 'pecan pollen', 'carya illinoinensis pollen', 'carya tetraptera pollen', 'hicorius oliviformis pollen', 'juglans pecan pollen', 'carya angustifolia pollen', '']
# ['', 'ambrosia artemisiifolia', 'short ragweed pollen extract', 'short ragweed pollen extracts', 'standardized short ragweed pollen allergenic extract', '']
# ['', 'allergenic extract- ryegrass, perennial lolium perenne', 'perennial rye grass pollen extract', 'standardized perennial rye grass pollen', 'lolium perenne allergenic extract', 'lolium perenne', '']
# ['', 'timothy grass pollen extract', 'phleum nodosum pollen', 'timothy pollen', 'timothy grass pollen', 'phleum pratense pollen extract', 'allergenic extract, timothy grass', 'grass pollen extract', 'standardized timothy grass pollen', 'allergenic extract,timothy grass pollen', 'common timothy pollen', 'timothy grass pollen extracts', 'phleum pratense', 'allergenic extract, grass, timothy', 'timothy grass (phleum pretense) pollen standardized', '']
# ['', 'standardized cat pelt', 'cat skin extract', '']
# ['', 'american house dust mite extract', 'mite d.f.', 'american house dust mite', 'mite d.f. (dermatophagoides farinae) standardized', 'insects (whole body), mite dermatophagoides farinae', 'house dust mite extract, dermatophagoides farinae', '']
# ['', 'european house dust mite', 'european house dust mite extract', 'mite d.p. (dermatophagoides pteronyssinus) standardized', 'insects (whole body), mite dermatophagoides pteronyssinus', 'dermatophagoides pteronyssinus whole', 'ae-mite, dermatophagoides pteronyssinus', 'mite d.p.', 'house dust mite extract, dermatophagoides pteronyssinus', '']
# ['', 'allergenic extract, redtop grass', 'standardized redtop grass pollen', '']
# ['', 'sweet vernal grass pollen extract', 'standardized sweet vernal grass pollen', '']
# ['', 'canis canis skin', 'canis familiaris domesticus skin', 'canis familiaris skin', 'dog epithelia', 'domestic dog skin', 'canis domesticus skin', '']
# ['', 'domestic horse skin', 'horse skin', 'horse epithelia', 'horse (feral) skin', 'equus przewalskii forma caballus skin', 'equine skin', 'equus caballus skin', 'equus ferus caballus skin', '']
# ['', 'iris germanica var. florentina root', 'iris x germanica root', 'iris germanica var. florentina rhizome', '']
# ['', 'american cockroach allergenic extract', 'allergenic extract- cockroach periplaneta americana', '']
# ['', 'allergenic extract- cockroach, german blatella germanica', 'german cockroach allergenic extract', '']
# ['', 'rhizopus arrhizus', 'mold, rhizopus arrhizus', 'allergenic extract, mold, rhizopus arrhizus', 'rhizopus oryzae extract', 'rhizopus arrhizus mold', '']
# ['', 'aspergillus flavus var. oryzae whole', 'aspergillus oryzae', 'aspergillus flavus var. oryzae', 'eurotium oryzae', '']
# ['', 'acnida tuberculata pollen', 'western waterhemp pollen extract', 'acnida subnuda pollen', 'rough-fruit amaranth pollen', 'acnida altissima pollen', 'amaranthus tuberculatus pollen', 'acnida concatenata pollen', 'roughfruit amaranth pollen', 'amaranthus ambigens pollen', 'amaranthus altissimus pollen', 'tall waterhemp pollen', '']
# ['', 'felis domesticus hair', 'cat hair allergenic extracts', 'cat hair (felis domesticus)', 'cat hair', 'cat hair (felis domesticus) standardized', 'felis catus domestica hair', 'cat hair extract', 'felis silvestris catus hair', 'domestic cat hair', '']
# ['', 'milk protein', 'milk casein', 'casein allergenic extract', 'calcium caseinate', 'bovine casein', 'casein, milk', 'casein, cow milk', '']
# ['', 'paralithodes camtschaticus flesh', 'king crab (paralithodes camtschaticus)', 'paralithodes camtschatica flesh', 'paralithodes camtschaticus muscle', 'red king crab flesh', '']
# ['', 'flounder allergenic extract', 'southern flounder', '']
# ['', 'lobster, unspecified', 'lobster allergenic extract', 'american lobster', '']
# ['', 'oyster, unspecified', 'oyster allergenic extract', 'eastern oyster', '']
# ['', 'shrimp allergenic extract', 'common shrimp', 'shrimp, unspecified', '']
# ['', 'tuna allergenic extract', 'ae-tuna', 'tuna, unspecified', '']
# ['', 'hamster skin extract', 'syrian hamster skin extract', '']
# ['', 'whitefish', 'white fish allergenic extract', '']
# ['', 'blue ridge blueberry', 'blueberry allergenic extract', '']
# ['', 'house fly allergenic extract', 'house fly extract', '']
# ['', 'oat loose smut extract', 'oat smut allergenic extract', '']
# ['', 'tilletia caries whole', 'tilletia tritici', 'lycoperdon tritici', 'tilletia caries', 'stinking wheat smut', 'caeoma sitophilum', 'tilletia sitophila', 'stinking smut of wheat', 'wheat bunt fungus', 'fusisporium inosculans', 'uredo caries', 'uredo sitophila', '']
# ['', 'flaxseed allergenic extract', 'flaxseed extract', '']
# ['', 'western wheatgrass', 'western wheatgrass pollen extract', '']
# ['', 'arroyo willow pollen', 'arroyo willow pollen extract', '']
# ['', 'populus balsamifera ssp. trichocarpa pollen', 'balsam poplar pollen extract', 'populus trichocarpa pollen', 'black cottonwood pollen', 'black cottonwood pollen extract', '']
# ['', 'burrobrush pollen extract', 'ambrosia salsola pollen', '']
# ['', 'japanese encephalitis vaccine ic51', 'japanese encephalitis vaccine', 'japanese encephalitis virus strain sa 14-14-2 antigen (formaldehyde inactivated)', '']
# ['', 'filamentous haemagglutinin', 'bordetella pertussis filamentous hemagglutinin vaccine, inactivated', 'filamentous haemagglutinin adsorbed', '']
# ['', 'bordetella pertussis pertactin vaccine, inactivated', 'pertactin adsorbed', 'pertactin', '']
# ['', 'inactivated poliovirus type i', 'inactivated poliomyelitis vaccine (v.c.o.) type 1 mahoney', 'poliovirus vaccine inactivated, type 1 (mahoney)', '']
# ['', 'inactivated poliomyelitis vaccine (d.c.o.) type 2 mef1', 'poliovirus vaccine inactivated, type 2 (mef-1)', 'inactivated poliovirus type ii', '']
# ['', 'inactivated poliovirus type iii', 'inactivated poliomyelitis vaccine (v.c.o.) type 3 saukett', 'poliovirus vaccine inactivated, type 3 (saukett)', '']
# ['', 'fusarium bulbigenum', 'fusarium oxysporum whole', 'fusarium oxysporum', '']
# ['', 'ustilago nuda', 'barley smut extract', '']
# ['', 'catfish (ameiurus catus)', 'amiurus catus flesh', 'pimelodus catus flesh', 'silurus catus flesh', 'ictalurus catus flesh', 'ameiurus catus muscle', 'ameiurus catus flesh', '']
# ['', 'chionoecetes opilio flesh', 'snow crab flesh', 'snow crab (chionoecetes opilio)', 'opilio crab', 'chionoecetes opilio muscle', '']
# ['', 'canis familiarus domesticus hair', 'canis canis hair', 'canis domesticus hair', 'domestic dog hair', 'dog hair extract', 'canis lupus familiaris hair extract', 'canis familiaris hair', 'canis lupus familiaris hair', 'dog hair', '']
# ['', 'quercus castanea pollen', 'quercus muehlenbergii pollen', 'chinkapin oak pollen', 'quercus alexanderi pollen', 'quercus brayi pollen', 'quercus acuminata pollen', '']
# ['', 'sabina virginiana oil', 'cedar oil', 'juniperus virginiana wood oil', 'red cedar wood oil', 'oil of cedar wood', 'juniperus virginiana', 'juniperus virginiana oil', 'eastern red cedar stem oil', 'cedarwood oil', 'eastern red cedar wood oil', 'red cedarwood oil', 'red cedar stem oil', 'juniperus virginiana volatile oil', 'juniperus virginiana stem oil', '']
# ['', 'white hickory pollen extract', 'carya alba pollen', '']
# ['', 'rough marshelder pollen extract', 'iva annua var. annua pollen', '']
# ['', 'kochia scoparia pollen', 'burning bush pollen extract', '']
# ['', 'burweed marshelder pollen extract', 'iva xanthifolia pollen', '']
# ['', 'redroot pigweed whole', 'galliaria scabra whole', 'amaranthus retroflexus', 'amaranthus bullatus whole', 'careless weed whole', 'amaranthus retroflexus whole', 'galliaria retroflexa whole', 'amaranthus spicatus whole', 'rough pigweed whole', 'red-root amaranth whole', 'amaranthus recurvatus whole', 'amaranthus curvifolius whole', 'redroot amaranth whole', 'amaranthus delilei whole', 'amaranthus bulgaricus whole', 'amaranthus rigidus whole', 'amaranthus johnstonii whole', '']
# ['', 'acremonium roseum', 'cephalosporium roseum', 'cephalosporium roseum whole', '']
# ['', 'pleospora tarda', 'pleospora tarda whole', 'stemphylium botryosum', '']
# ['', 'koelers grass pollen extract', 'standardized june grass pollen', '']
# ['', 'alkali blite pollen extract', 'suaeda nigra pollen', '']
# ['', 'yellow hornet venom protein', 'dolichovespula arenaria venom protein extract', '']
# ['', 'white faced hornet venom protein', 'bald-faced hornet venom protein', '']
# ['', 'allergenic extract, italian ryegrass pollen', 'lolium multiflorum pollen', 'italian rye grass pollen extract', 'lolium perenne ssp. multiflorum pollen', '']
# ['', 'mycogone nigra whole', 'mycogone nigra', '']
# ['', 'humicola lanuginosa', 'thermomyces lanuginosus', 'humicola brevispora', 'sepedonium lanuginosum', 'thermomyces lanuginosus whole', 'monotospora lanuginosa', '']
# ['', 'monilia cutanea', 'trichosporon cutaneum whole', 'mycoderma cutaneum', 'oidium cutaneum', 'proteomyces cutaneus', 'basidiotrichosporon cutaneum', 'geotrichum cutaneum', 'oospora cutanea', 'trichosporon cutaneum', 'geotrichoides cutanea', '']
# ['', 'barley malt flr', 'malted barley', 'barley malt flour', '']
# ['', 'sage leaf allergenic extract', 'salvia officinalis', '']
# ['', 'ulmus fulva pollen', 'ulmus rubra pollen', 'slippery elm pollen', '']
# ['', "king's-nut pollen", 'shellback hickory pollen', 'hicoria laciniosa pollen', 'juglans laciniosa pollen', 'carya laciniosa pollen', 'shellbark hickory pollen', '']
# ['', 'bacillus anthracis strain v770-np1-r filtrate (attenuated) antigen', 'anthrax vaccine adsorbed', 'bacillus anthracis strain v770-np1-r filtrate antigen', 'bacillus anthracis strain v770-np1-r antigens', 'bacillus anthracis strain v770-np1-r antigen', 'bacillus anthracis inactivated antigen', '']
# ['', 'betula pendula pollen', 'european white birch pollen', 'silver birch pollen', 'betula alba var. pendula pollen', 'betula pendula pollen extract', 'weeping birch pollen', '']
# ['', 'cercidium floridum pollen', 'palo verde pollen', 'cercidium torreyanum pollen', 'blue paloverde pollen', 'parkinsonia torreyana pollen', 'cercidium floridum subsp. floridum pollen', 'blue palo verde pollen', 'parkinsonia florida pollen', '']
# ['', 'poultry', 'poultry, unspecified', 'chicken, turkey, duck, goose, or quail', '']
# ['', 'clam allergenic extract', 'northern quahog', 'clam', 'quahog', 'minced clams', '']
# ['', 'guinea pig dander', 'cavia aperea porcellus dander', 'cavia cobaya dander', 'cavia porcellus dander', '']
# ['', 'cow dander', 'bos primigenius taurus dander', 'aurochs dander', 'bos primigenius dander', 'bos taurus dander', 'domesticated cattle dander', 'bos bovis dander', 'domestic cow dander', 'domestic cattle dander', 'bovine dander', 'bos indicus dander', '']
# ['', 'monilia digitata', 'penicillium digitatum whole', 'mucor digitata', 'penicillium digitatum', '']
# ['', 'clonostachys rosea f. rosea', 'clonostachys rosea', 'haplotrichum roseum', 'penicillium roseum', 'clonostachys araucaria', 'gliocladium aureum', 'clonostachys rosea forma rosea', 'gliocladium roseum', '']
# ['', 'hymenoptera venom diagnostic', 'common wasp venom protein', 'yellow jacket venom protein', '']
# ['', 'typhoid vaccine (salmonella typhi ty21a)', 'salmonella enterica subsp. enterica serovar typhi', 'salmonella typhi ty21a live antigen', 'typhoid vaccine live ty21a', '']
# ['', 'amylase ad', 'porcine pancreas alpha-amylase', 'amylase a', 'alpha-amylases', 'alpha-amylase (porcine)', 'alpha-amylase swine pancreas', 'amylase, pancreatic', 'alpha-amylase', '1,4-alpha-d-glucan glucanohydrolase', '']
# ['', 'algal oil (schizochytrium sp.)', 'dha from algal (schizochytrium) oil', '']
# ['', 'polyethylene glycol 400', 'octaethylene glycol', 'peg-8', '3,6,9,12,15,18,21-heptaoxatricosane-1,23-diol', 'peg-400', 'polyethylene glycol 8', '']
# ['', 'vitamin d, unspecified form', 'vitamin d nos', 'calciferol', '']
# adding calciferol
# ['', 'oils, palm kernel, hydrogenated', 'palm kernel oil, hydrogenated', '']
# ['', 'peg-6', 'macrogol 300', 'peg 300', '']
# ['', 'ti tree oil', 'melaleuca oil', '']
# ['', 'benzoin absolute', 'gum benzoin tincture', 'benzoin resin, unspecified', 'gum sumatra', 'gum benzoin', 'benzoin tincture, compound', '']
# ['', 'styrax gum (liquidambar styraciflua)', 'liquidambar styraciflua resin', 'american storax', 'sweet gum', 'redgum gum', 'american sweetgum gum', 'liquidambar macrophylla resin', '']
# ['', 'thermus thermophilus lysate', 'venuceane', 'thermus thermophilus ferment', '']
# ['', 'peg-80', 'peg 3500', 'polyethylene glycol 3500', 'macrogol 3500', '']
# ['', 'european elder flowering top', 'sambucus nigra', 'european black elderberry flowering top', 'black elder flowering top', '']
# ['', 'curcuma zanthorrhiza oil', 'temu lawak oil', 'curcuma xanthorrhiza volatile oil', 'curcuma zanthorrhiza root oil', 'curcuma xanthorrhiza root oil', '']
# ['', 'diethylbenzylidene malonate dimethicone', 'dimethicodiethylbenzalmalonate', 'diethylmalonylbenzylidene oxypropene dimethicone', '']
# ['', 'protein c human', 'blood coagulation factor xiv', 'human protein c', 'protein c concentrate (human)', 'protein c (coagulation inhibitor)', 'protein c concentrate', 'protein c concentrate human', 'autoprothrombin iia', '']
# ['', 'polyphenylmethyl siloxane', 'methyl phenyl polysiloxane', '']
# ['', 'vibrio subtilis whole', 'bacillus subtilis whole', '']
# ['', 'flaxseed oil', 'flax oil', '']
# ['', 'oenothera oil', 'oenothera lamarckiana l. oil', 'oleum oenotherae erythrospinae', 'oenothera biennis (evening primrose) seed extract', 'primrose oil', 'oils, glyceridic, evening primrose', 'oenothera biennis (evening primrose) oil', 'oenothera biennis seed oil', 'oenothera biennis l. oil', 'oenotherae biennis oleum', 'oenothera pycnocarpa seed oil', 'oenothera biennis seed extract', 'oenothera muricata seed oil', '']
# ['', 'white birch oil', 'birch tar oil, rectified', 'betula verrucosa tar oil', 'betula alba oil', 'european white birch tar oil', 'betula alba var. pendula tar oil', 'rectified birch tar oil', 'birch tar oil', 'betula pendula tar volatile oil', 'betula pendula resin oil', '']
# ['', 'balsam-of-peru oil', 'balsam peru volatile oil', 'balsam (peru) oil', 'peruvian balsam oil', 'myroxylon pereirae wood oil', 'balsam peru', 'toluifera balsamum var. pereirae wood oil', 'balsam of peru essential oil ', 'balsam peru oil', 'toluifera pereirae wood oil', 'peru balsam oil', 'bálsamo perú', 'myroxylon pereirae (balsam peru) oil', 'bálsamo de perú', 'china oil', 'myroxylon balsamum var. pereirae wood oil', 'myrospermum sonsonatense wood oil', 'myrospermum pereirae wood oil', '']
# ['', 'thrombin (human)', 'thrombin human', 'thrombin human plasma-derived', 'trombina humana', '']
# ['', 'rho d immune globulin human', 'immunoglobulin human anti-rh', 'rh0(d) immune globulin intravenous (human)', 'anti-d immunoglobulins', 'igg, rho (d)', 'rho(d) immune globulin im human', 'human anti-d immunoglobulin', 'rho(d) immune globulin (human)', 'rho(d) immune globulin human', 'anti-d immunoglobulin', 'rho (d) immune globulin,human', '']
# ['', 'purified protein derivative of tuberculin', 'tuberculina ppd', 'tuberculin,purified protein derivative', 'tuberculin, purified protein derivative', 'tuberculinum', 'mycobacterium tuberculosis purified protein derivative', 'tuberculin ppd', '']
# ['', 'porcine recombinant factor viii b-domain truncated', 'antihemophilic factor porcine, b-domain truncated recombinant', 'antihemophilic factor (recombinant) porcine sequence', '']
# ['', 'antihemophilic factor (recombinant, fc fusion protein)', 'antihemophilic factor (recombinant bdd), fc fusion protein', 'coagulation factor viii recombinant immunoglubulin g1 fusion protein', '']
# ['', 'coagulation factor ix recombinant immunoglubulin g1 fusion protein', 'recombinant human coagulation factor ix, fc fusion protein', '']
# ['', 'hbsag', 'hepatitis b surface antigen', 'hepatitis b surface antigens', 'hepatitis b surface antigen (recombinant)', 'hepatitis-b surface antigen', 'hepatitis b surface antigen (rdna)', 'hepatitis b virus hbsag surface protein antigen', 'hepatitis b surface antigen vaccine', 'hepatitis b antigen', 'hepatitis b vaccine', '']
# ['', 'cholera enterotoxin b chain', 'choleragenoid', 'cholera enterotoxin subunit b', '']
# ['', 'r-hil-7', 'recombinant human interleukin-7', 'il-7', 'interleukin-7 human recombinant', 'sh-polypeptide-42', 'interleukin 7 glycosylated', '']
# ['', 'pineapple stem bromelain', 'bromelain, stem', '']
# ['', 'recombinant human alpha mannosidase', 'rhlaman', 'lamazym', '']
# ['', 'bcg ssi', 'bcg (ssi strain)', '']
# ['', 'human endothelin', 'endothelin 1 (rat)', 'endothelin (porcine)', 'endothelin 1 (pig)', 'endothelin 1 (human)', '']
# ['', 'rcv', '(+/-)-emtricitabine', '']
# ['', 'il-10 (nonglycosylated)', 'il-10', '']
# ['', 'factor xiii, human', 'factor xiii concentrate (human)', 'fibrinoligase', 'factor xiii (fibrin stabilising factor)', 'factor xiii', '']
# ['', 'boanmycin', 'pingyangmycin a6', 'zhengguangmycin a6', '']
# ['', 'urocortin 2', 'urocortin ii', '']
# ['', 'von willebrand factor', 'factor con willebrand', 'von willebrand factor complex (human)', "von willebrand's factor", 'human von willebrand factor', 'factor von willebrand', 'von willebrand factor (human)', 'von willebrand factor, human', '']
# ['', 'pancreatic lipase', 'lipase, pancreatic', '']
# ['', 'coagulation factor x (human)', 'factor x', 'factor x (stuart prower factor)', 'stuart-prower factor', 'human coagulation factor x', 'coagulation factor x', '']
# ['', 'protein s (human)', 'vitamin k-dependent protein s', 'protein s', '']
# ['', 'factor vii human', 'serum prothrombin conversion accelerator', 'factor vii (proconvertin)', 'factor vii', 'coagulation factor vii (human)', 'human coagulation factor vii', 'proconvertin', '']
# ['', 'activated prothrombin complex concentrate', 'factor viii inhibitor bypassing fraction', 'antiinhibitor coagulant complex', 'factor viii bypassing fraction', 'factor viii inhibitor bypassing activity', '']
# ['', 'human coagulation factor ix', 'factor ix (human)', 'factor ix purificado', 'coagulation factor ix (human)', 'antihemophilic factor b', '']
# ['', 'omega 6 acids', 'omega 6 fatty acids', 'n-6 fatty acids', 'ω-6 fatty acids', '']
# ['', 'calcitonin (pork natural)', 'calcitonin (porcine)', 'alpha-thyrocalcitonin (pig)', 'pig calcitonin', 'calcitonin pork', 'calcitonin (pork)', 'calcitonin (swine)', 'porcine calcitonin', 'calcitonin,porcine', 'alpha-thyrocalcitonin (porcine)', 'pig alpha-thyrocalcitonin', '']
# ['', 'chaste tree', 'agni casti fructus', '']
# ['', 'hederae helicis folium', 'hedera helix leaf', '']
# ['', 'quassia amara wood', 'quassia amara', 'surinam quassia wood', '']
# ['', "monsel's solution", 'ferric subsulfate', 'basic ferric sulfate solution', '']
# ['', 'cytomegalovirus immunoglobulin', 'cmv-immune globulin', 'cmvig', '']
# ['', 'neisseria meningitidis group w-135 polysaccharide antigen, a', 'meningococcal polysaccharide antigen group w-135', 'neisseria meningitidis group w-135 capsular polysaccharide antigen', '']
# ['', 'neisseria meningitidis group y polysaccharide antigen, a', 'meningococcal polysaccharide antigen group y', 'neisseria meningitidis group y capsular polysaccharide antigen', '']
# ['', 'botulinum neurotoxin e immune fab2, equine', 'botulinum neurotoxin e immune fab2 (equine)', '']
# ['', 'botulinum neurotoxin c immune fab2 (equine)', 'botulinum neurotoxin c immune fab2, equine', '']
# ['', 'botulinum neurotoxin g immune fab2, equine', 'botulinum neurotoxin g immune fab2 (equine)', '']
# ['', 'botulinum neurotoxin a immune fab2 (equine)', 'botulinum neurotoxin a immune fab2, equine', '']
# ['', 'botulinum neurotoxin f immune fab2, equine', 'botulinum neurotoxin f immune fab2 (equine)', '']
# ['', 'botulinum neurotoxin d immune fab2 (equine)', 'botulinum neurotoxin d immune fab2, equine', '']
# ['', 'botulinum neurotoxin b immune fab2 (equine)', 'botulinum neurotoxin b immune fab2, equine', '']
# ['', 'felis catus dander', 'cat dander diagnostic allergen extract', '']
# ['', 'centruroides antivenin (equine)', 'centruroides (scorpion) immune fab2 (equine)', "centruroides (scorpion) immune f(ab')2 (equine) injection", 'antivenin,centruroides immune fab2', 'centruroides suffusus suffusus) (equine)', 'centruroides (scorpion) immune f(ab)2 intravenous (equine)', 'mexican scorpion (centruroides) fab2 antivenin (equine)', 'centruroides antivenin', 'antivenin, scorpion', "centruroides (scorpion) immune f(ab')2 (equine)", 'centruroides fab2 antivenin (equine)', 'scorpion (centruroides) fab2 immunoglobulin (equine)', 'polyvalent mexican scorpion antivenin (horse)', '']
# ['', 'gibbera saubinetii', 'fusarium roseum', 'dichomera saubinetii', 'sphaeria saubinetii', 'dothidea zeae', 'fusarium graminearum', 'sphaeria zeae', 'gibberella zeae whole', 'gibberella saubinetii', 'gibberella zeae', 'botryosphaeria saubinetii', 'gibberella rosea', '']
# ['', 'recombinant varicella zoster virus (vzv) glycoprotein e', 'ge recombinant varicella zoster virus (vzv) glycoprotein e', 'ge: recombinant varicella zoster virus (vzv) glycoprotein e', '']
# ['', 'cenegermin-bkbj', 'rhngf', '']
# ['', 'pitcher plant', 'sarracenia rosea whole', "frog's-britches whole", 'sarracenia purpura', 'sidesaddle-flower whole', 'purple pitcherplant whole', "huntsman's-horns whole", 'sarracenia purpurea l.', 'sarracenia purpurea whole', 'pitcherplant whole', '']
# ['', 'passiflora incarnata flower dry extract', 'passiflora incarnata flower extract', 'passion flower extract', 'passion flower', 'true passionflower', 'purple passionflower', '']
# ['', 'black snakeroot', 'cimicifuga racemosa rhizome', 'rattleroot', 'cimicifuga racemosa root', 'fairy candle root', 'cimicifuga racemosa root with rhizome', 'black cohosh', 'cimicifugae rhizoma', '']
# ['', 'tocopherol acetate, unspecified', 'tocopheryl acetate', 'vitamin e acetate, unspecified form', 'vitamin e (alpha tocopherol acetate)', 'vitamin e acetate', 'tocopherol acetate', '']
# adding tocopheryl acetate
# adding tocopherol acetate
# ['', 'marijuana top', 'cannabis sativa subsp. indica top extract', 'marihuana', 'cannabis sativa subsp. indica top', 'marijuana', 'cannabis', 'hashish top', 'cannabis indica', 'cannabis indica top', '']
# ['', 'sh-polypeptide-17', 'il-1 alpha', 'il-1α', 'dermapoietin', 'il1 alpha', 'dermatopoietin', 'interleukin 1 alpha', 'il1a', 'hematopoietin-1', '']
# ['', 'collagen, porcine', 'collagen porcine', '']
# ['', 'soy germ isoflavones', 'soybean isoflavones', 'soybean isoflavoues', '']
# ['', 'antivenin (bothrops atrox/crotalus adamanteus/crotalus atrox/crotalus durissus terrificus) (equine)', 'antivenin,crotalidae polyvalent', 'pit viper (crotalid) antivenin (equine)', 'polyvalent crotalidae antivenin', 'crotalidae polyvalent antivenin (equine)', 'antivenin (crotalidae) polyvalent (equine origin)', 'crotaline antivenin', 'crotaline antivenin, polyvalent', 'antivenin crotaline (pit-viper) equine immune f(ab)2)', 'antivenin, crotalidae polyvalent, equine', 'polyvalent crotalidae antivenin (equine)', 'pit viper (crotalinae) immunoglobulin (equine)', "crotalidae immune f(ab')2 (equine)", 'antivenin (crotalidae) polyvalent (equine)', 'pit viper (crotalinae) immune globulin (equine)', 'pit viper (crotalinae) antivenin (equine)', 'pit viper (crotalinae) immune globulin antivenin (equine)', 'pit viper (crotalidae) antivenin (equine)', 'crotalid antivenin (equine)', 'pit viper (crotalinae) immune antivenin (equine)', '']
# ['', 'botulism immune globulin intravenous (human) (big-iv)', 'human-derived botulism antitoxin antibodies', 'botulism immune globulin intravenous (human)', 'botulism immune globulin iv human', '']
# ['', 'cyclopolydimethylsiloxane', 'polydimethyl siloxy cyclics', 'dimethylcyclopolysiloxane', 'polydimethylcyclosiloxane', '']
# ['', 'recombinant human basic fibroblast growth factor, kcb-1', 'kcb-1', 'basic fgf', 'heparin-binding growth factor 2', 'fgf 2', 'bfgf', 'basic astrolial growth factor', 'basic fibroblast growth factor, recombinant human, kcb-1', 'fibroblast growth factor, basic', '']
# ['', 'ethyl hydroxyethylcellulose', 'hydroxyethylcellulose ethylether', 'ethyl-2-hydroxyethylcellulose', '2-hydroxyethyl ether of ethyl cellulose', 'cellulose ethyl hydroxyethyl ether', 'ethylhydroxyethylcellulose', 'cellulose, ethyl 2-hydroxyethyl ether', 'ethyl hydroxyethyl cellulose', '']
# ['', "1,1'-oxybis(2-propanol)", '4-oxa-2,6-heptandiol', 'dipropyleneglycol', 'oxybispropanol', '']
# ['', 'methoxy peg-12 all-trans-retinamide', 'medimin a', '']
# ['', 'albumin human, microspheres', 'albumin microsphere human serum', 'human serum albumin microspheres', 'albumin,microsphere human serum', 'albumin, microsphere human serum', 'protein-type a microspheres', '']
# ['', 'soya lecithin, hydrogenated', 'glycine max lecithin, hydrogenated', 'hydrogenated lecithin soybean', 'hydrogenated lecithin (soybean)', 'hydrogenated soybean phosphatidylcholine', 'lecithin, soybean, hydrogenated', 'hydrogenated soy lecithin', 'soya lecithins, hydrogenated', 'lecithin, hydrogenated soybean', 'soy lecithin, hydrogenated', 'hydrogenated soybean phosphatitylcholine', 'lecithin, hydrogenated', '']
# ['', 'thunnus thynus flesh', 'thynnus secundodorsalis flesh', 'bluefin tunny', 'thynnus linnei flesh', 'thunnus thynnus flesh', 'albacora thynnus flesh', 'tuna (thunnus thynnus)', 'thynnus thynnus flesh', 'thynnus vulgaris flesh', 'northern bluefin tuna flesh', 'thunnus vulgaris flesh', 'orcynus thynnus flesh', 'orcynus secondidorsalis flesh', 'atlantic bluefin tuna', 'thunnus thynnus muscle', 'thynnus mediterraneus flesh', 'thunnus secundodorsalis flesh', 'scomber thynnus flesh', '']
# ['', 'anthoxanthum pauciflorum whole', 'vanilla grass', 'anthoxanthum alpinum whole', 'buffalo grass', 'xanthonanthos odoratus whole', 'sweet vernal grass', 'anthoxanthum asperum whole', 'anthoxanthum maderense whole', 'anthoxanthum nebrodense whole', 'anthoxanthum pilosum whole', 'anthoxanthum odoratum whole', 'anthoxanthum sommierianum whole', 'holy grass', 'sweet vernalgrass', 'anthoxanthum villosum whole', 'phalaris ciliata whole', '']
# ['', 'culex domesticus', 'culex calcitrans', 'culex varioannulatus', 'culex pipiens', 'culex pipiens whole', 'culex marginalis', 'culex osakaensis', 'culex meridionalis', 'culex trifurcatus', 'culex molestus', 'culex musca', 'culex sternopunctatus', 'culex autogenicus', 'culex azoriensis', 'culex pallipes', 'culex melanorhinus', 'culex phytophagus', 'culex thoracicus', 'culex pallens', 'culex quasimodestus', 'culex torridus', 'culex luteus', 'culex longefurcatus', 'culex calloti', 'northern house mosquito whole', 'culex erectus', 'culex rufus', 'culex unistriatus', 'culex haematophagus', 'culex pipiens preparation', 'culex agilis', 'culex comitatus', 'northern house mosquito', 'culex disjunctus', 'culex pipines', 'culex rufinus', 'culex dipseticus', 'culex consobrinus', 'culex bicolor', 'culex bifurcatus', 'culex doliorum', '']
# ['', 'rumex acetosella whole', 'rumex arvensis whole', 'red sorrel whole', 'sheep sorrel', 'sheep sorrel whole', 'acetosella acetosella whole', 'rumex acetosella', 'common sheep sorrel whole', 'field sorrel whole', '']
# ['', 'narrowleaf dock', 'curley dock', 'rumex crispus top', 'rumex crispus flower/leaf/stem extract', 'sour dock', 'curly dock', '']
# ['', 'sarocladium strictum', 'molds, rusts and smuts, cephalosporium acremonium', 'ae-cephalosporium acrimonium', 'acremonium strictum allergenic extract', 'acremonium strictum extract', 'allergenic extract, cephalosporium acrimonium', 'allergenic extract- cephalosporium acremonium', 'allergenic extract, cephalosporium acremonium', 'molds, rusts and smuts, acremonium strictum', 'cephalosporium chrysogenum thirum. & sukapure 1963', '']
# ['', 'salix nigra bark', 'salix nigra', 'salix dubia bark', 'salix flavovirens bark', 'salix ligustrina bark', 'salix ludoviciana bark', 'salix ambigua bark', 'salix nigra (willow) bark extract', 'salix purshiana bark', 'salix falcata bark', 'black willow bark', 'salix denudata bark', '']
# ['', 'common wormwood root', 'artemisia vulgaris', 'absinthium spicatum root', 'felon-herb root', 'artemisia affinis root', 'artemisia vulgaris root extract', 'artemisia opulenta root', 'artemisia javanica root', 'mugwort root', 'nagadamani root', 'artemisia officinalis root', 'artemisia vulgaris root', '']
# ['', 'allergenic extract- penicillium glaucum', 'penicillium glaucum', 'molds, rusts and smuts, penicillium glaucum', 'carpenteles glaucum', 'molds, rusts and smuts, penicillium glaucus', 'ae-penicillium glaucus', 'penicillium glaucum whole', 'allergenic extract- penicillium glaucus', '']
# ['', 'evernia herinii', 'parmelia prunastri var. retusa', 'lichen stictoceros', 'oak moss absolute', 'evernia stictoceros', 'lichen prunastri', 'evernia prunastri whole', 'physcia prunastri', 'oak moss', '']
# ['', 'timothy top', 'timothy', 'timothy grass', 'common timothy top', 'phleum nodosum top', 'common timothy', 'timothy grass top', '']
# ['', 'bifidobacterium liberorum whole', 'bifidobacterium lactentis whole', 'bifidobacterium longum bv. infantis whole', 'bifidobacterium infantis whole', 'bifidobacterium infantis', 'bifidobacterium longum infantis whole', 'bifidobacterium longum subsp. infantis whole', 'bifidobacterium longum subsp. infantis', '']
# ['', 'clostridium putrificum whole', 'bacillus putrificus whole', 'ermengemillus botulinus whole', 'bacillus botulinus whole', 'pacinia putrifica whole', 'clostridium botulinum whole', 'botulobacillus botulinus whole', '']
# ['', 'l. reuteri', 'lactobacillus fermentum subsp. reuteri whole', 'lactobacillus reuteri whole', 'lactobacillus fermentum biotype ii whole', '']
# ['', 'streptococcus faecium whole', 'enterococcus faecium whole', '']
# ['', 'thermobacterium helveticum whole', 'caseobacterium e whole', 'lactobacillus helveticus whole', 'bacillus casei e whole', 'bacillus e whole', 'lactobacillus helveticum whole', 'lactobacterium helveticum whole', 'plocamobacterium helveticum whole', '']
# ['', 'dl-threonic acid', 'threo-2,3,4-trihydroxybutyric acid', '2,3,4-trihydroxy-(threo)-butanoic acid', '']
# ['', 'lowbush blueberry fruit', 'vaccinium angustifolium (blueberry) fruit', 'cyanococcus pensylvanicus fruit', 'vaccinium lamarckii fruit', 'cyanococcus angustifolius fruit', 'vaccinium angustifolium fruit', 'vaccinium brittonii fruit', 'vaccinium minutiflorum fruit', 'vaccinium multiflorum fruit', 'vaccinium ramulosum fruit', 'vaccinium nigrum fruit', 'vaccinium humile fruit', '']
# ['', 'd & c yellow no. 10', 'japan yellow 203', 'c.i. food yellow 13', 'food yellow 13', 'd and c yellow no. 10', 'd&c yellow no. 10', '']
# ['', 'phospholipids egg', 'egg oil lecithin', 'endolipide component egg lecithin', 'egg yolk lecithins', 'egg lecithin', 'egg phospholipid', 'egg phospholipids', 'egg yolk phosphatides', 'lecithins, egg yolk', 'egg yolk lecithin', 'egg yolk phospholipids', 'egg oil phospholipids', 'egg lecithin component of endolipide', 'egg phosphatides', '']
# ['', 'pork, stomach', 'porcine stomach', 'wild boar stomach', 'pig stomach', 'swine stomach', '']
# ['', 'dwarf bilberry', 'fresh billberry fruit (vaccinium myrtillus l.)', 'whortleberry', 'vaccinium myrtillus dry fruit', 'vaccinium myrtillus fruit', 'myrtilli fructus siccus (vaccinium myrtillus l.)', 'myrtilli fructus recens (vaccinium myrtillus l.)', 'bilberry fruit', 'myrtillus', 'vaccinium myrtillus', 'myrtle blueberry fruit', 'dwarf bilberry fruit', 'european blueberry fruit', 'myrtle whortleberry', 'myrtle whortleberry fruit', 'myrtilli fructus', 'myrtle blueberry', 'dried billberry fruit (vaccinium myrtillus l.)', 'european blueberry', '']
# ['', 'aloe vera polysaccharide extract', 'hydrapol', 'aloe barbadensis leaf polysaccharides', 'aloe vera (l.) burm.f. leaf polysaccharides', '']
# ['', 'echinacea purpurea aerial parts extract', 'echinacea purpurea flower', 'purple coneflower flowering top', 'eastern purple coneflower flowering top', 'rudbeckia purpurea flowering top', 'echinacea purpurea aerial parts', 'brauneria purpurea flowering top', 'echinacea purpurea herb', '']
# ['', 'echinaceae purpureae herba', 'purple coneflower', 'brauneria purpurea (l.) britton', 'eastern purple coneflower whole', 'brauneria purpurea whole', 'purple coneflower herb', 'echinacea purpurea extract', 'echinacea purpurea whole', 'rudbeckia purpurea whole', 'rudbeckia serotina whole', 'rudbeckia purpurea l.', 'echinacea purpurea herb with root', 'echinacea purpurea (purple coneflower), fresh herb', 'rudbeckia speciosa whole', 'echinacea serotina whole', 'purple coneflower whole', 'echinacea speciosa whole', 'echinacea purpurea (l.) moench', 'brauneria purpurea', 'eastern purple coneflower', 'rudbeckia purpurea', 'echinacea purpurea (purple coneflower), dried herb', 'echinacea intermedia whole', 'echinacea whole', '']
# ['', 'caviar extract', 'caviar', 'caviar preparation', '']
# ['', 'pork placenta', 'placenta, porcine', 'placenta totalis suis', '']
# ['', 'brown garden snail mucin', 'brown gardensnail mucin', 'garden snail mucin preparation', '']
# ['', 'collagen, soluble, fish skin', 'collagen,soluble', 'fish skin collagen, soluble', '']
# ['', 'chinese forest musk deer musk sac resin', 'shexiang (moschus berezovskii)', 'musk (moschus berezovskii)', 'dwarf musk deer musk sac resin', 'moschus (moschus berezovskii)', '']
# ['', 'bos primigenius gallstone', 'bovis calculus', 'cow gallstone', 'bos taurus gallstone preparation', 'niuhuang', 'aurochs gallstone', 'domestic cattle gallstone', 'tiwai peiyu niuhuang', 'niu huang', 'bezoar', 'rengong niuhuang', 'bovine gallstone', 'cow-bezoan cultured in vitro', 'cow-bezoar', 'artificial cow-bezoan', 'domestic cow gallstone', 'bovis calculus sativus', 'calculus bovis', 'bos indicus gallstone', 'bovis calculus artifactus', '']
# ['', 'zhenzhu (hyriopsis cumingii)', 'pearl powder', 'cultured freshwater pearl', 'pearl', 'hyriopsis cumingii cultured pearl', 'margarita (hyriopsis cumingii)', '']
# ['', 'apis mellifera secretion', 'fengla (apis mellifera)', 'honey bee secretion', 'beeswax (apis mellifera)', 'cera flava (apis mellifera)', 'queen bee jelly', 'honeybee secretion', 'honey (apis mellifera)', 'honey bee secretion used in the nutrition of larvae and adult queens secreted from worker bee hypopharyngeal glands', '']
# ['', 'oyster shell', 'oyster shell extract', 'edible oyster shell', 'oyster shell powder', 'ostrea shell powder', 'mud oyster shell', 'ostrea shell extract', 'common oyster shell', 'colchester native oyster shell', 'european flat oyster shell', '']
# ['', 'jojoba seed oil', 'simmondsia chinensis seed oil', 'buxus chinensis oil', 'simmondsia californica oil', 'simmondsia chinensis (jojoba) seed oil', 'simmondsia chinensis oil', '']
# ['', 'avena sativa flowering top extract', 'avena sativa', 'avena byzantina flowering top', 'oat flowering top', '']
# ['', 'aloe barbadensis flower extract', 'li hui hua', 'aloe vera flower extract', 'curacao aloe flower', 'aloe barbadensis flower', 'aloe flower extract', 'ghrita kumari flower', 'barbatos aloe flower', '']
# ['', 'bai zhi', 'baizhi (angelica dahurica)', 'dahurian angelica root', 'o-sisi-udo root', 'dahurian angelica root (angelica dahurica)', 'ezo senkyu root', 'yoroi-gusa root', 'udo-modaki root', 'angelica dahurica root powder', 'angelicae dahuricae radix (angelica dahurica)', 'fragrant angelica root', 'angelica dahurica root extract', 'angelicae dahuricae radix', 'angelica dahurica root dry extract', '']
# ['', 'bacopa whole', 'asiatic pennywort whole', 'gotu kola', 'mandukaparni whole', 'centella asiatica extract', 'coastal water-hyssop whole', 'luo de da whole', 'spadeleaf whole', 'herba centellae', 'sheep-rot whole', 'hydrocotyle asiatica', 'brahmi whole', 'water hyssop whole', 'bacopa monniera whole extract', 'gotu kola whole', 'thankuni whole', 'ji xue cao whole', 'indian pennywort whole', 'jixuecao whole', 'ma ti cao whole', 'hydrocotyle', '']
# ['', 'aloe ferox leaf extract', 'aloe ferox leaf exudate', 'lu hui (aloe ferox)', 'aloe ferox leaf preparation', 'aloe folii extractus (aloe ferox)', 'aloe candelabrum leaf', 'pachidendron supralaeve leaf', 'aloe ferox leaf powder', 'aloe ferox juice', 'aloe capensis', 'aloe ferox leaf juice extract', 'aloe herba (aloe ferox)', 'cape aloes', 'aloes (aloe ferox)', 'aloe pallancae leaf', 'aloe pseudoferox leaf', 'aloe ferox leaf juice', 'aloe folium (aloe ferox)', 'aloe muricata leaf', 'aloe ferox leaf gel', 'cape aloe leaf', 'aloe galpinii leaf', 'luhui (aloe ferox)', 'busipho ferox leaf', 'aloe ferox dry leaf juice', 'aloe ferox leaf juice powder', 'pachidendron ferox leaf', 'aloe subferox leaf', 'aloe (aloe ferox)', 'pachidendron pseudoferox leaf', 'new aloe', 'aloe supralaevis leaf', 'aloe horrida leaf', '']
# ['', 'eucomniae cortex', 'hardy rubber tree bark', 'eucommia bark (eucommia ulmoides)', 'du zhong', 'eucommia bark', 'du zhong bark', 'eucommia ulmoides bark extract', 'gutta-percha-tree bark', 'eucommiae cortex', 'chinese rubber tree bark', 'duzhong', '']
# ['', 'sphacelaria scoparioides', 'halopteris scoparia', 'sphacelaria scoparia', 'stypocaulon spinulosum', 'sphacelaria scoparia extract', 'halopteris scoparia extract', 'stypocaulon scoparium whole', 'halopteris spinulosa', 'sphacelaria spinulosa', 'conferva scoparia', '']
# ['', 'korean ginseng fruit', 'asian ginseng fruit', 'chinese ginseng fruit', 'panax ginseng berry extract', 'panax schinseng fruit', 'panax verus fruit', 'aralia ginseng fruit', '']
# ['', 'capsicum annuum var. minus fruit', 'piquin', 'capsicum annuum var. aviculare fruit', "bird's eye pepper fruit", 'chile tepin', 'bird pepper extract', 'american bird pepper fruit', 'chilipiquin', 'chiltepin pepper', 'tepin pepper fruit', 'american bird pepper', 'chiltepe fruit', 'african bird pepper', 'chilipiquin fruit', 'tepin pepper', 'chiltepe', 'capsicum annuum var. minimum fruit', 'capsicum annuum var. glabriusculum fruit', 'chiltepin pepper fruit', 'chile tepin fruit', "bird's eye pepper", '']
# ['', 'calendula oil', 'marigold, pot', 'marigold extract', 'calendula officinalis flower extract', 'calendula flower', 'calendula hydruntina flower', 'calendula eriocarpa flower', 'caltha officinalis flower', 'calendula officinalis flower water', 'calendula x santamariae flower', 'calendula officinalis flower oil', 'calendula aurantiaca flower', 'calendula officinalis extract', 'calendula prolifera flower', 'calendula officinalis flower fluid extract', 'marigold pot flower', 'calendulae flos', 'pot marigold flower', 'calendula flower olive oil infusion', '']
# ['', 'burra gokharu root', 'bindii root', 'puncturevine caltrop root', 'goathead root', 'small caltrops root', 'gokshura root', 'yellow vine root', 'tribulus root', 'tribulus terrestris root extract', 'tribulus terrestris root powder', '']
# ['', 'curled dock whole', 'yellow dock', 'curly dock whole', 'sour dock whole', 'yellow dock whole', '']
# ['', 'chinese spikenard whole', 'nardostachys whole', 'chinese nardostachys whole', 'chinese nardostachys', 'nardostachys chinensis', '']
# ['', 'jojoba seed', 'deer nut seed', 'coffeeberry seed', 'simmondsia chinensis (jojoba) seed powder', 'buxus chinensis seed', 'simmondsia chinensis (jojoba) seed extract', 'wild hazel seed', 'pignut seed', 'quinine nut seed', 'simmondsia californica seed', 'gray box bush seed', 'goat nut seed', 'goatnut seed', '']
# ['', 'morus alba var. multicaulis root bark', 'morus acidosa root bark', 'morus sinensis root bark', 'morus tatarica root bark', 'tut kishmishmi root bark', 'white mulberry root-bark', 'mulberry bark', 'sang root bark', 'white mulberry root bark', 'mulberry white bark', 'sangbaipi', 'mori cortex', 'morus intermedia root bark', 'morus multicaulis root bark', 'morus alba multicaulis root bark', 'sang bai pi', 'sang zhi root bark', '']
# ['', 'holy basil top', 'tulsi top', 'sacred basil top', 'holy basil leaf/stem', 'tulasi top', 'ocimum sanctum', 'ocimum tenuiflorum extract', '']
# ...
# ['', 'elecampane inula root', 'elf-dock root', 'elf-wort root', 'inula helenium rhizome', 'tumuxiang (inula helenium)', 'inula', 'saussurea radix (inula helenium)', 'yellow starwort root', 'tu mu xiang root', 'mu xiang (inula helenium)', 'inula helenium root extract', 'velvet-dock root', 'aucklandiae lappa radix (inula helenium)', 'scab-wort root', 'horse-elder root', 'elecampane root', 'inula root (inula helenium)', 'wood fragrance (inula helenium)', 'elecampane', 'aucklandiae radix (inula helenium)', 'inulae radix (inula helenium)', 'elecampane root extract', 'tu mu xiang', 'elecampane rhizome', 'inula helenium extract', 'inula helenium', 'inulae racemosae radix (inula helenium)', 'elecampane extract', 'horse-heal root', 'inula helenium root with rhizome', '']
# ['', 'bearded usnea', 'usnea extract', 'usnea barbata whole', 'usnea (usnea barbata)', 'usnea', 'usnea barbata (lichen) extract', 'lichen barbatus', '']
# ['', 'antelaea azadirachta leaf', 'melia azadirachta leaf powder', 'azadirachta indica leaf extract', 'neem leaf', 'nimba leaf', 'melia azadirachta leaf extract', 'azadirachta leaf', 'melia azadirachta leaf', 'bead tree leaf', 'margosa leaf', '']
# ['', 'hercules-club whole', 'hercules club whole', 'southern prickly ash', 'zanthoxylum clava-herculis', 'pepperwood whole', 'hercules-club pricklyash whole', '']
# ['', 'salix vitellina bark water', 'salix alba (willow) bark water', 'salix alba bark water', 'white willow bark volatile oil', 'salix vitellina bark volatile oil', 'golden willow bark water', 'white willow bark water', 'golden willow bark volatile oil', '']
# ['', 'malus domestica fruit oil', 'apple fruit water', 'malus domestica fruit water', 'malus x domestica fruit oil', 'pyrus malus (apple) fruit water', '']
# ['', 'balloon flower leaf', 'chinese-bellflower leaf', 'platycodon leaf', 'japanese bellflower leaf', 'platycodon grandiflorum leaf', 'jie geng leaf', '']
# ['', 'small caltrops whole', 'bullhead whole', 'burra gokharu whole', 'yellow vine whole', 'mexican sandbur whole', 'bindii whole', 'caltrop whole', 'puncture vine whole', 'goathead whole', 'puncturevine caltrop whole', 'tribulus', 'tribulus whole', 'texas sandbur whole', 'gokshura whole', '']
# ['', 'tremella fuciformis', 'silver ear fungus whole', 'tremella', 'snow fungus whole', '']
# ['', 'rice hull', 'oryza sativa (rice) hull powder', 'oryza sativa (rice) bran extract', 'oryza sativa bran', 'oryza sativa (rice) bran', 'oryza sativa (rice) bran wax', 'rice bran wax', 'oryza sativa (rice) hull extract', 'oryza sative bran wax', 'rice bran fiber', '']
# ['', 'shobhanjana leaf', 'shigru leaf', 'horseradish tree leaf', 'moringa oleifera leaf extract', 'moringa moringa leaf', 'moringa pterygosperma leaf', 'horseradishtree leaf', 'maranga leaf', 'muringnga leaf', 'murungai leaf', '']
# ['', 'rosa centifolia flower water', 'rose absolute (rosa centifolia)', 'cabbage rose water', 'cabbage rose oil', 'rosa centifolia flower volatile oil', '']
# ['', 'scutellaria baicalensis extract', 'scutellaria root extract', 'baical skullcap root', 'scutellaria baicalensis root powder', 'scutellaria lanceolaria root', 'scutellaria macrantha root', 'scutellariae radix', 'scutellaria baicalensis root dry extract', 'huang qin', 'huangqin', 'scutellaria root', 'scutellaria baicalensis root extract', 'scutellaria baicalensis', 'scutellaria baicalensis root georgi', '']
# ['', 'garcinia fruit', 'garcinia cambogia', 'gambooge fruit', 'brindall berry fruit', 'garcinia cambogia fruit', 'garcinia cambogia fruit extract', 'kodumpuli fruit', 'garcinia cambogia (constituent of garcinia cambogia and garcinia indica)', 'goraka fruit', 'malabar tamarind fruit', 'brindleberry fruit', '']
# ['', 'paraguay tea extract', 'ilex paraguariensis leaf extract', 'yerba mate', 'mat', 'ilex mate', 'yerba mate extract', 'ilex paraguariensis', 'paraguay tea', "mate' leaf (ilex paraguariensis st. hilaire)", 'yerba mat', 'mate extract', 'mate folium (ilex paraguariensis st. hilaire)', 'mate', 'houx mate', "jesuit's tea", 'mate absolute', 'mate folium', 'mate (leaves)', '']
# ['', 'chondrus crispus whole', 'chondrus platynus', 'mazzaella heterocarpa', 'carageen', 'chondrus crispus powder', 'polymorpha crispa', 'iridaea heterocarpa', 'chondrus crispus leaf', 'irish moss (chondrus crispus)', 'carrageen', 'chondrus norvegicus', 'carrageen moss', 'iridophycus heterocarpum', 'carrageen leaf', 'irish moss', 'fucus norvegicus', 'halymenia platynus', 'carageen leaf', '']
# ['', 'cayenne pepper whole', 'pimento whole', 'sweet pepper whole', 'capsicum annuum whole extract', 'red pepper whole', '']
# ['', 'typhonium', 'typhonium giganteum', 'typhonium whole', 'typhonium stoliczkae whole', 'typhonium giraldii whole', '']
# ['', 'yellow fir (phellodendron amurense)', 'amur cork-tree bark (phellodendron amurense)', 'amur cork tree bark', 'phellodendron amurense', 'phellodendron bark (phellodendron amurense)', 'phellodendri amurensis cortex', 'amur cork-tree', 'phellodendron amurense bark extract', 'guanhuangbo', 'phellodendri cortex (phellodendron amurense)', '']
# ['', 'melaleuca alternifolia (tea tree) leaf', 'narrow-leaved tea-tree leaf', 'snow-in-summer leaf', 'narrow-leaved ti-tree leaf', 'melaleuca alternifolia (tea tree) leaf powder', 'narrow-leaved paperbark leaf', 'melaleuca alternifolia (tea tree) leaf extract', 'tea tree', '']
# ['', 'sawtooth oak whole', 'quercus acutissima', '']
# ['', 'radicchio,raw', 'cichorium intybus (chicory) leaf extract', 'cichorium intybus leaf', 'cichorium intybus leaf extract', 'chicory greens, raw', 'ju ju', 'cichorii herba', 'chicory greens,raw', 'radicchio, raw', 'radicchio', 'chicory leaf extract', '']
# ['', 'african oil palm fruit oil', 'palm oil (from fruit)', 'elaeis guineensis oil', 'palm oil (unhydrogenated)', 'african palm oil', 'elaeis guineensis (palm) oil', 'oil,palm', 'oil palm', 'elaeis guineensis fruit oil', 'oil, palm', '']
# ['', 'camphor oil, formosan ho-sho, leaves', 'cinnamomum camphora (camphor) leaf oil', 'camphor leaf volatile oil', 'camphor oil formosan ho-sho leaves', 'camphor laurel leaf oil', 'camphortree leaf oil', 'cinnamomum camphora leaf oil', 'camphor tree leaf oil', 'camphora camphora leaf oil', 'laurus camphora leaf oil', '']
# ['', 'zanthoxylum macrophyllum bark', "hercule's club (zanthoxylum clava-herculis) bark", 'pepperwood bark', 'hercules-club pricklyash bark', 'southern pricky ask bark', "hercules' club (zanthoxylum clava-herculis) bark", '']
# ['', 'influenza virus type a', 'influenza a virus whole', 'fluav', '']
# ['', 'influenza virus type b', 'influenzavirus b: influenza b virus whole', 'influenzavirus b: influenza b virus', 'influenza b virus whole', 'influenzavirus b influenza b virus whole', 'flubv', '']
# ['', 'influenza a virus a/california/7/2009 (h1n1) live(attenuated) antigen', 'influenza a virus a/california/7/2009(h1n1) live(attenuated) antigen', '']
# ['', 'adenovirus vaccine, live, oral, type 4', 'adenovirus type 4 vaccine live', 'human adenovirus e serotype 4 strain cl-68578', 'mastadenovirus human adenovirus b type 4 strain cl-68578', 'human adenovirus serotype 4 strain cl-68578', 'adenovirus type 4 strain cl-68578', 'human adenovirus serotype 4 vaccine strain cl-68578', '']
# ['', 'influenza a virus h1n1 live antigen, a', 'influenza a virus a/south dakota/6/2007(h1n1) live(attenuated) antigen', 'influenza a virus a/south dakota/6/2007 (h1n1) live(attenuated) antigen', '']
# ['', 'influenza a virus h3n2 live antigen, a', 'influenza a virus a/uruguay/716/2007(h3n2) live(attenuated) antigen', '']
# ['', 'insulin-like growth factor-2', 'insulin-like growth factor-ii', 'igf-2', 'igf-ii', 'cg-igf2', 'sh-polypeptide-31', 'rh-polypeptide-31', 'human insulin-like growth factor ii', 'human oligopeptide-24', 'insulin-like growth factor 2', 'insulin-like growth factor ii (human)', 'multiplication-stimulating activity iii-2', 'rh-oligopeptide-8', '']
# ['', 'dl-alpha-tocopheryl acetate', 'all-rac-alpha-tocopheryl acetate', 'all-rac-alfa-tocopheryl acetate', '']
# ['', 'pvp-k 30', 'plasdone k29-32', 'polyvinylpyrrolidone k30', 'polyvinylpyrrolidone k-29/32', 'plasdone k29/32', 'povidone k29/32', '1-vinylpyrrolidin-2-one homopolymer', 'povidone k29-32', 'polyvinylpyrrolidone k 30', 'pvp k-30', 'pvp k30', '']
# ['', 'zinc sulfate, unspecified hydrate', 'zinc sulfate, unspecified', '']
# ['', 'buergeria obovata bark', 'magnolia thurberi bark', 'michelia gracilis bark', 'kobushi magnolia bark', 'magnolia borealis bark', 'magnolia pseudokobus bark', 'magnolia praecocossima bark', 'talauma obovata bark', 'magnolia kobushii bark', 'yulania kobus bark', '']
# ['', 'kale, raw', 'brassica oleracea var. acephala low fiber cultivar group leaf', 'kale,raw', 'kale leaf', 'brassica oleracea var. viridis low fiber cultivar group leaf', 'brassica oleracea subsp. acephala low fiber cultivar group leaf', '']
# ['', 'sophorae flavescentis radix', 'sofora zheltovataya root', 'sophorae radix', 'shargal lider root', 'sophora root', 'sophora angustifolia root', 'bitter root', 'dogol-evs root', 'kushen', 'lightyellow sophora root', 'shrubby sophora root', 'sle-tres root', 'ku shen', '']
# ['', 'iron carbonate, precipitated', 'ferric carbonate, ferric hydroxide, ferrous hydroxide (variable mixture)', 'iron subcarbonate', 'iron oxide, brown', '']
# ['', 'plantago insularis seed', 'indian plantain seed', 'plantago brunnea seed', 'plantago fastigiata seed', 'psyllium seed, blonde', 'indian psyllium', 'blonde psyllium', 'plantaginis ovatae testa', 'ispaghula extract', 'ispaghula seed', 'plantago minima seed', 'ispaghula', 'ispaghul', 'blond psyllium', 'plantago gooddingii seed', 'plantaginis ovatae semen', 'ispaghula husk', '']
# ['', 'bioflavonoids', 'hesperidin complex', 'citrus bioflavonoid', 'bioflavonoids,citrus', '']
# ['', 'vamsha stem', 'arundarbor orientalis stem', 'gigantochloa maxima stem', 'nastus arundinaceus stem', 'arundarbor bambos stem', 'giant thorny bamboo stem', 'arundarbor agrestis stem', 'bambusa orientalis stem', 'bambos maxima stem', 'bambos arundo stem', 'arundo bamboo stem', 'bambusa arundinacea stem', 'arundo bambos stem', 'bambos arundinacea stem', 'arundo agrestis stem', 'thorny bamboo stem', 'spiny bamboo stem', 'arundarbor maxima stem', 'bambos agrestis stem', 'arundo arborea stem', 'indian thorny bamboo stem', 'bambusa agrestis stem', 'bambusa maxima stem', 'arundarbor arundinacea stem', 'bambusa bambos stem', '']
# ['', 'common anemarrhena rhizome', 'zhimu', 'knowing mother root', 'anemarrhena rhizome', 'anemarrhena asphodeloides root', 'zhi mu rhizome', 'anemarrhenae rhizoma', 'terauchia anemarrhenifolia rhizome', 'anemarrhenae rhizome', 'zhi mu', 'terauchia anemarrhenifolia root', 'anemarrhena asphodeloides rhizome', '']
# ['', 'hinoki leaf', 'hinoki cypress leaf', 'hinoki false cypress leaf', 'japanese cypress leaf', '']
# ['', 'hydrocotyle erecta leaf', 'thankuni leaf', 'sheep-rot leaf', 'asiatic pennywort leaf', 'spadeleaf leaf', 'hydrocotyle asiatica leaf', 'ji xue cao leaf', 'gotu kola leaf', 'mandukaparni leaf', '']
# ['', 'european elderberry flower', 'sambucus', 'sambucus nigra l. flower', 'sambucus nigra extract', 'european black elderberry flower', 'european black elder flower', 'elder flower', 'sambuci flos', '']
# ['', 'rosmarinus officinalis leaf oil', 'rosemary oil spain', 'oil of rosemary', 'rosmarinus officinalis (rosemary) leaf oil', 'rosemary oil egypt', 'rosemary volatile oil', 'rosemary oil morocco', 'rosemary oil france', 'rosemary oleoresin', 'rosemary leaf oil', '']
# ['', 'ginger root oil cochin', 'zingiber sichuanense oil', 'zingiber officinale oil', 'zingiber missionis oil', 'ginger volatile oil', 'amomum zingiber oil', 'zingiber cholmondeleyi oil', 'ginger root oil china', 'zingiber zingiber oil', 'amomum angustifolium oil', 'amomum zinziba oil', 'zingiber officinale (ginger) root oil', 'zingiber officinale rhizome oil', 'zingiber aromaticum oil', 'ginger root oil', '']
# ['', 'salicis cortex', 'salix', 'salix spp. bark', '']
# ['', 'curcuma domestica root oil', 'kua domestica root oil', 'stissera curcuma root oil', 'curcuma longa rhizome essential oil', 'amomum curcuma root oil', 'curcuma montana root oil', 'curcuma longa root oil', 'curcuma ochrorhiza root oil', 'curcuma longa (turmeric) root oil', 'curcuma brog root oil', 'curcuma soloensis root oil', 'curcuma euchroma root oil', 'stissera longa root oil', 'turmeric volatile oil', 'curcuma viridiflora root oil', '']
# ['', 'atractylodes chinensis rhizome', 'atractylis chinensis root', 'atractylodes erosodentata root', 'atractylodes lyrata root', 'atractylis ovata rhizome', 'atractylodes rhizome', 'atractylodes ovata root', 'atractylis pinnatifolia root', 'atractylodes lancea rhizome', 'atractylis separate root', 'atractylodis lanceae rhizoma', 'atractylis lyrata root', 'atractylodes chinensis root', 'cangzhu', 'atractylis ovata root', 'mao cang zhu rhizome', 'cang zhu', 'giraldia stapfii root', 'atractylis lancea root', 'acarna chinensis root', '']
# ['', 'bos taurus liver', 'bos bovis liver', 'cow liver', 'bos primigenius taurus liver', 'beef, liver', 'bovine liver', '']
# ['', 'camponotus pennsylvanicus whole', 'black carpenter ant', 'black carpenter ant whole', '']
# ['', 'vaccinia virus live antigen, b', 'vaccinia virus strain new york city board of health live (attenuated) antigen', '']
# ['', '2-methylbenzoic acid anilide', '2-methyl-n-phenylbenzamide', 'o-toluanilide', '2-methylbenzoanilide', '2-methylbenzanilide', 'o-methylbenzanilide', '']
# ['', 'diphtheria toxin-il-3 fusion protein targeting il-3 receptor', 'tagraxofusp-erzs', 'tagraxofusp', '']
# ['', 'turoctocog alfa pegol, n8-gp', 'turoctocog alfa pegol', 'n8-gp', '']
# ['', 'spirulina platensis whole', 'spirulina', 'oscillatoria platensis', 'spirulina (arthrospira platensis)', 'arthrospira platensis', 'spirulina platensis', 'arthrospira platensis whole', '']
# ['', 'ephedra stem (ephedra sinica)', 'ephedra ma-huang stem', 'ephedrae herba', 'ephedra stem', 'ephedrae herba (ephedra sinica)', 'ephedra sinica stem', 'ephedra (ephedra sinica)', 'mahunag (ephedra sinica)', 'chinese ephedra stem (ephedra sinica)', 'chinese jointfir stem (ephedra sinica)', 'ephedra herb (ephedra sinica)', 'ma huang (ephedra sinica)', 'cao ma huang', 'ephedra flava stem', '']
# ['', 'polygalae radix', 'polygala root', 'yuan zhi (polygala tenuifolia)', 'thinleaf milkwort root', 'thin-leaf polygala root', 'yuanzhi', 'polygala tenuifolia root', '']
# ['', 'agrostis repens top', 'agrostis sabulicola top', 'agrostis maeotica top', 'agrostis seminuda top', 'water bentgrass', 'vilfa compressa top', 'black bent', 'agrostis compressa top', 'cinna karataviensis top', 'agrostis tenella top', 'agrostis limosa top', 'agrostis dispar top', 'agrostis gigantea top extract', 'agrostis gigantea top', 'vilfa alba top', 'agrostis virletii top', 'agrostis graniticola top', 'agrostis diffusa top', 'agrostis dubia top', 'redtop', 'agrostis osakae top', 'vilfa gigantea top', 'agrostis praticola top', 'redtop grass', 'agrostis nigra top', 'vilfa dispar top', 'vilfa nigra top', '']
# ['', 'cayenne pepper seed', 'red pepper', 'cayenne pepper', 'hot pepper', 'cayenne pepper allergenic extract', 'capsicum annuum var. annuum seed', '']
# ['', 'dengue tetravalent vaccine (live, attenuated)', 'dengue tetravalent vaccine, live', 'dengue vaccine', '']
# ['', 'interleukin-2', 'il-2', '']
# adding interleukin-2
# ['', 'pik3ca', 'phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit alpha isoform', '']
# ['', 'cd40 ligand', 'recombinant cd40-ligand', '']
# ['', 'antigen lb39-aa', 'antigen sk29-aa', 'mart1', '']
# ['', 'vx15/2503', 'moab vx15/2503', '']

# %%
print(listPartialMatchSynonyms_compoundDB)
# Out:
# ['mecamylamine', 'mecamylamine', 'mecamylamine', 'olsalazine', 'olsalazine', 'olsalazine', 'olsalazine', 'gemifloxacin', 'gemifloxacin', 'gemifloxacin', 'gemifloxacin', 'bevirimat', 'tolrestat', 'tolrestat', 'tolrestat', 'tolrestat', 'tolrestat', 'melagatran', 'melagatran', 'ondansetron', 'ondansetron', 'ondansetron', 'ondansetron', 'ondansetron', 'ondansetron', 'ondansetron', 'iloprost', 'iloprost', 'iloprost', 'iloprost', 'iloprost', 'iloprost', 'linomide', 'semustine', 'semustine', 'semustine', 'semaxanib', 'semaxanib', 'orantinib', '4-methoxyphenol', 'ether', 'flomoxef', 'flomoxef', 'flomoxef', 'flomoxef', 'flomoxef', 'ddt', 'zofenoprilat', 'ether', 'ether', 'ether', 'ether', 'ether', 'saquinavir', 'saquinavir', 'saquinavir', 'saquinavir', 'saquinavir', 'saquinavir', 'nelfinavir', 'nelfinavir', 'nelfinavir', 'nelfinavir', 'ether', 'plerixafor', 'plerixafor', 'plerixafor', 'plerixafor', 'plerixafor', 'macimorelin', 'macimorelin', 'macimorelin', 'marimastat', 'marimastat', 'marimastat', 'marimastat', 'saquinavir', 'saquinavir', 'saquinavir', 'saquinavir', 'saquinavir', 'nadolol', 'nadolol', 'nadolol', 'nadolol', 'nadolol', 'nadolol', 'nadolol', 'nadolol', 'nadolol', 'thiotepa', 'thiotepa', 'thiotepa', 'thiotepa', 'thiotepa', 'thiotepa', 'thiotepa', 'thiotepa', 'thiotepa', 'l-alanosine', '1-octanol', 'lopinavir', 'lopinavir', 'lopinavir', 'lopinavir', 'canertinib', 'biapenem', 'biapenem', 'biapenem', '1-hexadecylpyridinium', 'oxametacin', 'oxametacin', 'oxametacin', 'valdecoxib', 'valdecoxib', 'valdecoxib', 'valdecoxib', 'valdecoxib', 'valdecoxib', 'tafenoquine', 'tafenoquine', 'tafenoquine', 'tafenoquine', 'ether', 'ether', 'ether', 'dabigatran', 'dabigatran', 'dabigatran', 'ether', 'licofelone', 'tropisetron', 'tropisetron', 'tropisetron', 'tropisetron', 'tropisetron', '4-iodophenol', 'sitamaquine', 'sitamaquine', 'sitamaquine', 'talampanel', 'talampanel', 'temazepam', 'temazepam', 'temazepam', 'temazepam', 'temazepam', 'temazepam', 'temazepam', 'temazepam', 'praziquantel', 'praziquantel', 'praziquantel', 'praziquantel', 'praziquantel', 'praziquantel', 'praziquantel', 'praziquantel', 'ether', 'ibuproxam', 'ibuproxam', 'ibuproxam', 'mivacurium', 'mivacurium', 'mivacurium', 'mivacurium', 'mivacurium', 'mivacurium', 'mivacurium', 'mivacurium', 'laquinimod', 'laquinimod', 'laquinimod', 'talabostat', 'talabostat', 'voreloxin', 'firocoxib', 'firocoxib', 'firocoxib', 'tasosartan', 'tasosartan', 'tasosartan', 'tasosartan', 'ether', 'prinomastat', 'prinomastat', 'prinomastat', 'ether', 'thiazolidinedione', 'cifenline', 'cifenline', 'narcobarbital', 'narcobarbital', 'sultiame', 'sultiame', 'sultiame', 'sultiame', 'sultiame', 'felbinac', 'felbinac', 'felbinac', 'felbinac', 'felbinac', 'felbinac', 'felbinac', 'ether', 'imidapril', 'imidapril', 'imidapril', 'imidapril', 'imidapril', 'pafuramidine', 'alovudine', 'alovudine', 'alovudine', 'alamifovir', 'alpha-acetyldigoxin', 'ether', 'cimicoxib', 'pentetrazol', 'pentetrazol', 'pentetrazol', 'pentetrazol', 'banoxantrone', 'banoxantrone', '1-hexadecylpyridinium', 'ganstigmine', 'ganstigmine', 'tandutinib', 'tandutinib', 'plevitrexed', 'plevitrexed', 'oxetacaine', 'oxetacaine', 'oxetacaine', 'oxetacaine', 'nelfinavir', 'nelfinavir', 'nelfinavir', 'nelfinavir', 'ramelteon', 'ramelteon', 'ramelteon', 'ramelteon', 'ramelteon', 'sulconazole', 'sulconazole', 'sulconazole', 'sulconazole', 'nitroferricyanide', 'propantheline', 'propantheline', 'propantheline', 'propantheline', 'propantheline', 'propantheline', 'propantheline', 'propantheline', '7-methylthiomethylpaclitaxel', 'ganirelix', 'ganirelix', 'ganirelix', 'ganirelix', 'ganirelix', 'ganirelix', 'ganirelix', 'ganirelix', 'ganirelix', 'degarelix', 'degarelix', 'degarelix', 'degarelix', 'abarelix', 'abarelix', 'abarelix', 'abarelix', 'procysteine', 'tramiprosate', 'tramiprosate', '(-)-oddc', 'frovatriptan', 'frovatriptan', 'frovatriptan', 'frovatriptan', 'frovatriptan', 'frovatriptan', 'biricodar', 'biricodar', 'diamthazole', 'chlordantoin', 'c ...

# %%
### find common based on inchikey between compounds DB and chembl  and write to csv 
import pandas as pd
dfdb2 =pd.read_csv('drugbank_drug.tsv',delimiter='\t',encoding='utf-8')


print(dfdb2.columns[52]) #44=calculated properties
listInchiKey_CompoundDB=[]
listInchiKeyOnly_CompoundDB=[]
listInchiKey_CompoundDB.append(dfdb2[dfdb2.columns[52]])
count=0

for item in dfdb2[dfdb2.columns[52]]:
    count = count+1
    item=str(item)
    listInchiKeyOnly_CompoundDB.append(item)
# Out:
# inchikey

# %%
print(len(listInchiKeyOnly_CompoundDB))
# Out:
# 13339

# %%
print(listInchiKeyOnly_CompoundDB[0])
# Out:
# nan

# %%
print(len(listInchiKeyOnly_CompoundDB))
dfChembl =pd.read_csv('chembl24inchikey.csv',delimiter=',',encoding='utf-8') #.chembl24inchikey
listChemblInchiKey=dfChembl.values.tolist()
print(len(listChemblInchiKey))
print(type(listChemblInchiKey))
#exact matches inchikey against compound db
listExactMatch_CompoundDB=[]
dictExactMatchInchi_compoundDB={}

for item in listChemblInchiKey:    
    if item[0] in listInchiKeyOnly_CompoundDB:        
        listExactMatch_CompoundDB.append(item[0])

print(len(listExactMatch_CompoundDB))

dfChemblInchi =pd.read_csv('chembl24inchikey_chemblids.csv',delimiter=',',encoding='utf-8') #.chembl24inchikey
#add to dict chembl id as value and synonyms as key
listChemblInchi= [str(x) for x in dfChemblInchi[dfChemblInchi.columns[0]]]
listChemblIds=[str(x) for x in dfChemblInchi[dfChemblInchi.columns[1]]]


dictChemblInchiIds=dict(zip(listChemblInchi,listChemblIds))

for key, value in dictChemblInchiIds.items() :
    print(key, value)
    break
# Out:
# 13339
# 1820035
# <class 'list'>
# 7195
# GHBOEFUAGSHXPO-XZOTUCIWSA-N CHEMBL1

# %%
for item in listInchiKeyOnly_CompoundDB:   
    if item in dictChemblInchiIds:
        dictExactMatchInchi_compoundDB[item]= dictChemblInchiIds[item] 
           

       
print(len(dictExactMatchInchi_compoundDB))
# Out:
# 7195

# %%
import csv

count=0
dataArr=dfdb2.values
for idx in range(len(dfdb2.values)):
    print("ss")
    break
          
#add chembl id also to csv synonym matches file 
with open("outmatches_inchikey_drugnames_chemblids.tsv",'w') as outcsv2: 
    writer2=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')  
    with open("outmatches_inchikey_chemblids.tsv",'w') as outcsv: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        for idd in range(len(dfdb2.values)):
            dbname=dataArr[idd][52]
            if dbname in dictExactMatchInchi_compoundDB.keys():
                for name, idval in dictExactMatchInchi_compoundDB.items():   
                    if dbname == name:                    
                        item=dataArr[idd]  
                        chemblid=idval
                        writer.writerow([ chemblid,item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                        writer2.writerow([chemblid, item[0], item[2]])
# Out:
# ss

# %%
### find common based on smiles between compounds DB and chembl  and write to csv 
import pandas as pd
dfdb2 =pd.read_csv('drugbank_drug.tsv',delimiter='\t',encoding='utf-8')
print(dfdb2.columns[44]) #44=calculated properties
listSMILES_CompoundDB=[]
listSMILES_CompoundDBOnly_CompoundDB=[]
listSMILES_CompoundDB.append(dfdb2[dfdb2.columns[44]])
count=0

for item in dfdb2[dfdb2.columns[44]]:
    count = count+1   
    if item != 'nan': 
        item=str(item)
        arr = item.split('||')
        arr2=[]
        for item in arr:
            if 'SMILES' in item:
                arr2.append(item)
                for item in arr2:
                    val = item.split('::')
                    listSMILES_CompoundDBOnly_CompoundDB.append(val[1]) 
                    
print(len(listSMILES_CompoundDBOnly_CompoundDB))  
dfChembl =pd.read_csv('chembl24smiles.csv',delimiter='\t',encoding='utf-8')
listChemblsmiles=dfChembl.values.tolist()
print(len(listChemblsmiles))
print(type(listChemblsmiles))
listExactMatchsmiles_CompoundDB=[]

dictExactMatchSmi_compoundDB={}
for item in listChemblsmiles:    
    if item[0] in listSMILES_CompoundDBOnly_CompoundDB:        
        listExactMatchsmiles_CompoundDB.append(item[0])

print(len(listExactMatchsmiles_CompoundDB))


dfChemblSMI =pd.read_csv('chembl24smiles_chemblids.csv',delimiter=',',encoding='utf-8') #.chembl24smiles
#add to dict chembl id as value and synonyms as key
listChemblSMI= [str(x) for x in dfChemblSMI[dfChemblSMI.columns[0]]]
listChemblIds=[str(x) for x in dfChemblSMI[dfChemblSMI.columns[1]]]


dictChemblSmiIds=dict(zip(listChemblSMI,listChemblIds))

for key, value in dictChemblSmiIds.items() :
    print(key, value)
    break
# Out:
# calculated_properties_kind_value_source
# 31046
# 1820035
# <class 'list'>
# 1272
# COc1ccc2[C@@H]3[C@H](COc2c1)C(C)(C)OC4=C3C(=O)C(=O)C5=C4OC(C)(C)[C@@H]6COc7cc(OC)ccc7[C@H]56 CHEMBL1

# %%
for item in listSMILES_CompoundDBOnly_CompoundDB:   
    if item in dictChemblSmiIds:
        dictExactMatchSmi_compoundDB[item]= dictChemblSmiIds[item] 
             
print(len(dictExactMatchSmi_compoundDB))
# Out:
# 1267

# %%
import csv

count=0
dataArr=dfdb2.values
for idx in range(len(dfdb2.values)):
    print("ss")
    break

#add chembl id also to csv smiles matches file 
with open("outmatches_smiles_drugnames_chemblids.tsv",'w') as outcsv2: 
    writer2=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')  
    with open("outmatches_smiles_chemblids.tsv",'w') as outcsv: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        
        for idd in range(len(dfdb2.values)):
            listIm=[]
            item_ = dataArr[idd][44]            
            if item_ != 'nan': 
                item_=str(item_)
                arr = item_.split('||')
                arr2=[]
                for item in arr:
                    if 'SMILES' in item:
                        arr2.append(item)
                        for item in arr2:
                            val = item.split('::')
                            listIm.append(val[1]) 
                    
            if listIm:
                if listIm[0] in dictExactMatchSmi_compoundDB.keys():
                    for smi, idval in dictExactMatchSmi_compoundDB.items():   
                        if smi == listIm[0]:                    
                            item=dataArr[idd]  
                            chemblid=idval
                            writer.writerow([ chemblid,item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                                item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                                 item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                                item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                               item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                            writer2.writerow([chemblid, item[0], item[2]])
# Out:
# ss

# %%
### find common based on chembl id  between compounds DB and chembl  and write to csv 
import pandas as pd
dfdb2 =pd.read_csv('drugbank_drug.tsv',delimiter='\t',encoding='utf-8')


print(dfdb2.columns[54]) #54=chembl id 
listChemblID_CompoundDB=[]
listChemblIDOnly_CompoundDB=[]


count=0

for item in dfdb2[dfdb2.columns[54]]:
    if str(item) != "nan":
        item=str(item)
        listChemblIDOnly_CompoundDB.append(item) 
            
print("len",len(listChemblIDOnly_CompoundDB))
print(len(listChemblIDOnly_CompoundDB))
dfChemblids =pd.read_csv('chembl24_chemblids.csv',delimiter='\t',encoding='utf-8')
listChemblids=dfChemblids.values.tolist()
print(len(listChemblids))
print(type(listChemblids))
#exact matches inchikey against compound db
listExactMatchChemblid_CompoundDB=[]
for item in listChemblids:    
    if item[0] in listChemblIDOnly_CompoundDB:        
        listExactMatchChemblid_CompoundDB.append(item[0])

print(len(listExactMatchChemblid_CompoundDB))
# Out:
# ChEMBL
# len 7550
# 7550
# 1828820
# <class 'list'>
# 7491

# %%
import csv

count=0
dataArr=dfdb2.values
for idx in range(len(dfdb2.values)):
    print("ss")
    break

            
with open("outmatches_chemblid.tsv",'w') as outcsv: 
    writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
    for idd in range(len(dfdb2.values)):
        if dataArr[idd][54] in listExactMatchChemblid_CompoundDB:
            item=dataArr[idd]
            
            writer.writerow([item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                            item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
            

with open("outmatches_chemblid_drugnames.tsv",'w') as outcsv: 
    writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
    for idd in range(len(dfdb2.values)):
        if dataArr[idd][54] in listExactMatchChemblid_CompoundDB:
            item=dataArr[idd]            
            writer.writerow([item[54], item[0],item[2]])
# Out:
# ss

# %%
#### not in use #####
#write consolidated non matches  to csv based smiles out csv , inchi out csv
listCompoundDBMatchedNames=[]
listCompoundDBMatchedIDs=[]

dfid =pd.read_csv('outmatches_chemblid_drugnames.csv', header=None, delimiter=";", encoding='utf-8')
listid=dfid.values

for item in listid:
    listCompoundDBMatchedIDs.append(item[0])
    listCompoundDBMatchedNames.append(item[1])
    
dfid1 =pd.read_csv('outmatches_names_drugnames.csv', header=None, delimiter=";", encoding='utf-8')
listid1=dfid1.values
print(listid1[0])
for item1 in listid1:
   

    listCompoundDBMatchedIDs.append(item1[0])
    listCompoundDBMatchedNames.append(item1[1])
    
dfid2 =pd.read_csv('outmatches_inchikey_drugnames.csv',header=None,  delimiter=";", encoding='utf-8')
listid2=dfid2.values

for item2 in listid2:
    listCompoundDBMatchedIDs.append(item2[0])
    listCompoundDBMatchedNames.append(item2[1])
         
dfid3 =pd.read_csv('outmatches_smiles_drugnames.csv',header=None,  delimiter=";", encoding='utf-8')
listid3=dfid3.values

for item3 in listid3:
    listCompoundDBMatchedIDs.append(item3[0])
    listCompoundDBMatchedNames.append(item3[1])
            
#outmatches_synonyms
dfid4 =pd.read_csv('outmatches_synonyms_drugnames.csv',header=None,  delimiter=";", encoding='utf-8')
listid4=dfid4.values

for item4 in listid4:
    listCompoundDBMatchedIDs.append(item4[0])
    listCompoundDBMatchedNames.append(item4[1])  
        
print(len(listCompoundDBMatchedIDs))

print(len(listCompoundDBMatchedNames))
#dfmatchInchiKeyDrugs =pd.read_csv('drugbank_salt.tsv',delimiter='\t',encoding='utf-8')

#two new lists for name and synonym
dfid5 =pd.read_csv('outmatches_synonyms_nonmatches_chembl_drugnames.csv',header=None,  delimiter=";", encoding='utf-8')
listid5=dfid5.values

for item5 in listid5:
    listCompoundDBMatchedIDs.append(item5[0])
    listCompoundDBMatchedNames.append(item5[1])
    
dfid6 =pd.read_csv('outmatches_names_nonmatches_chembl_drugnames.csv',header=None,  delimiter=";", encoding='utf-8')
listid6=dfid6.values

for item6 in listid6:
    listCompoundDBMatchedIDs.append(item6[0])
    listCompoundDBMatchedNames.append(item6[1])
    
#revised two list obtained after code corrections - check chembl synonym is as is present in name, synonym before going for
#substring with space
#two new lists for name and synonym
dfid7 =pd.read_csv('outmatches_synonyms_nonmatches_chembl_drugnames_2.csv',header=None,  delimiter=";", encoding='utf-8')
listid7=dfid7.values

for item7 in listid7:
    listCompoundDBMatchedIDs.append(item7[0])
    listCompoundDBMatchedNames.append(item7[1])

    
dfid9 =pd.read_csv('outmatches_names_nonmatches_chembl_drugnames_3.csv',header=None,  delimiter=";", encoding='utf-8')
listid9=dfid9.values

for item9 in listid9:
    listCompoundDBMatchedIDs.append(item9[0])
    listCompoundDBMatchedNames.append(item9[1])
       
    
dfid10 =pd.read_csv('outmatches_names_nonmatches_chembl_drugnames_3.csv',header=None,  delimiter=";", encoding='utf-8')
listid10=dfid10.values

for item10 in listid10:
    listCompoundDBMatchedIDs.append(item10[0])
    listCompoundDBMatchedNames.append(item10[1])
# Out:
# ['DB00001' 'Lepirudin']
# 30994
# 30994

# %%
#repeat write complete matches with chembl id to write to non matches list + later use for partial match findings
listCompoundDBMatchedNames=[]
listCompoundDBMatchedIDs=[]
listChemblMatchedIDs=[]


dfid =pd.read_csv('outmatches_chemblid_drugnames.tsv', header=None, delimiter="\t", encoding='utf-8')
listid=dfid.values

for item in listid:
    listChemblMatchedIDs.append(item[0])
    listCompoundDBMatchedIDs.append(item[1])
    listCompoundDBMatchedNames.append(item[2])
    
dfid1 =pd.read_csv('outmatches_names_drugnames_chemblids.tsv', header=None, delimiter="\t", encoding='utf-8')
listid1=dfid1.values
print(listid1[0])
for item1 in listid1: 
    listChemblMatchedIDs.append(item1[0])
    listCompoundDBMatchedIDs.append(item1[1])
    listCompoundDBMatchedNames.append(item1[2])
    
dfid2 =pd.read_csv('outmatches_inchikey_drugnames_chemblids.tsv',header=None,  delimiter="\t", encoding='utf-8')
listid2=dfid2.values

for item2 in listid2:
    listChemblMatchedIDs.append(item2[0])
    listCompoundDBMatchedIDs.append(item2[1])
    listCompoundDBMatchedNames.append(item2[2])
         
dfid3 =pd.read_csv('outmatches_smiles_drugnames_chemblids.tsv',header=None,  delimiter="\t", encoding='utf-8')
listid3=dfid3.values

for item3 in listid3:
    listChemblMatchedIDs.append(item3[0])    
    listCompoundDBMatchedIDs.append(item3[1])
    listCompoundDBMatchedNames.append(item3[2])
            
#outmatches_synonyms
dfid4 =pd.read_csv('outmatches_synonyms_drugnames_chemblids.tsv',header=None,  delimiter="\t", encoding='utf-8')
listid4=dfid4.values

for item4 in listid4:
    listChemblMatchedIDs.append(item4[0])    
    listCompoundDBMatchedIDs.append(item4[1])
    listCompoundDBMatchedNames.append(item4[2])  
        
print(len(listChemblMatchedIDs))

print(len(listCompoundDBMatchedNames))

print(len(listCompoundDBMatchedNames))
# Out:
# ['CHEMBL1201666' 'DB00001' 'Lepirudin']
# 34378
# 34378
# 34378

# %%
for i in listCompoundDBMatchedNames:
    if i.startswith('Lep'):
        print(i)
# Out:
# Lepirudin
# Lepirudin

# %%
#write non matches to csv (compared against list of exact matches of name, smiles, inchi,, syonyms, id)

import csv

count=0
dataArr=dfdb2.values
for idx in range(len(dfdb2.values)):
    print("ss")
    break

countM=0
countN=0


with open("exact_outnonmatches_dbid_dbnames.tsv",'w') as outcsv2:  
    writer2=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')

    with open("exact_outnonmatches_allfields.tsv",'w') as outcsv: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        for idd in range(len(dfdb2.values)):            
            if dataArr[idd][0] in listCompoundDBMatchedIDs :
                countM =countM+1
            elif dataArr[idd][2] in listCompoundDBMatchedNames:                 
                countN =countN+1
            else:    
                count=count+1
                item=dataArr[idd] 
                writer.writerow([item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                                  item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                            item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                writer2.writerow([item[0],item[2]])
          
                     
                     
                
print("match id",countM) 
                
print("match name",countN)  
                
print("no match",count)
# Out:
# ss
# match id 12045
# match name 0
# no match 1294

# %%
#data fusion part - find ony unique matches from all the individual matches (chembl id, name, synonym, inchi, smiles)
dictDBID_ChemblID={}

df_id =pd.read_csv('outmatches_chemblid_drugnames.tsv', header=None, delimiter="\t", encoding='utf-8')
listids=df_id.values

for item in listids:
    dictDBID_ChemblID[item[1]]=item[0]   

    
df_name =pd.read_csv('outmatches_names_drugnames_chemblids.tsv', header=None, delimiter="\t", encoding='utf-8')
listnames=df_name.values
for item1 in listnames: 
    dbid=item1[1]
    if dbid not in dictDBID_ChemblID.keys():
        dictDBID_ChemblID[item1[1]]=item1[0]   

df_inchiK =pd.read_csv('outmatches_inchikey_drugnames_chemblids.tsv', header=None, delimiter="\t", encoding='utf-8')
listInchiK=df_inchiK.values
for item2 in listInchiK: 
    dbid=item2[1]
    if dbid not in dictDBID_ChemblID.keys():
        dictDBID_ChemblID[item2[1]]=item2[0]      
    
         
df_smi =pd.read_csv('outmatches_smiles_drugnames_chemblids.tsv',header=None,  delimiter="\t", encoding='utf-8')
listSMI=df_smi.values

for item3 in listSMI:
    dbid=item3[1]
    if dbid not in dictDBID_ChemblID.keys():
        dictDBID_ChemblID[item3[1]]=item3[0]     
            
#outmatches_synonyms
df_synonyms =pd.read_csv('outmatches_synonyms_drugnames_chemblids.tsv',header=None,  delimiter="\t", encoding='utf-8')
listSynonyms=df_synonyms.values
for item4 in listSynonyms:
    dbid=item4[1]
    if dbid not in dictDBID_ChemblID.keys():
        dictDBID_ChemblID[item4[1]]=item4[0] 


print(len(dictDBID_ChemblID))
# Out:
# 12045

# %%
#data fusion write all unique matches to new csv - use this for cerating matched relations in neo4j
import csv

count=0
dataArr=dfdb2.values
print(len(dfdb2.values))
for idx in range(len(dfdb2.values)):
    print("ss")
    break

with open("exact_outallmatches_unique_chemblid_drugnames.tsv",'w') as outcsv: 
    writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
    for idd in range(len(dfdb2.values)):
        if dataArr[idd][0] in dictDBID_ChemblID.keys():
            item=dataArr[idd]
            cid=dictDBID_ChemblID[dataArr[idd][0]]
            count=count+1
            writer.writerow([cid,item[0],item[2]])       

print("count=",count)
# Out:
# 13339
# ss
# count= 12045

# %%
#find matches based on inchikey - drugbank salts and chembl and write to csv 
import pandas as pd
dfdbsalt =pd.read_csv('drugbank_salt.tsv',delimiter='\t',encoding='utf-8')


print(dfdbsalt.columns[3]) #44=calculated properties
listInchiKey_salt=[]
listInchiKeyOnly_salt=[]
dictExactMatchInchi_saltDB={}
listInchiKey_salt.append(dfdbsalt[dfdbsalt.columns[3]])
count=0

for item in dfdbsalt[dfdbsalt.columns[3]]:
    count = count+1
    item=str(item)
    listInchiKeyOnly_salt.append(item) 


dfChemblInchi =pd.read_csv('chembl24inchikey_chemblids.csv',delimiter=',',encoding='utf-8') 
#add to dict chembl id as value and synonyms as key
listChemblInchi= [str(x) for x in dfChemblInchi[dfChemblInchi.columns[0]]]
listChemblIds=[str(x) for x in dfChemblInchi[dfChemblInchi.columns[1]]]


dictChemblInchiIds=dict(zip(listChemblInchi,listChemblIds))

for item in listInchiKeyOnly_salt:   
    if item in dictChemblInchiIds:
        dictExactMatchInchi_saltDB[item]= dictChemblInchiIds[item] 
print(len(dictExactMatchInchi_saltDB))
# Out:
# inchikey
# 1427

# %%
#write drugbank salt inchi matches to csv
import csv

count=0
dataArrS=dfdbsalt.values
for idx in range(len(dfdbsalt.values)):
    print("ss")
    print(dataArrS[idx])
    break
    
#add chembl id also to csv matches file 
with open("outmatches_salt_inchikey_drugnames_chemblids.tsv",'w') as outcsv2: 
    writer=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')  
   
    for idd in range(len(dfdbsalt.values)):
        dbinchi=dataArrS[idd][3]
        if dbinchi in dictExactMatchInchi_saltDB.keys():
            count=count+1
            item=dataArrS[idd]  
            chemblid=dictExactMatchInchi_saltDB[dbinchi]
            writer.writerow([chemblid,item[0],item[1]])
print("inchi matches in salt",count)
# Out:
# ss
# ['DBSALT000105' 'Leuprolide acetate' '37JNS02E7V'
#  'RGLRXNKKBLIBQS-XNHQSDQCSA-N' '74381-53-6' nan nan]
# inchi matches in salt 1427

# %%
#find matches based on name - drugbank salts and chembl and write to csv 
import pandas as pd
dfdbsalt =pd.read_csv('drugbank_salt.tsv',delimiter='\t',encoding='utf-8')


listSaltNames_compoundDB=[]
listSaltExactMatchNames_compoundDB=[]
listChemblNames=[]
dictSaltExactMatchNames_compoundDB={}

#listNames_compoundDB.append(dfdb2[dfdb2.columns[2].lower()])
listSaltNames_compoundDB=[x.lower() for x in dfdbsalt[dfdbsalt.columns[1].lower()]]

print("total",len(dfdbsalt[dfdbsalt.columns[1]]))                    
print(len(listSaltNames_compoundDB))

dfChemblNames =pd.read_csv('chembl24prefnames_ids.csv',delimiter=',',encoding='utf-8') #chembl24prefnames.csv
print(dfChemblNames.shape)

#add to list only contains names
listChemblNames= [str(x).lower() for x in dfChemblNames[dfChemblNames.columns[0]]]

print(len(listChemblNames))

print(type(listChemblNames))

for item in listSaltNames_compoundDB:     
    if item in listChemblNames :
        listSaltExactMatchNames_compoundDB.append(item)
        
print(len(listSaltExactMatchNames_compoundDB))

#add to dict chembl id as value and name as key
listChemblNames= [str(x).lower() for x in dfChemblNames[dfChemblNames.columns[0]]]
listChemblIds=[str(x) for x in dfChemblNames[dfChemblNames.columns[1]]]
dictChemblNamesIds=dict(zip(listChemblNames,listChemblIds))

#consider checking names in drugbank salt to synonmys in chembl
dfChemblSynonyms =pd.read_csv('chembl24_synonyms_ids.csv',delimiter=',',encoding='utf-8')#chembl24_synonyms
listChemblSNames= [str(x).lower() for x in dfChemblSynonyms[dfChemblSynonyms.columns[0]]]
listChemblSIds=[str(x) for x in dfChemblSynonyms[dfChemblSynonyms.columns[1]]]
dictChemblSIds=dict(zip(listChemblSNames,listChemblSIds))
  

        
for item in listSaltNames_compoundDB:   
    if item in dictChemblNamesIds:
        dictSaltExactMatchNames_compoundDB[item]= dictChemblNamesIds[item]  
    if item in dictChemblSIds:
        dictSaltExactMatchNames_compoundDB[item]= dictChemblSIds[item] 
      
       
print(len(dictSaltExactMatchNames_compoundDB))
# Out:
# total 2236
# 2236
# (1828820, 2)
# 1828820
# <class 'list'>
# 1310
# 1399

# %%
#write drugbank salt name matches to csv
import csv

count=0
dataArrS=dfdbsalt.values
for idx in range(len(dfdbsalt.values)):
    print("ss")
    print(dataArrS[idx])
    break
    
#add chembl id also to csv matches file 
with open("outmatches_salt_names_drugnames_chemblids.tsv",'w') as outcsv2: 
    writer=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')  
   
    for idd in range(len(dfdbsalt.values)):
        dbname=str(dataArrS[idd][1]).lower()
        if dbname in dictSaltExactMatchNames_compoundDB.keys():
            count=count+1
            item=dataArrS[idd]  
            chemblid=dictSaltExactMatchNames_compoundDB[dbname]
            writer.writerow([chemblid,item[0],item[1]])
print("name matches in salt",count)
# Out:
# ss
# ['DBSALT000105' 'Leuprolide acetate' '37JNS02E7V'
#  'RGLRXNKKBLIBQS-XNHQSDQCSA-N' '74381-53-6' nan nan]
# name matches in salt 1399

# %%
#data fusion for drugbank salt - find unique out matches 
dictSaltDBID_ChemblID={}

dfsalt_inchi =pd.read_csv('outmatches_salt_inchikey_drugnames_chemblids.tsv', header=None, delimiter="\t", encoding='utf-8')
listSaltInchiids=dfsalt_inchi.values

for item in listSaltInchiids:
    dictSaltDBID_ChemblID[item[1]]=item[0]   

    
dfsalt_name =pd.read_csv('outmatches_salt_names_drugnames_chemblids.tsv', header=None, delimiter="\t", encoding='utf-8')
listSaltNames=dfsalt_name.values
for item1 in listSaltNames: 
    dbid=item1[1]
    if dbid not in dictSaltDBID_ChemblID.keys():
        dictSaltDBID_ChemblID[item1[1]]=item1[0] 
        
print("dict total unique matches in salt",len(dictSaltDBID_ChemblID))
# Out:
# dict total unique matches in salt 1676

# %%
#data fusion write all unique matches for salt to new csv - use this for creating matched relations in neo4j from salt_drugbank
import csv

count=0
dataArrS=dfdbsalt.values
print(len(dfdbsalt.values))
for idx in range(len(dfdbsalt.values)):
    print("ss")
    break

with open("exact_outallmatches_unique_salt_chemblid_drugnames.tsv",'w') as outcsv: 
    writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
    for idd in range(len(dfdbsalt.values)):
        if dataArrS[idd][0] in dictSaltDBID_ChemblID.keys():
            item=dataArrS[idd]
            cid=dictSaltDBID_ChemblID[dataArrS[idd][0]]
            count=count+1
            writer.writerow([cid,item[0],item[1]])       

print("count=",count)
# Out:
# 2236
# ss
# count= 1676

# %%
#### not in use #####
### find if partial match exists between overall exact non matches and chembl for name and synonmys 
import pandas as pd #outnonmatches_allfields
dfdbs = pd.read_csv('exact_outnonmatches_allfields.tsv', header=None, delimiter='\t',encoding='utf-8')

print(dfdbs.columns[2]) #2=name
print(dfdbs.columns[28]) 
print(len(dfdbs.columns))

listPartialMatchNames_dfdbs=[]
listPartialMatchSynonyms_dfdbs=[]
listSynonyms_dfdbs=[]
listChemblSynonyms=[]
listNames_dfdbs=[]
dictPartialMatchNames={}
dictPartialMatchSynonyms={}
listNames_dfdbs=[str(x).lower() for x in dfdbs[dfdbs.columns[2]]]

print("total",len(dfdbs[dfdbs.columns[2]]))                    
print(len(listNames_dfdbs))
print(listNames_dfdbs[0])

dfChemblSynonyms =pd.read_csv('chembl24_synonyms_ids.csv',delimiter=',',encoding='utf-8')
print(dfChemblSynonyms.shape)
#add to dict chembl id as value and synonyms as key
listChemblSNames= [str(x).lower() for x in dfChemblSynonyms[dfChemblSynonyms.columns[0]]]
listChemblSIds=[str(x) for x in dfChemblSynonyms[dfChemblSynonyms.columns[1]]]


dictChemblSIds=dict(zip(listChemblSNames,listChemblSIds))

for key, value in dictChemblSIds.items() :
    print(key, value)
    break  

        
for item in listNames_dfdbs:     
    for name, idval in dictChemblSIds.items(): 
        arrAll = name.split(' ')
        for i in arrAll:            
            if i in item :                
                dictPartialMatchNames[item]=idval

                

    
        
print(len(listPartialMatchNames_dfdbs))

#synonmys contains  formate |a||||aa||||bb||||b|
for x in dfdbs[dfdbs.columns[28]]:
    x=str(x)
    if '|' in x:
        xall = x.replace('||||','|')
        xarr = xall.split("|")
        for m in xarr:
            if m!= '':
                listSynonyms_dfdbs.append(m.lower())
    else:
        if x!= '':
            m=x
            listSynonyms_dfdbs.append(m.lower())

            
        
for item in listSynonyms_dfdbs:     
    for name, idval in dictChemblSIds.items(): 
        arrAll = name.split(' ')
        for i in arrAll:            
            if i in item :                
                dictPartialMatchSynonyms[item]=idval

                

        
print(len(dictPartialMatchSynonyms))
# Out:
# 2
# 28
# 55
# total 4994
# 4994
# sermorelin
# (155331, 2)
# bromoenol lactone CHEMBL1256018
# 0
# 5602

# %%
#### not in use #####
print(len(dictPartialMatchSynonyms))
print(len(dictPartialMatchNames))
for k,v in dictPartialMatchSynonyms.items():
    print(k)
# Out:
# ['nan', 'calcitonin, salmon', 'calcitonin (salmon synthetic)', 'salmon calcitonin', 'calc1_oncke', 'calcitonina salmón sintética', 'calcitonin salmon recombinant', 'calcitonin salmon', 'calcitonin-salmon', 'recombinant salmon calcitonin', 'immune globulin subcutaneous', 'igha2_human', 'human normal immunoglobulin', 'immune globulin intravenous', 'ivig', 'human igg', 'immunoglobulin g (human)', 'human immunoglobulin g', 'immune globulin (human)', 'intravenous immunoglobulin', 'immunoglobulin g, human', 'sh-polypeptide-46', 'recombinant human interferon alfa-2a', 'interferon alfa-2a, recombinant', 'interferon alpha-2a', 'interferon alfa-2a,recombinant', 'ifna2_human', 'interferon-alfa-2a', 'rifn-alpha-2a', 'interferon alfa-2a (recombinant)', 'interferon alfa-2a', 'recombinant human interferon-alfa-2a', 'coagulation factor viia', 'fa7_human', 'eptacog alfa', 'coagulation factor viia (recombinant)', 'rfviia', 'eptacog alfa (activated)', 'lipoprotein ospa antigen recombinant', 'ospa lipoprotein', 'ospa1_borbu', 'lipoprotein outer surface a borrelia burgdorferi antigen', 'drotrecogin alfa activated', 'blood coagulation factor xiv (human)', 'drotrecogin-alfa', 'recombinant human activated protein c (rh-apc)', 'proc_human', 'activated protein c', 'drotrecogin alfa (activated)', 'drotrecogin alfa, activated', 'drotrecogin alfa (activated), lyophilized', 'alpha-1-proteinase inhibitor human', 'alpha-1-proteinase inhibitor,human', 'alfa1 antitrypsin', 'alpha-1-antiproteinase', 'alpha1-proteinase inhibitor human', 'alfa-1-antitripsina', 'alpha-1-antitrypsin', 'alpha1-proteinase inhibitor (human)', 'alpha1-proteinase inhibitor', 'alpha 1-proteinase inhibitor (human)', 'api', 'a1at_human', 'alpha-1 proteinase inhibitor (human)', 'alpha-1 protease inhibitor', 'alpha 1-antitrypsin', 'alpha-1-proteinase inhibitor, human', 'alpha 1-proteinase inhibitor, human', 'alpha 1-proteinase inhibitor', 'alpha-1-proteinase inhibitor (human)', 'ovine digoxin immune fab', 'digoxin immune fab, ovine', 'digitalis antitoxin', 'digoxin-specific antibody fragments', 'incobotulinumtoxina', 'prabotulinumtoxin a', 'botulinum toxin a', 'evabotulinumtoxina', 'onabotulinumtoxina', 'bxa1_clobo', 'toxina botulínica a', 'btx-a', 'botulinum a neurotoxin', 'abobotulinumtoxina', 'toxine botulinique a', 'botulinum toxin type a', 'rabbit anti-human thymocyte globulin', 'antithymocyte immunoglobulin', 'anti-thymocyte globulin rabbit', 'lapine t-lymphocyte immune globulin', 'rabbit anti-human thymocyte globulin (ratg)', 'rabbit antithymocyte globulin', 'anti-t-lymphocyte immune globulin, rabbit', 'anti-human thymocyte immunoglobulin, rabbit', 'rabbit anti-human thymocyte immunoglobulin', 'rabbit anti-thymocyte immunoglobulin', 'ratg', 'rabbit atg', 'thymoglobulin', 'thymoglobuline', 'anti-thymocyte globulin (rabbit)', 'nonacog alfa', 'nonacog gamma', 'recombinant factor ix', 'factor ix (recombinant)', 'fa9_human', 'coagulation factor ix (recombinant)', 'coagulation factor ix recombinant human', 'ps', 'phosphatidyl-l-serine', 'ptd-l-ser', 'phosphatidylserine', 'dpnh', 'reduced nicotinamide adenine diphosphate', 'nicotinamide-adenine dinucleotide, reduced', '1,4-dihydronicotinamide adenine dinucleotide', 'reduced nicotinamide-adenine dinucleotide', 'nad reduced form', 'nicotinamide adenine dinucleotide (reduced)', 'nan', 'pentosane polysulfate', 'pentosanpolysulfat', 'pentosan sulfuric polyester', 'pentosano polisulfato', 'pentosani polysulfas', 'nan', '9-chloro-6alpha-fluoro-11beta,21-dihydroxy-16alpha-methyl-1,4-pregnadien-3,20-dione', '9-chloro-6alpha-fluoro-16alpha-methyl-1,4-pregnadiene-11beta,21-diol-3,20-dione', 'clocortolonum', 'clocortolone', 'clocortolon', 'clocortolona', 'codergocrine mesylate', 'ergoloid mesilates', 'dihydroergotoxine monomethanesulfonate', 'dihydroergotoxine mesylate', 'co-dergocrine mesilate', 'dihydroergotoxine methanesulfonate', 'co-dergocrine mesylate', 'ergoloid methanesulfonate', 'ergoloid mesylates', 'co-dergocrine methanesulfonate', 'ergoloid  ...
# []
# 73
# 163
# calcitonin-salmon
# incobotulinumtoxina
# evabotulinumtoxina
# onabotulinumtoxina
# abobotulinumtoxina
# clocortolone
# cefditoren
# tolevamer
# aluminium
# aluminum
# ginkgo
# liotrix
# ferrum
# zn
# nx1838
# dha-paclitaxel
# azapropazone
# apazone
# pancreozymin
# sestamibi
# fibrinogen
# nofetumomab
# air
# dextrose
# glucose
# alseroxylon
# rauwolfia
# sutilains
# cod
# salmon
# calciferol
# chlor
# omega-3
# phospholipids
# tocopherols
# soysterol
# tocophersolan
# tpgs
# ba
# ta
# ac
# 153sm
# triolein
# clobetasone
# creosote
# merbromin
# prajmalium
# methenolone
# aloe
# lu-177
# 177lu
# morrhuate
# phosphorous
# ginsenoside
# cellulose
# 99tc
# glycyrrhiza
# k
# acetate
# hydroxide
# phosphate
# carbonate
# sulfate
# p-32
# tetraborate
# cobalt
# lh
# olive
# senega
# interleukin-2
# d-ribose
# ribose
# hu14.18-il2

# %%
#### not in use #####
#partial matches based on synonyms between non matched and chembl in a separate csv
import csv

count=0
dataArr2=dfdbs.values
for idx in range(len(dfdbs.values)):
    print("ss")
    break
print(dfdbs.values[0][2])
            
with open("outmatches_partialnames_nonmatches_chembl.tsv",'w') as outcsv: 
    with open("outmatches_partialnames_nonmatches_chembl_drugnames.tsv",'w') as outcsv2: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        writer2=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')

        for idd in range(len(dfdbs.values)): 
            namedb=dfdbs.values[idd][2].lower()            
            if namedb in dictPartialMatchNames.keys():                       
                for n,val in dictPartialMatchNames.items():
                    if n == namedb:
                        item=dataArr2[idd]            
                        writer.writerow([val, item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                writer2.writerow([val, item[0], item[2]]) 
            
            
with open("outmatches_partialsynonyms_nonmatches_chembl.tsv",'w') as outcsv: 
    with open("outmatches_partialsynonyms_nonmatches_chembl_drugnames.tsv",'w') as outcsv2: 
        writer=csv.writer(outcsv,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')
        writer2=csv.writer(outcsv2,delimiter='\t',quotechar='|',quoting=csv.QUOTE_MINIMAL,lineterminator='\n')

        for idd in range(len(dfdbs.values)):            
            bExists=False
            synonyms=str(dfdbs.values[idd][28]).lower()  
            if '|' in synonyms:
                xall = synonyms.replace('||||','|')
                xarr = xall.split("|")
                
                print(xarr)
                for arr in xarr:                    
                    if arr!= '':
                        if 'ergoloid' in arr:
                            print("arr",arr)
                            print("listPartialMatchSynonyms2_dfdbs",listPartialMatchSynonyms2_dfdbs)
                        if str(arr) in dictPartialMatchSynonyms.keys():
                            print("adding",arr)
                            for n,val in dictPartialMatchSynonyms.items():
                                if n == str(arr):                         
                                    item=dataArr2[idd]            
                                    writer.writerow([val, item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                                    writer2.writerow([val, item[0], item[2]])
            else:
                if synonyms in dictPartialMatchSynonyms.keys(): 
                    arr=synonyms
                    for n,val in dictPartialMatchSynonyms.items():
                        if n == str(arr):                         
                            item=dataArr2[idd]            
                            writer.writerow([val, item[0],item[1],item[2],item[3],item[4], item[5],item[6],item[7],item[8],item[9],item[10],
                            item[11],item[12],item[13],item[14], item[15],item[16],item[17],item[18],item[19],item[20],
                             item[21],item[22],item[23],item[24], item[25],item[26],item[27],item[28],item[29],item[30],
                            item[31],item[32],item[33],item[34], item[35],item[36],item[37],item[38],item[39],item[40],
                           item[41],item[42],item[43],item[44], item[45],item[46],item[47],item[48],item[49],item[50],
                               item[51],item[52],item[53],item[54]])
                            writer2.writerow([val, item[0], item[2]])
# Out:
# ss
# Sermorelin
# ['', 'calcitonin, salmon', 'calcitonin (salmon synthetic)', 'salmon calcitonin', 'calc1_oncke', 'calcitonina salmón sintética', 'calcitonin salmon recombinant', 'calcitonin salmon', 'calcitonin-salmon', 'recombinant salmon calcitonin', '']
# adding calcitonin-salmon
# ['', 'immune globulin subcutaneous', 'igha2_human', 'human normal immunoglobulin', 'immune globulin intravenous', 'ivig', 'human igg', 'immunoglobulin g (human)', 'human immunoglobulin g', 'immune globulin (human)', 'intravenous immunoglobulin', 'immunoglobulin g, human', '']
# ['', 'sh-polypeptide-46', 'recombinant human interferon alfa-2a', 'interferon alfa-2a, recombinant', 'interferon alpha-2a', 'interferon alfa-2a,recombinant', 'ifna2_human', 'interferon-alfa-2a', 'rifn-alpha-2a', 'interferon alfa-2a (recombinant)', 'interferon alfa-2a', 'recombinant human interferon-alfa-2a', '']
# ['', 'coagulation factor viia', 'fa7_human', 'eptacog alfa', 'coagulation factor viia (recombinant)', 'rfviia', 'eptacog alfa (activated)', '']
# ['', 'lipoprotein ospa antigen recombinant', 'ospa lipoprotein', 'ospa1_borbu', 'lipoprotein outer surface a borrelia burgdorferi antigen', '']
# ['', 'drotrecogin alfa activated', 'blood coagulation factor xiv (human)', 'drotrecogin-alfa', 'recombinant human activated protein c (rh-apc)', 'proc_human', 'activated protein c', 'drotrecogin alfa (activated)', 'drotrecogin alfa, activated', 'drotrecogin alfa (activated), lyophilized', '']
# ['', 'alpha-1-proteinase inhibitor human', 'alpha-1-proteinase inhibitor,human', 'alfa1 antitrypsin', 'alpha-1-antiproteinase', 'alpha1-proteinase inhibitor human', 'alfa-1-antitripsina', 'alpha-1-antitrypsin', 'alpha1-proteinase inhibitor (human)', 'alpha1-proteinase inhibitor', 'alpha 1-proteinase inhibitor (human)', 'api', 'a1at_human', 'alpha-1 proteinase inhibitor (human)', 'alpha-1 protease inhibitor', 'alpha 1-antitrypsin', 'alpha-1-proteinase inhibitor, human', 'alpha 1-proteinase inhibitor, human', 'alpha 1-proteinase inhibitor', 'alpha-1-proteinase inhibitor (human)', '']
# ['', 'ovine digoxin immune fab', 'digoxin immune fab, ovine', 'digitalis antitoxin', 'digoxin-specific antibody fragments', '']
# ['', 'incobotulinumtoxina', 'prabotulinumtoxin a', 'botulinum toxin a', 'evabotulinumtoxina', 'onabotulinumtoxina', 'bxa1_clobo', 'toxina botulínica a', 'btx-a', 'botulinum a neurotoxin', 'abobotulinumtoxina', 'toxine botulinique a', 'botulinum toxin type a', '']
# adding incobotulinumtoxina
# adding evabotulinumtoxina
# adding onabotulinumtoxina
# adding abobotulinumtoxina
# ['', 'rabbit anti-human thymocyte globulin', 'antithymocyte immunoglobulin', 'anti-thymocyte globulin rabbit', 'lapine t-lymphocyte immune globulin', 'rabbit anti-human thymocyte globulin (ratg)', 'rabbit antithymocyte globulin', 'anti-t-lymphocyte immune globulin, rabbit', 'anti-human thymocyte immunoglobulin, rabbit', 'rabbit anti-human thymocyte immunoglobulin', 'rabbit anti-thymocyte immunoglobulin', 'ratg', 'rabbit atg', 'thymoglobulin', 'thymoglobuline', 'anti-thymocyte globulin (rabbit)', '']
# ['', 'nonacog alfa', 'nonacog gamma', 'recombinant factor ix', 'factor ix (recombinant)', 'fa9_human', 'coagulation factor ix (recombinant)', 'coagulation factor ix recombinant human', '']
# ['', 'ps', 'phosphatidyl-l-serine', 'ptd-l-ser', 'phosphatidylserine', '']
# ['', 'dpnh', 'reduced nicotinamide adenine diphosphate', 'nicotinamide-adenine dinucleotide, reduced', '1,4-dihydronicotinamide adenine dinucleotide', 'reduced nicotinamide-adenine dinucleotide', 'nad reduced form', 'nicotinamide adenine dinucleotide (reduced)', '']
# ['', 'pentosane polysulfate', 'pentosanpolysulfat', 'pentosan sulfuric polyester', 'pentosano polisulfato', 'pentosani polysulfas', '']
# ['', '9-chloro-6alpha-fluoro-11beta,21-dihydroxy-16alpha-methyl-1,4-pregnadien-3,20-dione', '9-chloro-6alpha-fluoro-16alpha-methyl-1,4-pregnadiene-11beta,21-diol-3,20-dione', 'clocortolonum', 'clocortolone', 'clocortolon', 'clocortolona', '']
# adding clocortolone
# ['', 'codergocrine mesylate', 'ergoloid mesilates', 'dihydroergotoxine monomethanesulfonate', 'dihydroergotoxine mesylate', 'co-dergocrine mesilate', 'dihydroergotoxine methanesulfonate', 'co-dergocrine mesylate', 'ergoloid methanesulfonate', 'ergoloid mesylates', 'co-dergocrine methanesulfonate', 'ergoloid methanesulfonates', 'dihydroergotoxine mesilate', 'codergocrine methanesulfonate', 'codergocrine mesilate', 'dihydrogenated ergot alkaloids', 'dihydroergotoxine methanesulfonates', 'hydrogenated ergot alkaloids', '']
# arr ergoloid mesilates
# listPartialMatchSynonyms2_dfdbs ['rauwolfia', 'calciferol', 'calciferol', 'calciferol', 'iodinated (131i) human serum albumin', 'interleukin-2', 'alseroxylon', 'alseroxylon', 'alseroxylon', 'acriflavine hydrochloride', 'acriflavine hydrochloride', 'technetium (99mtc) tilmanocept', 'air', 'air, compressed', 'lyapolate sodium', 'lyapolate sodium', 'rauwolfia', 'rauwolfia', 'rauwolfia serpentina', 'rauwolfia serpentina', 'tocopheryl acetate', 'tocopherol acetate']
# arr ergoloid methanesulfonate
# listPartialMatchSynonyms2_dfdbs ['rauwolfia', 'calciferol', 'calciferol', 'calciferol', 'iodinated (131i) human serum albumin', 'interleukin-2', 'alseroxylon', 'alseroxylon', 'alseroxylon', 'acriflavine hydrochloride', 'acriflavine hydrochloride', 'technetium (99mtc) tilmanocept', 'air', 'air, compressed', 'lyapolate sodium', 'lyapolate sodium', 'rauwolfia', 'rauwolfia', 'rauwolfia serpentina', 'rauwolfia serpentina', 'tocopheryl acetate', 'tocopherol acetate']
# arr ergoloid mesylates
# listPartialMatchSynonyms2_dfdbs ['rauwolfia', 'calciferol', 'calciferol', 'calciferol', 'iodinated (131i) human serum albumin', 'interleukin-2', 'alseroxylon', 'alseroxylon', 'alseroxylon', 'acriflavine hydrochloride', 'acriflavine hydrochloride', 'technetium (99mtc) tilmanocept', 'air', 'air, compressed', 'lyapolate sodium', 'lyapolate sodium', 'rauwolfia', 'rauwolfia', 'rauwolfia serpentina', 'rauwolfia serpentina', 'tocopheryl acetate', 'tocopherol acetate']
# arr ergoloid methanesulfonates
# listPartialMatchSynonyms2_dfdbs ['rauwolfia', 'calciferol', 'calciferol', 'calciferol', 'iodinated (131i) human serum albumin', 'interleukin-2', 'alseroxylon', 'alseroxylon', 'alseroxylon', 'acriflavine hydrochloride', 'acriflavine hydrochloride', 'technetium (99mtc) tilmanocept', 'air', 'air, compressed', 'lyapolate sodium', 'lyapolate sodium', 'rauwolfia', 'rauwolfia', 'rauwolfia serpentina', 'rauwolfia serpentina', 'tocopheryl acetate', 'tocopherol acetate']
# ['', 'cefditoren', 'cefditoreno', '']
# adding cefditoren
# ['', 'polystyrenesulfonic acid', 'polystyrene sulfonic acid', 'poly(styrene-4-sulfonic acid)', 'tolevamer', 'polystyrene sulfonate', '']
# adding tolevamer
# ['', 'potassium ion', 'potassium(1+) ion', 'potassium(1+)', 'potassium(i) cation', 'potassium (ion)', '']
# ['', 'ephedra root (ephedra sinica)', 'ephedra', 'ma huang gen (ephedra sinica)', 'ephedra sinica root', 'mahuanggen (ephedra sinica)', 'hemp yellow root', 'chinese jointfir', 'cao ma huang root', 'ephedra ma-huang root', 'chinese ephedra root (ephedra sinica)', 'ephedrae radix', '']
# ['', 'aluminum metal', 'aluminium', 'aluminum', 'aluminium atom', 'al', 'aluminio', 'metallic aluminum', 'aluminium metallicum', 'aluminum powder', '']
# adding aluminium
# adding aluminum
# ['', 'magnesium, ion(mg2+)', 'magnesium ion', '']
# ['', 'ginkgo leaf', 'ginkgo biloba leaf dry extract', 'common ginkgo leaf', 'maidenhair tree leaf', 'salisburia biloba leaf', 'ginkgo biloba leaf', 'salisburia macrophylla leaf', 'ginkgo', 'salisburia ginkgo leaf', 'tanakan', 'ginkgo biloba extract', 'maidenhair extract', 'salisburia adiantifolia leaf', 'ginkgo macrophylla leaf', 'pterophyllus salisburiensis leaf', 'ginkgo extract', 'yinxingye', 'ginkgo folium', 'ginkgo biloba leaf tincture', '']
# adding ginkgo
# ['', 'hong shen root', 'red ginseng', 'ginseng, asian', 'panax ginseng root extract', 'aralia ginseng root', 'ninjin root', 'ren shen root', 'asian ginseng root', 'panax verus root', 'korean ginseng root', 'panax ginseng root', 'true ginseng root', 'panax ginseng', 'chinese ginseng root', 'ginseng extract', 'ren shen', 'ginseng (panax ginseng)', 'insam root', 'panax schinseng root', 'korean ginseng', 'ren seng root', '']
# ['', 'delta,4-estrene-3,17-dione', 'delta4-estrene-3,17-dione', '']
# ['', '17beta-hydroxy-5alpha-androst-1-en-3-one', '1-testo', 'delta1-dihydrotestosterone', '1-t', 'androstendolone', '']
# ['', '4-hydroxy-19-nortestosterone', '4-hydroxy nandrolone', '']
# ['', 'alphamethylacetylfentanyl', 'acetyl-alpha-methylfentanyl', '']
# ['', '17α-methyl-4-hydroxynandrolone', '4-hydroxy-19-normethyltestosterone', '']
# ['', '3-mf', 'mefentanyl', '']
# ['', '17beta-hydroxy-17alpha-methyl-5alpha-androst-1-ene-3-one', '17alpha-methyl-17beta-hydroxy-5alpha-androst-1-en-3-one', '17alpha-methyl-17beta-hydroxy-delta1-5alpha-androsten-3-one', '(5α,17β)-17-hydroxy-17-methylandrost-1-en-3-one', '(+)-methyl-1-testosterone', '']
# ['', 'attapulgite,activated', 'activated attapulgite', 'aluminium magnesium silicate (attapulgite)', 'attapulgite (activated)', 'attapulgite, activated', 'attapulgus clay', '']
# ['', 'liotrix (t4;t3)', 'liotrix', '']
# adding liotrix
# ['', 'ferrum metallicum', 'iron, carbonyl', 'iron powder', 'iron, electrolytic', 'iron, reduced', 'hierro', 'electrolytic iron', 'fer', 'fe', 'reduced iron', 'eisen', 'iron, elemental', 'ferrum', 'carbonyl iron', '']
# adding ferrum
# ['', 'zincum metallicum', 'zn', 'zinc, chelated', 'zinc, elemental', '']
# adding zn
# ['', '5-o-phosphono-α-d-ribofuranosyl diphosphate', '5-phosphoribosyl diphosphate', '5-phosphoribosyl 1-pyrophosphate', 'prib-pp', 'phosphoribosylpyrophosphate', 'α-d-ribofuranose 5-(dihydrogen phosphate) 1-(trihydrogen diphosphate)', 'phosphoribosyl pyrophosphate', 'prpp', '5-phospho-alpha-d-ribose 1-diphosphate', '']
# ['', 'methionamine', 'methionin', 'n-ac-met', 'nα-acetyl-l-methionine', 'thiomedon', 'l-(n-acetyl)methionine', 'acmet', '(2s)-2-acetamido-4-(methylsulfanyl)butanoic acid', 'acetylmethionine', 'acetyl-l-methionine', 'n-acetyl-l-methionine', '']
# ['', 'p-hydroxybenzoyl-coa', 'p-hydroxybenzoyl-coenzyme a', '4-hydroxybenzoyl-coa', '4-hydroxybenzoyl-coenzyme a', '4-hydroxybenzoyl coenzyme a', '']
# ['', 'β-mannobiose', '4-o-β-d-mannopyranosyl-β-d-mannopyranose', '']
# ['', '2-phospho-d-glycerate', 'd-glycerate 2-phosphate', '']
# ['', 'w-molybdopterin cofactor', 'tungstopterin', '']
# ['', 'dithiane diol', 'd-4,5-dihydroxy-1,2-dithiane', '']
# ['', 'l-serine, acetate (ester)', 'o3-acetyl-l-serine', '']
# ['', 'isopropyl β-d-thiogalactoside', 'isopropyl β-d-1-thiogalactopyranoside', 'isopropyl β-d-thiogalactopyranoside', 'isopropyl-β-d-thiogalactopyranoside', 'isopropyl thiogalactoside', 'isopropyl-β-d-thiogalactoside', 'iptg', '']
# ['', "n,n'-((((3alpha,5beta,12alpha)-3,12-dihydroxy-24-oxocholan-24-yl)imino)di-3,1-propandiyl)bis-d-gluconamide", 'deoxy-bigchap', "d-gluconamide, n,n'-((((3alpha,5beta,12alpha)-3,12-dihydroxy-24-oxocholan-24-yl)imino)di-3,1-propanediyl)bis-", 'n,n-bis(3-(d-gluconamido)propyl)deoxycholamide', '']
# ['', 'd-glucose, anhydrous', 'aldehydo-d-glucose', 'd(+)-glucose', 'dextrose anhydrous', 'd-glucose in linear form', 'anhydrous dextrose', 'glucose, anhydrous', 'glucose anhydrous', 'dextrose, anhydrous', '']
# ['', '(6s)-tetrahydrofolate', '(6s)-tetrahydrofolic acid', '(6s)-thfa', '(6s)-5,6,7,8-tetrahydropteroylglutamate', '(6s)-h4folate', '']
# ['', '5-o-phosphono-d-ribose', 'd-ribose 5-phosphate', 'aldehydo-d-ribose 5-phosphate', '']
# ['', '2-(dimethylamino)acetic acid', '(dimethylamino)acetic acid', 'n-methylsarcosine', 'n,n-dimethylaminoacetic acid', 'dimethylglycine', '']
# ['', '(3β)-cholest-5-en-3-ol, (z,z)-9,12-octadecadienoate', '18:2 cholesteryl ester', '(3β)-cholest-5-en-3-ol, (9z,12z)-9,12-octadecadienoate', 'ce(18:2(9z,12z))', 'cholesteryl (9z,12z-octadecadienoate)', 'cholest-5-en-3β-yl (z,z)-octadeca-9,12-dienoate', 'ce(18:2)', '(z,z)-(3beta)-cholest-5-en-3-ol 9,12-octadecadienoate', '']
# ['', '2-fluoro-2-deoxy-beta-d-galactopyranose', '2-deoxy-2-fluoro-beta-d-galactose', '']
# ['', 'alpha-1,4-tetraglucose', 'amylotetraose', '']
# ['', 'beta-galactose-6-phosphate', '6-o-phosphono-β-d-galactopyranose', '']
# ['', 'phosphorofluoridate', 'fluorophosphate', 'fluoridophosphate', '']
# ['', 'neopterin d-threo-form', 'monapterin', 'd-threo-monapterin', 'd-monapterin', '']
# ['', 'caprylic acid, cetyl ester', 'hexadecyl n-octanoate', 'hexadecyl caprylate', 'cetyl octanoate', 'cetyl caprylate', '']
# ['', 'mafp', 'methyl arachidonylfluorophosphonate', 'methoxy arachidonyl fluorophosphonate', '']
# ['', 'deoxyamidinoproclavaminate', 'deoxyguanidinoproclavaminate', '']
# ['', 'n-acetyl-l-α-alanine', 'l-n-acetylalanine', 'acetylalanine', 'n-acetyl-s-alanine', 'ac-ala-oh', '(s)-2-(acetylamino)propanoic acid', '2-acetamidopropionic acid', 'n-acetyl-l-alanine', 's-(-)-n-acetylalanine', '']
# ['', 'triose', 'd-(+)-glyceraldehyde', 'd-glycerose', 'd-2,3-dihydroxypropionaldehyde', 'd-2,3-dihydroxypropanal', 'd-aldotriose', '']
# ['', 'sorbitol-6-phosphate', 'sorbitol 6-phosphate', 'd-sorbitol-6-phosphate', 'd-sorbitol 6-phosphate', 'd-glucitol, 6-(dihydrogen phosphate)', '']
# ['', 'alpha-abequopyranose', 'α-abequopyranose', '3,6-dideoxy-α-d-xylo-hexopyranose', '']
# ['', 'xylitol 5-p', 'xylitol 5-phosphate', '']
# ['', '7-(α-d-glucopyranosyloxy)-4-methyl-2h-1-benzopyran-2-one', '4-methylumbelliferyl a-d-glucopyranoside', '7-(alpha-d-glucopyranosyloxy)-4-methyl-2h-1-benzopyran-2-one', '4-methylumbelliferyl α-d-glucoside', '']
# ['', 'vitamin b 12 factor iiim', '5-methoxybenzimidazole vitamin b12', '5-methoxybenzimidazolylcobalamin', 'cyano-5-methoxybenzimidazolylcobamide', '']
# ['', '2-(ethylmercuri-thio)-benzoic acid', '2-(ethylmercuriothio)benzoic acid', '[(o-carboxyphenyl)thio]ethylmercury', '']
# ['', 'galactobiose', 'β-d-galactopyranosyl-(1→4)-β-d-galactopyranose', '4-o-β-d-galactopyranosyl-β-d-galactopyranose', 'β-d-galp-(1→4)-β-d-galp', '']
# ['', 'propionyl-coa', 'propionyl-coenzyme a', 'propanoyl-coenzyme a', 'propionyl coenzyme a', 's-propanoyl-coa', 's-propionylcoenzyme a', 's-propionyl-coenzym-a', 's-propanoyl-coenzyme a', '']
# ['', '(+)-trans-limonene oxide', '(4r)-limonene 1alpha,2alpha-epoxide', 'd-limonene 1,2-epoxide', '1α,2α-epoxy-4βh-p-menth-8-ene', '(1s,4r,6r)-4-isopropenyl-1-methyl-7-oxabicyclo[4.1.0]heptane', '']
# ['', 'l-iduronic acid', 'α-l-iduronic acid', '']
# ['', 's-acetoacetyl-coenzyme a', 'acetoacetyl-coenzyme a', 'acetoacetyl coenzyme a', 's-acetoacetyl-coenzym a', 's-acetoacetyl-coa', '3-acetoacetyl-coa', '']
# ['', '2-[(2-oxopropyl)sulfanyl]ethanesulfonic acid', '2-ketopropyl-com', '2-(2-oxopropylthio)ethanesulfonate', '']
# ['', 'l-vinylglycine', '(2s)-2-amino-3-butenoic acid', '']
# ['', '6-deoxy-beta-l-galactopyranose', 'beta-l-fucopyranose', '']
# ['', '3-deoxy-arabino-hexonic acid', 'd-2-keto-3-deoxygluconate', '']
# ['', 'ches', '2-(cyclohexylamino)ethanesulfonic acid', '']
# ['', "guanosine 3'-phosphate", 'guanylic acid', "3'-guanylic acid", "guanosine-3'-monophosphate", "3'-gmp", '']
# ['', 'hexaamminecobalt(3+)', 'cobalt hexammine(iii)', '']
# ['', 's-arsono-l-cysteine', 's-arsonocysteine', '']
# ['', 'l-tyrosine amide', 'tyrosinamide', 'tyrosine amide', '(2s)-2-amino-3-(4-hydroxyphenyl)propanamide', '']
# ['', 'cysteine sulphoxide', 'l-cysteine s-oxide', 'cysteine sulfoxide', 's-oxo-l-cysteine', 's-oxocysteine', 'cysteine s-oxide', 'l-cysteine sulphoxide', '3-(oxidosulfanyl)-l-alanine', 'l-cysteine sulfoxide', '']
# ['', '3,6,9,12,15,18-hexaoxaeicosane-1,20-diol', 'heptaethylene glycol, peg330', '']
# ['', "1,1'2,2'-tetrastearoyl cardiolipin", 'tetra-dodecanoyl cardiolipin', "1,1'2,2'-tetra-dodecanoylcardiolipin", "1,1'2,2'-tetrastearoylcardiolipin", 'tetra-dodecanoylcardiolipin', "1,1'2,2'-tetra-dodecanoyl cardiolipin", 'tetrastearoylcardiolipin', '']
# ['', 'n-benzyl-3-(α-d-galactopyranosyloxy)benzamide', 'bapg', '']
# ['', 'zeaxanthin diepoxide', 'trans-violaxanthin', 'all-trans-violaxanthin', '']
# ['', 'α-d-galacturonic acid', 'alpha-d-galactopyranuronic acid', 'α-d-galactopyranuronic acid', '']
# ['', 'α-kdop', 'α-2-keto-3-deoxyoctulosonic acid pyranose', 'kdo', '3-deoxy-d-manno-oct-2-ulosonic acid', 'α-kdo', '']
# ['', 'l-m-tyr', 'l-mtyr', '3-hydroxy-l-phenylalanine', 'meta-tyrosine', '3-(m-hydroxyphenyl)alanine', 'm-tyrosine', 'l-m-tyrosine', 'm-l-tyrosine', '3-hydroxyphenylalanine', '']
# ['', 'tn antigen saccharide', 'n-acetyl-α-d-galactosamine', 'α-galpnac', 'galnac-α', 'tn antigen saccharide component', 'n-acetyl-alpha-d-galactosamine', 'tn saccharide', 'n-acetyl-2-deoxy-2-amino-galactose', 'tn saccharide component', 'α-galnac', '']
# ['', '4-thio-β-d-glucopyranose', '4-deoxy-4-thio-beta-d-glucopyranose', '']
# ['', '2,3-di-o-phytanyl-sn-glycerol', 'archaeol', '2,3-diphytanyl-sn-glycerol', '']
# ['', 'β-d-galactopyranuronic acid', 'β-d-galacturonic acid', '']
# ['', 'p-iodophenylalanine', 'p-iodo-l-phenylalanine', '4-iodophenylalanine', '']
# ['', 'α-d-glcnac', '2-(acetylamino)-2-deoxy-a-d-glucopyranose', 'n-acetyl-α-d-glucosamine', '2-(acetylamino)-2-deoxy-α-d-glucopyranose', 'α-glcnac', '']
# ['', 'd-epifucose', 'α-d-quinovopyranose', 'd-chinovose', 'd-quinovose', 'quinovose', 'd-glucomethylose', 'isorhodeose', 'isorhamnose', '']
# ['', 'l-2-hydroxypropionaldehyde', '(2s)-2-hydroxypropanal', 'l-lactaldehyde', '(s)-lactaldehyde', '']
# ['', 'azo-dye hapten', 'rr6 azo-dye hapten', '']
# ['', 'factor f420', 'n-{n-[o-(7,8-didemethyl-8-hydroxy-5-deazariboflavin phospho)-(s)-lactyl]-γ-l-glutamyl}-l-glutamate', 'f420', 'coenzyme γ-f420-2', '']
# ['', 'dodecylsulfuric acid', 'lauryl sulphate', 'lauryl sulfuric acid', 'sulfuric acid, monododecyl ester', 'monododecyl hydrogen sulfate', 'dodecyl hydrogen sulfate', 'n-dodecyl sulfate', 'lauryl sulfate', '']
# ['', 'α-tyv', '3,6-dideoxy-α-d-arabino-hexopyranose', 'α-tyvelopyranose', '']
# ['', 'β-d-galactosyl-(1→4)-β-d-galactosyl-(1→4)-β-d-galactose', 'beta-1,4-galactotrioside', 'β-d-gal-(1→4)-β-d-gal-(1→4)-β-d-gal', 'β-d-galp-(1→4)-β-d-galp-(1→4)-β-d-galp', '']
# ['', 'd-4-hydroxyphenylglycine', 'd-(-)-p-hydroxyphenylglycine', '(r)-(4-hydroxyphenyl)glycine', '(r)-ethyl 2-amino-2-(4-hydroxyphenyl)acetate', 'p-hydroxy-(r)-phenylglycine', 'd-n-(4-hydroxyphenyl)glycine', 'd-(-)-2-(p-hydroxyphenyl)glycine', 'd-(-)-amino(4-hydroxyphenyl)acetic acid', '(r)-alpha-amino-4-hydroxybenzeneacetic acid', 'd-(-)-4-hydroxyphenylglycine', 'd-p-hydroxyphenylglycine', 'd-2-amino-2-(p-hydroxyphenyl)acetic acid', '4-hydroxy-d-phenylglycine', '(r)-2-(4-hydroxyphenyl)glycine', 'p-hydroxy-d-phenylglycine', '']
# ['', 'd-methyl aspartic acid', '3-methyl-beta-d-aspartic acid', '']
# ['', '6-hydroxyphenylalanine-3,4-dione', '(s)-α-amino-4-hydroxy-3,6-dioxo-1,4-cyclohexadiene-1-propanoic acid', 'topaquinone', 'l-topaquinone', 'topa quinone', '']
# ['', 'riboflavin lumichrome', '7,8-dimethylbenzo[g]pteridine-2,4(1h,3h)-dione', '7,8-dimethylalloxazine', 'lumichrome', '']
# ['', 's-1,2-propanediol', '(s)-propylene glycol', '(s)-propane-1,2-diol', '(s)-1,2-propanediol', '']
# ['', 'diazene, methyl- (9ci)', 'methyldiimide', '']
# ['', '(r)-dimethylketol', '(r)-3-hydroxy-2-butanone', '(r)-3-hydroxybutan-2-one', '(r)-2-acetoin', '']
# ['', 'diureidoacetate', 'bis[(aminocarbonyl)amino]acetate', 'diureido-acetate', '']
# ['', '(s)-(+)-2-amino-3-methyl-1-butanol', '(2s)-2-amino-3-methylbutan-1-ol', '']
# ['', 'dihydrobiopterin', 'quinonoid dihydrobiopterin', 'l-erythro-q-dihydrobiopterin', 'q-bh2', '']
# ['', 'aspartyl adenylate', 'succinyl amp', '']
# ['', 'd-2-aminohexanoic acid', 'd-(−)-norleucine', '']
# ['', 'tetrafluoroaluminate(1−)', 'tetrafluoroaluminate anion', '']
# ['', '1β,4β-bornane', 'bornylane', 'bornane', '(1s,4s)-1,7,7-trimethylbicyclo[2.2.1]heptane', '']
# ['', 's-(hydrogen malonyl)coenzyme a', 'malonyl coenzyme a', 'coenzyme a, s-(hydrogen propanedioate)', '']
# ['', 'alpha-aminocinnamate', '2,3-didehydrophenylalanine', '']
# ['', 'c24:1 sulfatide', '1-(3-o-sulfo-beta-d-galactosyl)-n-[(15z)-tetracos-15-enoyl]sphingosine', '']
# ['', 'cymal(r)-5', '5-cyclohexyl-1-pentyl-beta-d-maltoside', 'cymal-5', '']
# ['', 'dns-lysine', 'n(epsilon)-dansyl-l-lysine', '']
# ['', '2-methyl-2-butenedioic acid', 'citraconate', '(z)-2-methyl-2-butenedioic acid', '2-methylmaleic acid', 'methylmaleic acid', 'α-methylmaleic acid', 'citraconsäure', 'cis-methylbutenedioic acid', 'cis-2-methylbutenedioic acid', 'methyl-maleinsäure', '']
# ['', '2-hydroxytetracosanoyl sulfatide', '2-hydroxytetracosanoylgalactosylceramide sulfate', '']
# ['', '5-n-undecyl-6-hydroxy-4,7-dioxobenzothiazole', 'uhdbt', '6-hydroxy-5-undecyl-4,7-benzothiazoledione', '6-hydroxy-5-undecyl-1,3-benzothiazole-4,7-dione', '']
# ['', 'estrone oleic acid ester', 'oleoyl estrone', 'oe', 'estrone monooleate', 'estrone 3-oleate', 'oleoylestrone', '']
# ['', 'eye 001', 'nx1838', 'pegaptanib sodium', 'pegaptanib octasodium', 'nx 1838', '']
# adding nx1838
# ['', 'sn mesoporphyrin', 'stannsoporfin', 'snmp', 'tin mesoporphyrin', '']
# ['', 'gastrin 17 immunogen', 'antigastrin 17', 'gastrin 17 vaccine', '']
# ['', 'rthrombin', 'recothrom', 'recombinant thrombin', 'rhthrombin', '']
# ['', 'd-tagatose', '(3s,4s,5r)-1,3,4,5,6-pentahydroxyhexan-2-one', 'd-tag', 'd-lyxo-hex-2-ulose', 'd-lyxo-hexulose', 'keto-d-tagatose', '']
# ['', 'deoxyhemoglobin', 'haemoglobin', 'human hemoglobin', '']
# ['', 'dce2_human', 'recombinant human glutamic acid decarboxylase', 'recombinant human gad65', '']
# ['', 'pyy(3-36)', 'pyy 3-36', 'pyy3-36', 'pyy (3-36) peptide', '']
# ['', 'tiomolibdate ion', 'thiomolybdate', '']
# ['', 'rhmbp', 'recombinant human mannose-binding lectin', 'mbl2_human', 'recombinant human mannan-binding protein', '']
# ['', 'bovine fibrinolysin', 'fibrinolysin (human)', 'fibrinolysin, human', 'plasmin (bos taurus)', 'plasmin bovine', 'plasmin (bovine)', 'bovine plasmin', '']
# ['', 'samarium-153-edtmp', 'samarium sm-153 lexidronam', '153sm-edtmp', 'samarium-153 lexidronam', 'samarium (153sm) lexidronam', 'samarium (153 sm) lexidronam', '']
# ['', "paclitaxel 2'-(all-cis-4,7,10,13,16,19-docosahexaenoate)", 'paclitaxel docosahexaenoic acid ester', 'dha paclitaxel', 'dha-paclitaxel', '']
# adding dha-paclitaxel
# ['', 'human ciliary neurotrophic factor', 'ciliary neurotrophic factor (human)', 'human cntf', '']
# ['', 'holmium ho-166 dotmp', '166ho-dotmp', '']
# ['', 'carbomer 974 (p)', 'buffergel', 'carbomer-974p', 'carbomer homopolymer type b', 'carbopol polymer', 'carbomer homopolymer type b (allyl pentaerythritol crosslinked)', 'carbomer 974p', '']
# ['', 'naphthalene 2-sulfonate polymer', 'polynaphthalene sulphonate', '']
# ['', 'tcdo', 'tetrachlorodecaoxygen', '']
# ['', 'rigscan cr49', 'rigscan cr', '']
# ['', '(25r)-5beta-spirostan-3beta-ol', 'isosarsapogenin', '(25r)-spirostan-3beta-ol', 'smilagenin', '']
# ['', 'infecton', 'technetium tc 99m ciprofloxacin', 'technetium (99mtc) ciprofloxacin', '99mtc-ciprofloxacin', '']
# ['', 'alpha-pyrrolidinononanophenone', 'alpha-pnp', '']
# ['', 'nf-kb decoy', 'nf-kappab decoy', '']
# ['', 'thd-dp-fm', 'tetrahydro-n,n-dimethyl-2,2-diphenyl-3-furanemethanamine', 'anavex 2-73', '']
# ['', 'acidic fibroblast growth factor', 'acidic fibroblast growth factor (afgf)', 'fibroblast growth factor, acidic', '']
# ['', 'xg-102 c-terminal acid', 'd-jnki 1 peptide', '']
# ['', '17beta-hydroxy-7alpha-methylestr-4-enone', '7alpha-methyl-3-oxo-4-estren-17beta-ol', 'ment', '7alpha-methyl-19-nortestosterone', '7alpha-methyl-17beta-hydroxy-4-estren-3-one', '7α-methyl-19-nortestosterone', '7alpha-methylnandrolone', 'trestolonum', '17beta-hydroxy-7alpha-methylestr-4-en-3-one', '19-nor-7alpha-methyltestosterone', '19-nor-methyltestosterone', 'trestolona', '']
# ['', 'peg inf alfacon-1', 'pegylated interferon alfacon-1', 'peg-alfacon', 'peg-interferon alfacon-1', 'peg-infergen', '']
# ['', 'mdipa', 'mdi-p', 'mdip', '']
# ['', 'hyaluronidase recombinant human', 'hyaluronidase (human recombinant)', 'hyaluronidase, human', 'recombinant human hyaluronidase', 'hyaluronidase human recombinant', 'vorhyaluronidase alfa', '']
# ['', '(r)-5-(1,2-dithiolaln-3-yl)-pentanoic acid tromethamine', 'thioctic acid tromethamine', '']
# ['', 'yspsl', 'rpsgl-ig', '']
# ['', 'rspsma', 'recombinant soluble prostate-specific membrane antigen (rspsma) vaccine', '']
# ['', 'calcitonin gene related peptide', 'cgrp', 'calcitonin-gene-related peptide', 'lab cgrp', '']
# ['', 'c1 inhibitor', 'c1-esterase inhibitor, human', 'c1-inhibiting factor', 'c1 esterase inhibitor (human)', 'ic1_human', 'human c1 inhibitor', 'human c1-esterase inhibitor', 'c1-inhibitor, plasma derived', 'plasma protease c1 inhibitor', 'c1 inhibitor (human)', 'c1 inhibitor human', 'c1-inh', '']
# ['', 'recombinant human endostatin', 'endostatins', '']
# ['', 'd2s', 'dextrin sulphate', '']
# ['', 'osteoprotegerin recombinant', 'tr11b_human', 'ropg', 'osteoclastogenesis inhibitory factor', '']
# ['', 'recombinant nematode anticoagulant protein c2', 'recombinant nematode anticoagulant protein-2', '']
# ['', 'αhga', 'alpha-hga', 'alpha-hydroxy-glycineamide', 'alphahga', 'ahga', 'alfahga', '']
# ['', '(3beta,5alpha,7beta)-3,7-dihydroxyandrostan-17-one', '7β-oh-epia', '7beta-oh-epia', '7β-hydroxyepiandrosterone', '']
# ['', 'rostaporfin', 'snet2', 'tin ethyl etiopurpurin', '']
# ['', '2-(4-(1,1-dimethylethyl)cyclohexyl)-3-hydroxy-1,4-naphthalenedione', "2-(4'-t-butylcyclohexyl)-3-hydroxy-1,4-naphthoquinone", '2-[4-(1,1-dimethylethyl)cyclohexyl]-3-hydroxy-1,4-naphthalenedione', '2-(4-tert-butylcyclohexyl)-3-hydroxy-1,4-naphthoquinone', '']
# ['', 'calcitonin (human)', 'calcitonin (human synthetic)', 'calcitonin, human synthetic', 'calcitonin, human', 'calcitonin human', '']
# ['', 'paris blue', 'ferric hexacyanoferrate(ii)', 'parisian blue', 'berlin blue', 'prussian blue insoluble', 'iron(iii) ferrocyanide', 'iron(iii) hexacyanoferrate(ii)', 'ferric hexacyanoferrate', 'ferric ferrocyanide', 'ferrocin', '']
# ['', 'tinzaparina', 'tinzaparin sodium', '']
# ['', '3-(10-methyl-9-anthryl)propionic acid', '3-(10-methyl-anthracen-9-yl)-propionic acid', '']
# ['', '(s)-2-phenyllactic acid', '(s)-(+)-atrolactic acid', '(s)-2-hydroxy-2-phenylpropanoic acid', '(s)-atrolactic acid', '']
# ['', 'azapropazone', 'azapropazonum', '1,2-dihydro-3-dimethylamino-7-methyl-1,2-(propylmalonyl)-1,2,4-benzotriazine', 'apazone', '3-dimethylamino-7-methyl-1,2-(n-propylmalonyl)-1,2-dihydro-1,2,4-benzotriazine', 'azapropazona', 'azapropazon', '5-(dimethylamino)-9-methyl-2-propyl-1h-pyrazolo(1,2-a)(1,2,4)benzotriazine-1,3(2h)-dione', '']
# adding azapropazone
# adding apazone
# ['', 'l-phenylalanine chloromethyl ketone', '(3s)-3-amino-1-chloro-4-phenyl-2-butanone', '']
# ['', 'p-nitrophenyl phosphonobutanoyl d-alanine', 'n-[4-(4-nitrophenylphospho)butyryl]-d-alanine', '']
# ['', 'p-nitrophenyl phosphonobutanoyl l-alanine', 'n-[4-(4-nitrophenylphospho)butyryl]-l-alanine', '']
# ['', 'testosterone-17-succinate', 'testosterone hemisuccinate', 'testosterone 17-hemisuccinate', '']
# ['', 'nadroparina', 'nadroparine', '']
# ['', 'human cck-33', 'human cholecystokinin-33', 'cck-pz', 'pancreozymin', '']
# adding pancreozymin
# ['', '21-hydroxy-5β-pregnane-3,20-dione', '5beta-dihydrodeoxycorticosterone', '5β-dihydrodeoxycorticosterone', '']
# ['', 'bacillus anthracis immune globulin human', 'anthrax immune globulin human', 'anthrax immune globulin (human)', '']
# ['', 'aluminum potassium sulfate anhydrous', 'potassium aluminium sulfate', 'potassium aluminum disulfate', 'alum, potassium', 'aluminum potassium sulfate', 'aluminium potassium sulfate', 'aluminium potassium bis(sulphate)', 'aluminum potassium disulfate', 'aluminum potassium alum', 'burnt potassium alum', 'potash alum', '']
# ['', 'podophyllum (resin)', 'podofillina', 'podophyllum resin', '']
# ['', 'pig thyroid', 'porcine thyroid', 'sus scrofa thyroid', 'thyroid (pork)', 'thyroid extract, porcine', '']
# ['', 'oxidronic acid 99mtc-complex', 'technetium 99mtc oxidronate', 'technetium (99mtc) oxidronate', 'technetium tc 99m oxidronate', '99mtc-hdp', '']
# ['', 'iron pyrophosphate', 'iron(iii) pyrophosphate', '']
# ['', 'technetium-99 tetrofosmin', 'technetium tc 99m tetrofosmin', 'technetium (99mtc) tetrofosmin', 'tc-99m tetrofosmin', '']
# ['', '99mtc sestamibi', '99m tc-sestamibi', 'technetium (99m tc) sestamibi', 'sestamibi', '99mtc-sestamibi', '99m-tc sestamibi', 'technetium tc 99m sestamibi', 'technetium (99mtc) sestamibi', '']
# adding sestamibi
# ['', 'technetium-99m-diisopropyliminodiacetic acid', 'technetium tc 99m disofenin', '99mtc-disida', 'technetium (99mtc) disofenin', '99mtc-disofenin', '']
# ['', 'technetium tc 99m pyrophosphate', 'technetium (99mtc) pyrophosphate', '']
# ['', 'beta-methylfentanyl', 'betamethylfentanyl', '']
# ['', 'butyr-fentanyl', 'butyrylfentanyl', '']
# ['', 'factor i (fibrinogen)', 'fibrinogen', 'coagulation factor i', 'factor i human', 'fibrinogen (human)', 'fibrinogen, human', 'fibrinogen concentrate human', 'human fibrinogen', 'fibrinogen human', 'fibrinogen human plasma-derived', 'fibrinogen concentrate (human)', '']
# adding fibrinogen
# ['', 'technetium tc 99m tilmanocept', 'technetium tc99 tilmanocept', 'technetium (99mtc) tilmanocept', '']
# ['', 'natrii aurothiomalas', 'gold sodium thiomalate', 'aurotiomalato sodico', 'sodium aurothiomalate', '']
# ['', 'technetium (99mtc) pertechnetate', 'technetium tc 99m pertechnetate', '(99tc)pertechnetate', 'gpert', 'cpert', 'pertechnetate-99tc', '']
# ['', 'ufur', 'tegafur/uracil', 'uft', '']
# ['', 'antihemophilic factor (recombinant), pegylated-aucl', 'antihemophilic factor (recombinant), pegylated', '']
# ['', 'nofetumomab', 'technetium tc 99m nofetumomab merpentan', 'technetium (99mtc) nofetumomab merpentan', '']
# adding nofetumomab
# ['', 'air, compressed', 'air, synthetic medicinal', 'air, medicinal', 'air', '']
# adding air
# ['', 'indium in-111 myoscint', 'indium (111in) imciromab pentetate', 'myoscint indium in-111', 'indium in 111 imciromab pentetate', 'indium in-111 imciromab pentetate', '']
# ['', 'grape sugar', 'glucose, liquid', 'dextrosa', 'dextrose, unspecified', 'dextrose', 'liquid glucose', 'dextrose solution', 'glucosa', 'glucose', '']
# adding dextrose
# adding glucose
# ['', 'rauwolfia serpentina alseroxylon', 'rauvolfia serpentina root', 'alseroxylon', 'snakeroot', 'rauwolfia', 'rauwolfia root', 'rauwolfia serpentina', 'alkaloids, rauwolfia', 'rauwolfia alkaloids', '']
# adding alseroxylon
# adding rauwolfia
# ['', 'sutilains', 'sutilaina', 'sutilaines', '']
# adding sutilains
# ['', 'chromate (51 cr) de sodium', 'sodium chromate cr 51', 'cromato sodico (51 cr)', 'natrii chromas (51 cr)', 'sodium chromate (51 cr)', 'sodium chromate (51cr)', '']
# ['', '(57co)vitamin b12', 'cyanocobalamine (57 co)', 'cyanocobalaminum (57 co)', 'cyanocobalamin co 57', 'cianocobalamina (57 co)', 'cyanocobalamin (57 co)', 'cyanocobalamin (57co)', '']
# ['', 'technetium polyphosphate', 'technetium (99mtc) polyphosphate', 'technetium tc 99m polyphosphate', '']
# ['', 'indium in 111 pentetate', 'indium in-111 pentetate', 'indium (111in) pentetic acid', '']
# ['', 'albumin,iodinated i-125 serum', 'iodinated (125 i) human serum albumin', 'albumin,iodinated serum,i-125', '125 i-hsa', 'albumin, blood serum, labeled with iodine-125', 'albumotope i-125', 'iodinated i 125 serum albumin', '125 i hsa', 'human serum albumin i-125', 'albumin, iodinated i 125 serum', 'iodinated (125i) human serum albumin', 'iodinated i-125 serum albumin', 'human albumin i-125', 'hsa i-125', '125-i-hsa', '']
# ['', 'albumin,iodinated serum,i-131', 'albumin, iodinated i-131 serum', 'iodinated i-131 serum albumin', 'albumin, blood serum, labeled with iodine-131', 'albumin, iodinated i 131 serum', 'iodinated i 131 serum albumin', 'human serum albumin i-131', 'albumin,iodinated i-131 serum', 'iodinated (131i) human serum albumin', 'human albumin i-131', '']
# ['', 'technetium tc-99m albumin aggregated', 'technetium tc 99m albumin colloid', '']
# ['', 'insulin bovine', 'insulin (beef)', 'insulin purified beef', '']
# ['', 'indium 111in oxyquinoline', 'indium (in111) oxine', 'in-111 oxyquinoline', 'indium-111 oxine', 'indium in111 oxine', 'indium (111 in) oxyquinoline', 'indium (in111) oxyquinoline', 'indium in-111 oxine', 'indium-111 oxyquinoline', '']
# ['', 'iodine iofetamine (123i)', 'iofetamine (123i)', 'iofetamine i 123', 'iofetamine, i-123', 'iofetamine (123 i)', '']
# ['', 'indium in 111 chloride', 'indium-111 chloride', 'indium in-111m chloride', 'indium in 111m chloride', '111indium trichloride', 'indium chloride in-111', 'indium chloride (111incl3)', '']
# ['', 'technetium tc 99m-labeled red blood cells', 'technetium tc-99m red blood cell', 'technetium tc-99m red blood cell human', 'technetium (99mtc) red blood cells', 'technetium tc 99m red blood cells', '']
# ['', 'synthetic porcine secretin', 'secretin (swine)', 'porcine secretin', 'secretin (pig)', 'secretin (porcine)', 'pig secretin', 'secretin synthetic porcine', '']
# ['', 'clostridium tetani whole', 'bacillus tetani whole', 'clostridium tetani', '']
# ['', 'rabies virus vaccine wistar strain pm-1503-3m (human)', 'rabies virus strain pm-1503-3m antigen (propiolactone inactivated)', '']
# ['', 'rotavirus vaccine, live, oral', 'rota virus, live attenuated', '']
# ['', 'rabies virus vaccine flury-lep strain', 'rabies virus strain flury lep antigen (propiolactone inactivated)', '']
# ['', 'recombinant human papillomavirus type 6 l1 protein', 'l1 protein, human papillomavirus type 6 vaccine', '']
# ['', 'l1 protein, human papillomavirus type 11 vaccine', 'recombinant human papillomavirus type 11 l1 protein', '']
# ['', 'recombinant human papillomavirus type 16 l1 protein', 'l1 protein, human papillomavirus type 16 vaccine', '']
# ['', 'l1 protein, human papillomavirus type 18 vaccine', 'recombinant human papillomavirus type 18 l1 protein', '']
# ['', 'recombinant human papillomavirus type 31 l1 protein', 'l1 protein, human papillomavirus type 31 vaccine', '']
# ['', 'recombinant human papillomavirus type 33 l1 protein', 'l1 protein, human papillomavirus type 33 vaccine', '']
# ['', 'recombinant human papillomavirus type 45 l1 protein', 'l1 protein, human papillomavirus type 45 vaccine', '']
# ['', 'recombinant human papillomavirus type 52 l1 protein', 'l1 protein, human papillomavirus type 52 vaccine', '']
# ['', 'recombinant human papillomavirus type 58 l1 protein', 'l1 protein, human papillomavirus type 58 vaccine', '']
# ['', 'rubivirus rubella virus wistar ra 27/3 whole', 'rubella virus strain wistar ra 27/3 live (attenuated) antigen', 'rubella virus vaccine,live', 'rubella virus live antigen, a', 'rubella virus strain wistar ra 27/3 live antigen', 'rubella, live attenuated', 'rubella virus vaccine live (wistar ra 27-3 strain)', 'rubella virus (vaccine strain ra27/3) live antigen', '']
# ['', 'varicella-zoster virus strain oka/merck live antigen', 'varicella vaccine', 'varicella zoster live (attenuated) antigen', 'varicella virus vaccine live (oka-merck) strain', 'chickenpox vaccine', 'human herpesvirus 3 live (attenuated) antigen', 'varicella-zoster virus strain oka/merck live (attenuated) antigen', 'varicella zoster live(attenuated) antigen', 'varicella-zoster virus (live, attenuated)', '']
# ['', 'pneumococcal capsular polysaccharide type 4 vaccine', 'pneumococcal polysaccharide serotype 4', '']
# ['', 'pneumococcal polysaccharide serotype 6b', 'pneumococcal capsular polysaccharide type 6b vaccine', '']
# ['', 'pneumococcal polysaccharide serotype 9v', 'pneumococcal capsular polysaccharide type 9v vaccine', '']
# ['', 'pneumococcal polysaccharide serotype 14', 'pneumococcal capsular polysaccharide type 14 vaccine', '']
# ['', 'pneumococcal capsular polysaccharide type 18c vaccine', 'pneumococcal polysaccharide serotype 18c', '']
# ['', 'pneumococcal capsular polysaccharide type 19f vaccine', 'pneumococcal polysaccharide serotype 19f', '']
# ['', 'pneumococcal capsular polysaccharide type 23f vaccine', 'pneumococcal polysaccharide serotype 23f', '']
# ['', 'motie molulu pollen', 'panicum dactylon pollen', 'standardized bermuda grass pollen', 'devilgrass pollen', 'allergen pack bermuda grass', 'grama-seda pollen', 'ae-bermuda grass', 'capriola dactylon pollen', 'common bermudagrass pollen', 'allergenic extract, bermuda grass', 'bermuda grass pollen extract', 'bermudagrass pollen', 'bermuda grass pollen', 'manienie pollen', 'allergenic extract- bermuda grass cynodon dactylon', 'allergenic extract,grass,bermuda', 'cynodon dactylon', '']
# ['', 'cocklebur pollen extract', 'rough cocklebur pollen extract', '']
# ['', 'meadowgrass pollen extract', 'kentucky bluegrass pollen extract', 'standardized kentucky blue/june grass pollen', 'poa pratensis', '']
# ['', 'festuca pratensis', 'standardized meadow fescue grass pollen', 'meadow fescue grass pollen extract', '']
# ['', 'orchard grass pollen extract', 'cocksfoot grass pollen', 'allergenic extract- orchard grass dactylis glomerata', 'dactylis glomerata', 'standardized orchard grass pollen', '']
# ['', 'juglans rubra pollen', 'juglans angustifolia pollen', 'juglans illinoinensis pollen', 'carya pecan pollen', 'hicoria pecan pollen', 'carya oliviformis pollen', 'juglans cylindrica pollen', 'hicorius diguetii pollen', 'carya diguetii pollen', 'hicorius tetraptera pollen', 'juglans oliviformis pollen', 'pecan pollen', 'carya illinoinensis pollen', 'carya tetraptera pollen', 'hicorius oliviformis pollen', 'juglans pecan pollen', 'carya angustifolia pollen', '']
# ['', 'ambrosia artemisiifolia', 'short ragweed pollen extract', 'short ragweed pollen extracts', 'standardized short ragweed pollen allergenic extract', '']
# ['', 'allergenic extract- ryegrass, perennial lolium perenne', 'perennial rye grass pollen extract', 'standardized perennial rye grass pollen', 'lolium perenne allergenic extract', 'lolium perenne', '']
# ['', 'timothy grass pollen extract', 'phleum nodosum pollen', 'timothy pollen', 'timothy grass pollen', 'phleum pratense pollen extract', 'allergenic extract, timothy grass', 'grass pollen extract', 'standardized timothy grass pollen', 'allergenic extract,timothy grass pollen', 'common timothy pollen', 'timothy grass pollen extracts', 'phleum pratense', 'allergenic extract, grass, timothy', 'timothy grass (phleum pretense) pollen standardized', '']
# ['', 'standardized cat pelt', 'cat skin extract', '']
# ['', 'american house dust mite extract', 'mite d.f.', 'american house dust mite', 'mite d.f. (dermatophagoides farinae) standardized', 'insects (whole body), mite dermatophagoides farinae', 'house dust mite extract, dermatophagoides farinae', '']
# ['', 'european house dust mite', 'european house dust mite extract', 'mite d.p. (dermatophagoides pteronyssinus) standardized', 'insects (whole body), mite dermatophagoides pteronyssinus', 'dermatophagoides pteronyssinus whole', 'ae-mite, dermatophagoides pteronyssinus', 'mite d.p.', 'house dust mite extract, dermatophagoides pteronyssinus', '']
# ['', 'allergenic extract, redtop grass', 'standardized redtop grass pollen', '']
# ['', 'sweet vernal grass pollen extract', 'standardized sweet vernal grass pollen', '']
# ['', 'canis canis skin', 'canis familiaris domesticus skin', 'canis familiaris skin', 'dog epithelia', 'domestic dog skin', 'canis domesticus skin', '']
# ['', 'domestic horse skin', 'horse skin', 'horse epithelia', 'horse (feral) skin', 'equus przewalskii forma caballus skin', 'equine skin', 'equus caballus skin', 'equus ferus caballus skin', '']
# ['', 'iris germanica var. florentina root', 'iris x germanica root', 'iris germanica var. florentina rhizome', '']
# ['', 'american cockroach allergenic extract', 'allergenic extract- cockroach periplaneta americana', '']
# ['', 'allergenic extract- cockroach, german blatella germanica', 'german cockroach allergenic extract', '']
# ['', 'rhizopus arrhizus', 'mold, rhizopus arrhizus', 'allergenic extract, mold, rhizopus arrhizus', 'rhizopus oryzae extract', 'rhizopus arrhizus mold', '']
# ['', 'aspergillus flavus var. oryzae whole', 'aspergillus oryzae', 'aspergillus flavus var. oryzae', 'eurotium oryzae', '']
# ['', 'acnida tuberculata pollen', 'western waterhemp pollen extract', 'acnida subnuda pollen', 'rough-fruit amaranth pollen', 'acnida altissima pollen', 'amaranthus tuberculatus pollen', 'acnida concatenata pollen', 'roughfruit amaranth pollen', 'amaranthus ambigens pollen', 'amaranthus altissimus pollen', 'tall waterhemp pollen', '']
# ['', 'felis domesticus hair', 'cat hair allergenic extracts', 'cat hair (felis domesticus)', 'cat hair', 'cat hair (felis domesticus) standardized', 'felis catus domestica hair', 'cat hair extract', 'felis silvestris catus hair', 'domestic cat hair', '']
# ['', 'milk protein', 'milk casein', 'casein allergenic extract', 'calcium caseinate', 'bovine casein', 'casein, milk', 'casein, cow milk', '']
# ['', 'paralithodes camtschaticus flesh', 'king crab (paralithodes camtschaticus)', 'paralithodes camtschatica flesh', 'paralithodes camtschaticus muscle', 'red king crab flesh', '']
# ['', 'flounder allergenic extract', 'southern flounder', '']
# ['', 'lobster, unspecified', 'lobster allergenic extract', 'american lobster', '']
# ['', 'oyster, unspecified', 'oyster allergenic extract', 'eastern oyster', '']
# ['', 'brown rice', 'brown rice preparation', 'rice allergenic extract', '']
# ['', 'shrimp allergenic extract', 'common shrimp', 'shrimp, unspecified', '']
# ['', 'tuna allergenic extract', 'ae-tuna', 'tuna, unspecified', '']
# ['', 'tetanus toxoid vaccine, inactivated', 'tetanus toxoid adsorbed', 'tetanus toxoid', '']
# ['', 'diphtheria toxoid', 'diphtheria toxoid adsorbed', '']
# ['', 'hamster skin extract', 'syrian hamster skin extract', '']
# ['', 'whitefish', 'white fish allergenic extract', '']
# ['', 'blue ridge blueberry', 'blueberry allergenic extract', '']
# ['', 'house fly allergenic extract', 'house fly extract', '']
# ['', 'oat loose smut extract', 'oat smut allergenic extract', '']
# ['', 'tilletia caries whole', 'tilletia tritici', 'lycoperdon tritici', 'tilletia caries', 'stinking wheat smut', 'caeoma sitophilum', 'tilletia sitophila', 'stinking smut of wheat', 'wheat bunt fungus', 'fusisporium inosculans', 'uredo caries', 'uredo sitophila', '']
# ['', 'flaxseed allergenic extract', 'flaxseed extract', '']
# ['', 'western wheatgrass', 'western wheatgrass pollen extract', '']
# ['', 'arroyo willow pollen', 'arroyo willow pollen extract', '']
# ['', 'populus balsamifera ssp. trichocarpa pollen', 'balsam poplar pollen extract', 'populus trichocarpa pollen', 'black cottonwood pollen', 'black cottonwood pollen extract', '']
# ['', 'burrobrush pollen extract', 'ambrosia salsola pollen', '']
# ['', 'japanese encephalitis vaccine ic51', 'japanese encephalitis vaccine', 'japanese encephalitis virus strain sa 14-14-2 antigen (formaldehyde inactivated)', '']
# ['', 'filamentous haemagglutinin', 'bordetella pertussis filamentous hemagglutinin vaccine, inactivated', 'filamentous haemagglutinin adsorbed', '']
# ['', 'bordetella pertussis pertactin vaccine, inactivated', 'pertactin adsorbed', 'pertactin', '']
# ['', 'inactivated poliovirus type i', 'inactivated poliomyelitis vaccine (v.c.o.) type 1 mahoney', 'poliovirus vaccine inactivated, type 1 (mahoney)', '']
# ['', 'inactivated poliomyelitis vaccine (d.c.o.) type 2 mef1', 'poliovirus vaccine inactivated, type 2 (mef-1)', 'inactivated poliovirus type ii', '']
# ['', 'inactivated poliovirus type iii', 'inactivated poliomyelitis vaccine (v.c.o.) type 3 saukett', 'poliovirus vaccine inactivated, type 3 (saukett)', '']
# ['', 'fusarium bulbigenum', 'fusarium oxysporum whole', 'fusarium oxysporum', '']
# ['', 'ustilago nuda', 'barley smut extract', '']
# ['', 'catfish (ameiurus catus)', 'amiurus catus flesh', 'pimelodus catus flesh', 'silurus catus flesh', 'ictalurus catus flesh', 'ameiurus catus muscle', 'ameiurus catus flesh', '']
# ['', 'chionoecetes opilio flesh', 'snow crab flesh', 'snow crab (chionoecetes opilio)', 'opilio crab', 'chionoecetes opilio muscle', '']
# ['', 'canis familiarus domesticus hair', 'canis canis hair', 'canis domesticus hair', 'domestic dog hair', 'dog hair extract', 'canis lupus familiaris hair extract', 'canis familiaris hair', 'canis lupus familiaris hair', 'dog hair', '']
# ['', 'quercus castanea pollen', 'quercus muehlenbergii pollen', 'chinkapin oak pollen', 'quercus alexanderi pollen', 'quercus brayi pollen', 'quercus acuminata pollen', '']
# ['', 'sabina virginiana oil', 'cedar oil', 'juniperus virginiana wood oil', 'red cedar wood oil', 'oil of cedar wood', 'juniperus virginiana', 'juniperus virginiana oil', 'eastern red cedar stem oil', 'cedarwood oil', 'eastern red cedar wood oil', 'red cedarwood oil', 'red cedar stem oil', 'juniperus virginiana volatile oil', 'juniperus virginiana stem oil', '']
# ['', 'white hickory pollen extract', 'carya alba pollen', '']
# ['', 'rough marshelder pollen extract', 'iva annua var. annua pollen', '']
# ['', 'kochia scoparia pollen', 'burning bush pollen extract', '']
# ['', 'burweed marshelder pollen extract', 'iva xanthifolia pollen', '']
# ['', 'redroot pigweed whole', 'galliaria scabra whole', 'amaranthus retroflexus', 'amaranthus bullatus whole', 'careless weed whole', 'amaranthus retroflexus whole', 'galliaria retroflexa whole', 'amaranthus spicatus whole', 'rough pigweed whole', 'red-root amaranth whole', 'amaranthus recurvatus whole', 'amaranthus curvifolius whole', 'redroot amaranth whole', 'amaranthus delilei whole', 'amaranthus bulgaricus whole', 'amaranthus rigidus whole', 'amaranthus johnstonii whole', '']
# ['', 'acremonium roseum', 'cephalosporium roseum', 'cephalosporium roseum whole', '']
# ['', 'pleospora tarda', 'pleospora tarda whole', 'stemphylium botryosum', '']
# ['', 'koelers grass pollen extract', 'standardized june grass pollen', '']
# ['', 'alkali blite pollen extract', 'suaeda nigra pollen', '']
# ['', 'yellow hornet venom protein', 'dolichovespula arenaria venom protein extract', '']
# ['', 'white faced hornet venom protein', 'bald-faced hornet venom protein', '']
# ['', 'allergenic extract, italian ryegrass pollen', 'lolium multiflorum pollen', 'italian rye grass pollen extract', 'lolium perenne ssp. multiflorum pollen', '']
# ['', 'mycogone nigra whole', 'mycogone nigra', '']
# ['', 'humicola lanuginosa', 'thermomyces lanuginosus', 'humicola brevispora', 'sepedonium lanuginosum', 'thermomyces lanuginosus whole', 'monotospora lanuginosa', '']
# ['', 'monilia cutanea', 'trichosporon cutaneum whole', 'mycoderma cutaneum', 'oidium cutaneum', 'proteomyces cutaneus', 'basidiotrichosporon cutaneum', 'geotrichum cutaneum', 'oospora cutanea', 'trichosporon cutaneum', 'geotrichoides cutanea', '']
# ['', 'barley malt flr', 'malted barley', 'barley malt flour', '']
# ['', 'sage leaf allergenic extract', 'salvia officinalis', '']
# ['', 'ulmus fulva pollen', 'ulmus rubra pollen', 'slippery elm pollen', '']
# ['', "king's-nut pollen", 'shellback hickory pollen', 'hicoria laciniosa pollen', 'juglans laciniosa pollen', 'carya laciniosa pollen', 'shellbark hickory pollen', '']
# ['', 'bacillus anthracis strain v770-np1-r filtrate (attenuated) antigen', 'anthrax vaccine adsorbed', 'bacillus anthracis strain v770-np1-r filtrate antigen', 'bacillus anthracis strain v770-np1-r antigens', 'bacillus anthracis strain v770-np1-r antigen', 'bacillus anthracis inactivated antigen', '']
# ['', 'betula pendula pollen', 'european white birch pollen', 'silver birch pollen', 'betula alba var. pendula pollen', 'betula pendula pollen extract', 'weeping birch pollen', '']
# ['', 'cercidium floridum pollen', 'palo verde pollen', 'cercidium torreyanum pollen', 'blue paloverde pollen', 'parkinsonia torreyana pollen', 'cercidium floridum subsp. floridum pollen', 'blue palo verde pollen', 'parkinsonia florida pollen', '']
# ['', 'poultry', 'poultry, unspecified', 'chicken, turkey, duck, goose, or quail', '']
# ['', 'clam allergenic extract', 'northern quahog', 'clam', 'quahog', 'minced clams', '']
# ['', 'cod, unspecified preparation', 'codfish', 'cod', 'codfish allergenic extract', '']
# adding cod
# ['', 'salmon allergenic extract', 'salmon', 'pink salmon', 'salmon preparation', '']
# adding salmon
# ['', 'saccharomyces cerevisiae/saccharomyces boulardii', 'yeasts', 'yeast, dried', 'yeast, unspecified', '']
# ['', 'guinea pig dander', 'cavia aperea porcellus dander', 'cavia cobaya dander', 'cavia porcellus dander', '']
# ...
# ['', 'cholera vaccine', 'cholera vaccine live oral', 'cholera vaccine, live, oral', '']
# ['', 'influenza a virus h1n1 live antigen, a', 'influenza a virus a/south dakota/6/2007(h1n1) live(attenuated) antigen', 'influenza a virus a/south dakota/6/2007 (h1n1) live(attenuated) antigen', '']
# ['', 'influenza a virus h3n2 live antigen, a', 'influenza a virus a/uruguay/716/2007(h3n2) live(attenuated) antigen', '']
# ['', 'insulin-like growth factor-2', 'insulin-like growth factor-ii', 'igf-2', 'igf-ii', 'cg-igf2', 'sh-polypeptide-31', 'rh-polypeptide-31', 'human insulin-like growth factor ii', 'human oligopeptide-24', 'insulin-like growth factor 2', 'insulin-like growth factor ii (human)', 'multiplication-stimulating activity iii-2', 'rh-oligopeptide-8', '']
# ['', 'dl-alpha-tocopheryl acetate', 'all-rac-alpha-tocopheryl acetate', 'all-rac-alfa-tocopheryl acetate', '']
# ['', 'pvp-k 30', 'plasdone k29-32', 'polyvinylpyrrolidone k30', 'polyvinylpyrrolidone k-29/32', 'plasdone k29/32', 'povidone k29/32', '1-vinylpyrrolidin-2-one homopolymer', 'povidone k29-32', 'polyvinylpyrrolidone k 30', 'pvp k-30', 'pvp k30', '']
# ['', 'n-acetyl-l-cysteine zinc salt', 'zinc acetylcysteine', '']
# ['', 'n-acetyl-l-cysteinamide', 'naca', 'n-acetyl cysteine amide', 'n-acetylcysteine amide', 'n-acetyl-cysteine-amide', 'n-acetylcysteinamide', 'n-acetyl-l-cysteine amide', 'nac amide', '']
# ['', 'calcium phosphate, dibasic, dihydrate', 'dicalcium phosphate dihydrate', 'calcium phosphate dibasic, hydrous', 'd.c.p.', 'calcium phosphate dihydrate, dibasic', 'dibasic calcium phosphate dihydrate', 'dibasic calcium phosphate hydrate', 'calcium phosphate, dibasic, hydrous', 'calcium monohydrogen phosphate dihydrate', '']
# ['', 'ascorbic acid, magnesium salt', 'vitamin c magnesium salt', 'l(+)-ascorbic acid magnesium salt', '']
# ['', 'l-ascorbic acid, zinc salt', 'l-ascorbic acid, zinc salt (2:1)', '(-)-ascorbic acid, zinc salt', '']
# ['', 'ascorbic acid nicotinamide complex', 'nicotinamide-ascorbic acid complex', 'niacinamide ascorbate', '']
# ['', 'zinc(ii) glycinate', 'zinc bisglycinate', '']
# ['', 'zinc carbonate, basic', 'zinc subcarbonate', 'basic zinc carbonate', 'zinc carbonate', '']
# ['', 'trimanganese dicitrate', 'manganese citrate anhydrous', '']
# ['', 'potassium, elemental', 'potassium metal', 'k', 'potassium, metal', 'potasio', 'kalium', '']
# adding k
# ['', 'lithium hydroxide anhydrous', 'lithiumhydroxid', 'lithium hydrate', '']
# ['', 'iron(ii) ion', 'fe2+', 'iron(2+) ion', 'iron, ion (fe2+)', 'iron(2+)', 'ferrous ion', '']
# ['', 'acetate anion', 'azetat', 'acetic acid anion', 'acetate', 'acetic acid, ion(1-)', 'acetate ion', 'acetoxy ion', 'acetate ion (1-)', '']
# adding acetate
# ['', 'sodium ion', 'sodium (ion)', 'sodium(1+)', '']
# ['', 'alumunum ion', 'aluminum(3+)', 'aluminium, ion (al3+)', 'aluminum(iii)', 'aluminum(iii) ion', '']
# ['', 'hydroxide', 'oxidanide', '']
# adding hydroxide
# ['', 'orthophosphate', 'phosphate', '']
# adding phosphate
# ['', 'ga3+', 'gallium ion(3+)', 'gallium, ion (ga3+)', 'gallium(iii) cation', 'gallium(3+) cation', 'gallium (ga3+)', '']
# ['', 'chromium(iii)', 'chromium ion (3+)', 'cr3+', 'chromium(iii) cation', 'chromic ion', 'chromium, ion (cr3+)', 'chromium cation (3+)', 'chromium cation (cr3+)', 'chromium(iii) ion', 'chromium (3+)', '']
# ['', 'gold ion(1+)', 'gold (au1+)', 'gold, ion (au1+)', 'gold(1+) ion', 'au+', 'gold(1+)', 'au1+', '']
# ['', 'indium, ion (in3+) in-111', 'indium-111 cation', 'indium cation in-111 (3+)', 'indium in-111 cation', 'indium cation in 111', 'indium (111in) cation', '']
# ['', 'strontium sr-89 cation', 'strontium (89sr) cation', 'strontium-89', '']
# ['', 'sulfuric acid ion(2-)', 'sulfate dianion', 'sulfate', 'sulfate(2-)', '']
# adding sulfate
# ['', 'zinc sulfate, unspecified hydrate', 'zinc sulfate, unspecified', '']
# ['', 'gallium (67ga)cation', 'gallium cation ga 67', 'gallium ga-67 cation', '']
# ['', 'gallium (67ga) chloride', 'gallium chloride,ga-67', 'gallium chloride, ga-67', 'gallium chloride ga 67', 'gallium (ga-67) chloride', '']
# ['', 'phosphorus-32', 'p-32', 'phosphorus, p-32', '']
# adding p-32
# ['', 'tetraborate', 'pyroborate', 'tetraborate ion', '']
# adding tetraborate
# ['', 'dota-octreotate', 'oxodotreotide', 'dota-tate', '']
# ['', 'octoxyglycerin', '3-(2-ethylhexyloxy)propane-1,2-diol', '']
# ['', 'buergeria obovata bark', 'magnolia thurberi bark', 'michelia gracilis bark', 'kobushi magnolia bark', 'magnolia borealis bark', 'magnolia pseudokobus bark', 'magnolia praecocossima bark', 'talauma obovata bark', 'magnolia kobushii bark', 'yulania kobus bark', '']
# ['', 'kale, raw', 'brassica oleracea var. acephala low fiber cultivar group leaf', 'kale,raw', 'kale leaf', 'brassica oleracea var. viridis low fiber cultivar group leaf', 'brassica oleracea subsp. acephala low fiber cultivar group leaf', '']
# ['', 'sophorae flavescentis radix', 'sofora zheltovataya root', 'sophorae radix', 'shargal lider root', 'sophora root', 'sophora angustifolia root', 'bitter root', 'dogol-evs root', 'kushen', 'lightyellow sophora root', 'shrubby sophora root', 'sle-tres root', 'ku shen', '']
# ['', 'iron carbonate, precipitated', 'ferric carbonate, ferric hydroxide, ferrous hydroxide (variable mixture)', 'iron subcarbonate', 'iron oxide, brown', '']
# ['', 'radium, isotope of mass 223 (223ra2+)', 'radium-223 ion(2+)', '']
# ['', 'bismuth(3+)', 'bisumth(3+) ion', 'bismuth(iii) cation', 'bismut(iii)-ion', 'wismut(iii)-ion', '']
# ['', 'phosphate-32', 'phosphate-32p', '']
# ['', 'cobalto', 'kobalt', 'cobalt, elemental', 'cobaltum', 'cobalt', '']
# adding cobalt
# ['', 'thallium cation tl-201 (1+)', 'thallous ion tl-201', 'thallium cation tl-201', '']
# ['', 'calcium(2+) ion', 'calcium (2+)', 'calcium(2+)ions', 'calcium ions', '']
# ['', 'gadolinium(3+)', 'gadolinium(iii) cation', 'gadolinium(3+) ion', '']
# ['', 'lanthanum(3+) ions', 'lanthanum(3+) ion', 'lanthanum(iii) cation', 'lanthanum, ion (la3+)', 'lanthanum cation (3+)', 'lanthanum cation (la3+)', 'lanthanum ion', '']
# ['', 'plantago insularis seed', 'indian plantain seed', 'plantago brunnea seed', 'plantago fastigiata seed', 'psyllium seed, blonde', 'indian psyllium', 'blonde psyllium', 'plantaginis ovatae testa', 'ispaghula extract', 'ispaghula seed', 'plantago minima seed', 'ispaghula', 'ispaghul', 'blond psyllium', 'plantago gooddingii seed', 'plantaginis ovatae semen', 'ispaghula husk', '']
# ['', 'bioflavonoids', 'hesperidin complex', 'citrus bioflavonoid', 'bioflavonoids,citrus', '']
# ['', 'vamsha stem', 'arundarbor orientalis stem', 'gigantochloa maxima stem', 'nastus arundinaceus stem', 'arundarbor bambos stem', 'giant thorny bamboo stem', 'arundarbor agrestis stem', 'bambusa orientalis stem', 'bambos maxima stem', 'bambos arundo stem', 'arundo bamboo stem', 'bambusa arundinacea stem', 'arundo bambos stem', 'bambos arundinacea stem', 'arundo agrestis stem', 'thorny bamboo stem', 'spiny bamboo stem', 'arundarbor maxima stem', 'bambos agrestis stem', 'arundo arborea stem', 'indian thorny bamboo stem', 'bambusa agrestis stem', 'bambusa maxima stem', 'arundarbor arundinacea stem', 'bambusa bambos stem', '']
# ['', 'common anemarrhena rhizome', 'zhimu', 'knowing mother root', 'anemarrhena rhizome', 'anemarrhena asphodeloides root', 'zhi mu rhizome', 'anemarrhenae rhizoma', 'terauchia anemarrhenifolia rhizome', 'anemarrhenae rhizome', 'zhi mu', 'terauchia anemarrhenifolia root', 'anemarrhena asphodeloides rhizome', '']
# ['', 'edta copper disodium salt', 'copper disodium ethylenediaminetetraacetate', 'copper versenate', 'copper disodium edetate', '']
# ['', 'maltose-rich malted barley extract', 'sprouted hordeum vulgare oligosaccharide extract', 'malt extract', 'malt extract, barley', '']
# ['', 'trisodium phosphate', 'sodium phosphate, tribasic, dodecahydrate', 'phosphoric acid, trisodium salt, dodecahydrate', 'phosphoric acid, trisodium salt, dodeahydrate', 'trisodium phosphate dodecahydrate', 'sodium phosphate dodecahydrate', '']
# ['', 'acetic chloride', 'acetic acid chloride', 'ethanoyl chloride', '']
# ['', '3-chlorobenzo(d)isothiazole 1,1-dioxide', '3-chloro-psi-saccharin', '']
# ['', '2,2,2-trifluoroethyl acetate', '2,2,2-trifluoroethanol acetate', '']
# ['', 'curcumin monosulfate', 'curcumin sulphate', '']
# ['', 'nitrogen chloride', 'trichloramine', 'agene', '']
# ['', 'disulfur dichloride', 'sulfur subchloride', 'thiosulfurous dichloride', 'sulfur monochloride', '']
# ['', 'simvastatin acetate', 'simvastatin acetate ester', "4'-acetylsimvastatin", '']
# ['', 'oleic chloride', 'oleic acid chloride', 'oleyl chloride', '']
# ['', 'phenol sulfate', 'phenylsulfate', '']
# ['', 'ghk complex with copper', 'ghk copper', 'copper tripeptide-1', 'cg-copper peptide', '']
# ['', 'hinoki leaf', 'hinoki cypress leaf', 'hinoki false cypress leaf', 'japanese cypress leaf', '']
# ['', 'hydrocotyle erecta leaf', 'thankuni leaf', 'sheep-rot leaf', 'asiatic pennywort leaf', 'spadeleaf leaf', 'hydrocotyle asiatica leaf', 'ji xue cao leaf', 'gotu kola leaf', 'mandukaparni leaf', '']
# ['', 'european elderberry flower', 'sambucus', 'sambucus nigra l. flower', 'sambucus nigra extract', 'european black elderberry flower', 'european black elder flower', 'elder flower', 'sambuci flos', '']
# ['', 'rosmarinus officinalis leaf oil', 'rosemary oil spain', 'oil of rosemary', 'rosmarinus officinalis (rosemary) leaf oil', 'rosemary oil egypt', 'rosemary volatile oil', 'rosemary oil morocco', 'rosemary oil france', 'rosemary oleoresin', 'rosemary leaf oil', '']
# ['', 'ginger root oil cochin', 'zingiber sichuanense oil', 'zingiber officinale oil', 'zingiber missionis oil', 'ginger volatile oil', 'amomum zingiber oil', 'zingiber cholmondeleyi oil', 'ginger root oil china', 'zingiber zingiber oil', 'amomum angustifolium oil', 'amomum zinziba oil', 'zingiber officinale (ginger) root oil', 'zingiber officinale rhizome oil', 'zingiber aromaticum oil', 'ginger root oil', '']
# ['', 'salicis cortex', 'salix', 'salix spp. bark', '']
# ['', 'curcuma domestica root oil', 'kua domestica root oil', 'stissera curcuma root oil', 'curcuma longa rhizome essential oil', 'amomum curcuma root oil', 'curcuma montana root oil', 'curcuma longa root oil', 'curcuma ochrorhiza root oil', 'curcuma longa (turmeric) root oil', 'curcuma brog root oil', 'curcuma soloensis root oil', 'curcuma euchroma root oil', 'stissera longa root oil', 'turmeric volatile oil', 'curcuma viridiflora root oil', '']
# ['', 'atractylodes chinensis rhizome', 'atractylis chinensis root', 'atractylodes erosodentata root', 'atractylodes lyrata root', 'atractylis ovata rhizome', 'atractylodes rhizome', 'atractylodes ovata root', 'atractylis pinnatifolia root', 'atractylodes lancea rhizome', 'atractylis separate root', 'atractylodis lanceae rhizoma', 'atractylis lyrata root', 'atractylodes chinensis root', 'cangzhu', 'atractylis ovata root', 'mao cang zhu rhizome', 'cang zhu', 'giraldia stapfii root', 'atractylis lancea root', 'acarna chinensis root', '']
# ['', 'bos taurus liver', 'bos bovis liver', 'cow liver', 'bos primigenius taurus liver', 'beef, liver', 'bovine liver', '']
# ['', 'hydrated ferric oxide', 'iron hydroxide oxide', '']
# ['', 'ethyl 8-hydroxy-alpha-(2-propynylamino)-5-quinolinepropanoate', '5-quinolinepropanoic acid, 8-hydroxy-alpha-(2-propyn-1-ylamino)-, ethyl ester', '']
# ['', 'n-(2-hydroxyoctadecanoyl)-4-hydroxysphinganine', 'ceramide 6 ii', 'biomide 6', 'n-(2-hydroxyoctadecanoyl)-hydroxysphinganine', 'n-2-hydroxystearoyl-phytosphingosine', 'n-(2-hydroxyoctadecanoyl)phytoceramide', 'n-(2-hydroxyoctadecanoyl)phytosphingosine', 'phc-c 18:0/18:0', 'n-(2-hydroxyoctadecanoyl)-4r-hydroxysphinganine', 'cytomide vi', 'phytosphingosine-2-hydroxy-18:0', 'ceramide 6', 'ceramide vi', '']
# ['', '1-stearoyl-c18-sphingosine', 'ceramide ii', 'ceramide ns', 'n-stearoylsphinganine', 'n-octodecanoyldihydroceramide', 'ceramide 2 pure', 'n-octodecanoylsphinganine', 'palmitoyl-c16-dihydrosphingosine', 'n-stearoyldihydroceramide', 'n-(octadecanoyl)-dihydroceramide', 'n-octodecanoyldihydrosphingosine', 'n-stearoyldihydrosphingosine', 'n-(stearoyl)-dihydroceramide', 'ceramide 2', 'n-(octodecanoyl)-sphinganine', 'n-(octadecanoyl)-sphinganine', '']
# ['', 'camponotus pennsylvanicus whole', 'black carpenter ant', 'black carpenter ant whole', '']
# ['', 'vaccinia virus live antigen, b', 'vaccinia virus strain new york city board of health live (attenuated) antigen', '']
# ['', '2-methylbenzoic acid anilide', '2-methyl-n-phenylbenzamide', 'o-toluanilide', '2-methylbenzoanilide', '2-methylbenzanilide', 'o-methylbenzanilide', '']
# ['', 'diphtheria toxin-il-3 fusion protein targeting il-3 receptor', 'tagraxofusp-erzs', 'tagraxofusp', '']
# ['', 'base q', '7-(3,4-trans-4,5-cis-dihydroxy-1-cyclopenten-3-ylaminomethyl)-7-deazaguanine', 'q base', '']
# ['', 'cannabivarol', 'cbv', '']
# ['', 'turoctocog alfa pegol, n8-gp', 'turoctocog alfa pegol', 'n8-gp', '']
# ['', 'pituitary luteinizing hormone', 'luteinizing hormone', 'lh', 'luteinising hormone', 'gonadotropin, luteinizing hormone', 'luteotropic hormone', 'luteinizing gonadotropic hormone', 'luteinising hormone (human)', '']
# adding lh
# ['', 'spirulina platensis whole', 'spirulina', 'oscillatoria platensis', 'spirulina (arthrospira platensis)', 'arthrospira platensis', 'spirulina platensis', 'arthrospira platensis whole', '']
# ['', 'common olive leaf', 'olea sativa leaf', 'olea europaea leaf extract', 'olea europaea (olive) leaf', 'olive', 'olive leaf', '']
# adding olive
# ['', 'dodecyl d-glucopyranoside', 'dodecyl d-glucoside', '']
# ['', 'ephedra stem (ephedra sinica)', 'ephedra ma-huang stem', 'ephedrae herba', 'ephedra stem', 'ephedrae herba (ephedra sinica)', 'ephedra sinica stem', 'ephedra (ephedra sinica)', 'mahunag (ephedra sinica)', 'chinese ephedra stem (ephedra sinica)', 'chinese jointfir stem (ephedra sinica)', 'ephedra herb (ephedra sinica)', 'ma huang (ephedra sinica)', 'cao ma huang', 'ephedra flava stem', '']
# ['', 'polygalae radix', 'polygala root', 'yuan zhi (polygala tenuifolia)', 'thinleaf milkwort root', 'thin-leaf polygala root', 'yuanzhi', 'polygala tenuifolia root', '']
# ['', 'senega officinalis', 'polygala senega root extract', 'seneca snakeroot root', 'senega', 'senega officinalis root', '']
# adding senega
# ['', 'solriamfetol', '(2r)-2-amino-3-phenylpropyl carbamate', '']
# ['', '(+)-β-isosparteine', '(-)-beta-isosparteine', '(+)-beta-isosparteine', 'nonalupine', '']
# ['', 'agrostis repens top', 'agrostis sabulicola top', 'agrostis maeotica top', 'agrostis seminuda top', 'water bentgrass', 'vilfa compressa top', 'black bent', 'agrostis compressa top', 'cinna karataviensis top', 'agrostis tenella top', 'agrostis limosa top', 'agrostis dispar top', 'agrostis gigantea top extract', 'agrostis gigantea top', 'vilfa alba top', 'agrostis virletii top', 'agrostis graniticola top', 'agrostis diffusa top', 'agrostis dubia top', 'redtop', 'agrostis osakae top', 'vilfa gigantea top', 'agrostis praticola top', 'redtop grass', 'agrostis nigra top', 'vilfa dispar top', 'vilfa nigra top', '']
# ['', 'cayenne pepper seed', 'red pepper', 'cayenne pepper', 'hot pepper', 'cayenne pepper allergenic extract', 'capsicum annuum var. annuum seed', '']
# ['', 'remdésivir', 'remdesivirum', 'remdesivir', '']
# ['', 'dengue tetravalent vaccine (live, attenuated)', 'dengue tetravalent vaccine, live', 'dengue vaccine', '']
# ['', 'interleukin-2', 'il-2', '']
# adding interleukin-2
# ['', '18f-flt', 'fluorothymidine f-18', '']
# ['', 'pik3ca', 'phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit alpha isoform', '']
# ['', 'cd40 ligand', 'recombinant cd40-ligand', '']
# ['', 'd-ribose', 'ribose', '']
# adding d-ribose
# adding ribose
# ['', '4-demethylcholesteryloxycarbonylpenclomedine', 'dm-choc-pen', '']
# ['', 'antigen lb39-aa', 'antigen sk29-aa', 'mart1', '']
# ['', 'allulose', 'erythrohexulose', 'pseudofructose', 'dl-psicose', '']
# ['', 'vx15/2503', 'moab vx15/2503', '']
# ['', 'photochlor', 'hpph', '']
# ['', 'emd 273063', 'hu14.18-il2', '']
# adding hu14.18-il2

# %%
#below this cell are old code #### not in use #####

# %%
df =pd.read_csv('drugbank_salt.tsv',delimiter='\t',encoding='utf-8')
print(df.shape)
# Out:
# (2236, 7)

# %%
listSaltsDB=[]
print("total",len(df[df.columns[3]]))

for item in range(len(df[df.columns[3]])):
    if str(df[df.columns[3]][item]) != 'nan':
        listSaltsDB.append(df[df.columns[3]][item])

print('nonempty count',len(listSaltsDB))
print(listSaltsDB)
# Out:
# total 2236
# nonempty count 2046
# ['RGLRXNKKBLIBQS-XNHQSDQCSA-N', 'IKDXDQDKCZPQSZ-JHYYTBFNSA-N', 'YNKFCNRZZPFMEX-XHPDKPNGSA-N', 'MLSVJHOYXJGGTR-IFHOVBQLSA-N', 'KFEFLCOCAHJBEA-ANRVCLKPSA-N', 'KBZOIRJILGZLEJ-LGYYRGKSSA-N', 'XQEJFZYLWPSJOV-XJQYZYIXSA-N', 'CEEQUQSGVRRXQI-UHFFFAOYSA-N', 'TYXBLACMHQBEEW-XKGORWRGSA-N', 'XDCFCHNAIMYBAZ-XQVUROGGSA-N', 'DAEPDZWVDSPTHF-UHFFFAOYSA-M', 'ZAIZDXVMSSDZFA-QRPNPIFTSA-N', 'ZRVUAXXSASAVFG-QRPNPIFTSA-M', 'QWJSAWXRUVVRLH-LREBCSMRSA-M', 'RRNJROHIFSLGRA-JEDNCBNOSA-N', 'BVHLGVCQOALMSV-JEDNCBNOSA-N', 'KWTQSFXGGICVPE-WCCKRBBISA-N', 'HGBAVEGDXFHRQP-FHNDMYTFSA-N', 'GGTYBZJRPHEQDG-WCCKRBBISA-N', 'SLPUVFBNQHVEEU-WCCKRBBISA-N', 'YWOPZILGDZKFFC-DFWYDOINSA-M', 'OSUIUMQSEFFIKM-WCCKRBBISA-N', 'YXJHJCDOUFKMBG-BMZHGHOISA-M', 'RPAJSBKBKSSMLJ-DFWYDOINSA-N', 'WRLFSJXJGJBFJQ-WPUCQFJDSA-N', 'FCHXJFJNDJXENQ-UHFFFAOYSA-N', 'XKZZNHPZEPVUQK-JEDNCBNOSA-N', 'IFQSXNOEEPCSLW-DKWTVANSSA-N', 'MYVIATVLJGTBFV-UHFFFAOYSA-M', 'DPJRMOMPQZCRJU-UHFFFAOYSA-M', 'UIERGBJEBXXIGO-UHFFFAOYSA-N', 'SQGOEODKLMPIRQ-HPFCUAHCSA-M', 'SWIRFWUEJODNRG-CURYUGHLSA-L', 'RBZYGQJEMWGTOH-RSDXMDNYSA-M', 'QGNJRVVDBSJHIZ-QHLGVNSISA-N', 'VYGQUTWHTHXGQB-FFHKNEKCSA-N', 'ZUFQODAHGAHPFQ-UHFFFAOYSA-N', 'TTWYZDPBDWHJOR-IDIVVRGQSA-L', 'MWEQTWJABOLLOS-AZGWGOJFSA-L', 'UQVDQSWZQXDUJB-UHFFFAOYSA-N', 'LQXHSCOPYJCOMD-UHFFFAOYSA-N', 'VWBQYTRBTXKKOG-IYNICTALSA-M', 'LFMYNZPAVPMEGP-PIDGMYBPSA-N', 'MIXMJCQRHVAJIO-TZHJZOAOSA-N', 'WMNUVYYLMCMHLU-UHFFFAOYSA-N', 'OFCJKOOVFDGTLY-UHFFFAOYSA-N', 'OJNSNSZTGUACNI-VAGRMJETSA-N', 'DAWXRFCLWKUCNS-MNTSKLTCSA-N', 'PYHRZPFZZDCOPH-UHFFFAOYSA-N', 'RFEJUZJILGIRHQ-OMDKHLBYSA-N', 'LDMPZNTVIGIREC-ZGPNLCEMSA-N', 'ZSTLCHCDLIUXJE-ZGBAEQJLSA-N', 'GEKNCWBANDDJJL-UHFFFAOYSA-N', 'QTAOMKOIBXZKND-PPHPATTJSA-N', 'NCAIGTHBQTXTLR-UHFFFAOYSA-N', 'NXNSCUZKMVYAJQ-UHFFFAOYSA-N', 'PPKXEPBICJTCRU-XMZRARIVSA-N', 'CHDPSNLJFOQTRK-UHFFFAOYSA-N', 'PGZUMBJQJWIWGJ-ONAKXNSWSA-N', 'AWMFUEJKWXESNL-JZBHMOKNSA-N', 'NSYZCCDSJNWWJL-YXOIYICCSA-N', 'ZXBDZLHAHGPXIG-VTXLJDRKSA-N', 'NNRXCKZMQLFUPL-WBMZRJHASA-N', 'VUEMAFLGEMYXIH-YZPBMOCRSA-N', 'YAVZHCFFUATPRK-YZPBMOCRSA-N', 'XTSSJGRRFMNXGO-YZPBMOCRSA-N', 'WVRRTEYLDPNZHR-YZPBMOCRSA-N', 'XVRCTDQUXAWPBW-FBTIOKFQSA-K', 'RCQXSQPPHJPGOF-UHFFFAOYSA-N', 'YOEWQQVKRJEPAE-UHFFFAOYSA-L', 'DEIYFTQMQPDXOT-UHFFFAOYSA-N', 'JZCLIFPQURTYFA-UHFFFAOYSA-N', 'SRMPHJKQVUDLQE-KUJJYQHYSA-N', 'HQUPLSLYZHKKQT-WVVFQGGUSA-N', 'MTKNGOHFNXIVOS-UHFFFAOYSA-N', 'RVCSYOQWLPPAOA-QKYUOBHYSA-M', 'MGCQZNBCJBRZDT-UHFFFAOYSA-N', 'RDRUTBCDIVCMMX-UHFFFAOYSA-N', 'GYTCJCWFCBALFS-UHFFFAOYSA-N', 'YNWDKZIIWCEDEE-UHFFFAOYSA-N', 'WIHMBLDNRMIGDW-UHFFFAOYSA-N', 'UTINOWOSWSPFLJ-FSRHSHDFSA-N', 'BORDVONYOHPTGR-JQDLGSOUSA-N', 'YTIJUXVIZLYQTB-UHFFFAOYSA-N', 'IDIIJJHBXUESQI-DFIJPDEKSA-N', 'SKZIMSDWAIZNDD-WJMOHVQJSA-N', 'UKLQXHUGTKWPSR-UHFFFAOYSA-M', 'NQHXCOAXSHGTIA-SKXNDZRYSA-N', 'MUFDLGGSOCHQOC-HTKOBJQYSA-N', 'SOYAGMVKMXZVNZ-HTKOBJQYSA-N', 'BOBLHFUVNSFZPJ-JOYXJVLSSA-N', 'XTYSXGHMTNTKFH-BDEHJDMKSA-N', 'NUBQKPWHXMGDLP-BDEHJDMKSA-N', 'XPCLDSMKWNNKOM-UHFFFAOYSA-K', 'RTEVGQJRTFFMLL-UHFFFAOYSA-N', 'SVSFIELZISOJDT-XRZFDKQNSA-N', 'GPVUAFAZVYNKRQ-UHFFFAOYSA-N', 'XNBFXTXDZMWXMN-UHFFFAOYSA-N', 'XDWVNCOPMIEDJK-UHFFFAOYSA-L', 'FVVDKUPCWXUVNP-UHFFFAOYSA-M', 'IPLQYSPEGHNJCQ-UHFFFAOYSA-L', 'PRZJIMSXCLZGLT-UHFFFAOYSA-M', 'GMUQJDAYXZXBOT-UHFFFAOYSA-M', 'CGTZMJIMMUNLQD-STYNFMPRSA-N', 'VWUPWEAFIOQCGF-UHFFFAOYSA-N', 'QORQZMBCPRBCAB-UHFFFAOYSA-M', 'KMTLSXAXTLQBKJ-UHFFFAOYSA-N', 'WVNOAGNOIPTWPT-NDUABGMUSA-N', 'DJHCCTTVDRAMEH-DUUJBDRPSA-N', 'LIZXGILRVOONMO-UHFFFAOYSA-M', 'RJNSNFZXAZXOFX-UHFFFAOYSA-N', 'CPFJLLXFNPCTDW-BWSPSPBFSA-N', 'NZDBKBRIBJLNNT-UHFFFAOYSA-N', 'WLQZEFFFIUHSJB-UHFFFAOYSA-N', 'LWYXFDXUMVEZKS-ZVFOLQIPSA-N', 'FJPYVLNWWICYDW-UHFFFAOYSA-M', 'IYECPECUTCOMMD-QFWOMMJSSA-N', 'HALQELOKLVRWRI-VDBOFHIQSA-N', 'RUYHIJHUVHIMIR-CVHRZJFOSA-N', 'XQTWDDCIUJNLTR-CVHRZJFOSA-N', 'NLORYLAYLIXTID-ISLYRVAYSA-N', 'XQKKWWCELHKGKB-UHFFFAOYSA-L', 'TVWRQCIPWUCNMI-UHFFFAOYSA-N', 'FEPTXVIRMZIGFY-UHFFFAOYSA-N', 'BRIPGNJWPCKDQZ-WXXKFALUSA-N', 'RGHAZVBIOOEVQX-UHFFFAOYSA-N', 'YGULWPYYGQCFMP-CEAXSRTFSA-N', 'HZYJYGJIOCXOTH-FAIYLGIWSA-N', 'XDXHAEQXIBQUEZ-UHFFFAOYSA-N',  ...

# %%
dfChembl =pd.read_csv('chembl24inchikey.csv',delimiter='\t',encoding='utf-8')

# %%
print(dfChembl.shape)
# Out:
# (1820035, 1)

# %%
listChemblInchiKey=dfChembl.values.tolist()
print(len(listChemblInchiKey))
print(type(listChemblInchiKey))
# Out:
# 1820035
# <class 'list'>

# %%
#exact matches inchikey
listExactMatch=[]
for item in listChemblInchiKey:
    
    if item[0] in listSaltsDB:
        
        listExactMatch.append(item[0])

print(len(listExactMatch))
# Out:
# 1427

# %%
dfExactMatchInhcikey = pd.DataFrame(listExactMatch)
dfExactMatchInhcikey.to_csv('ExactMatchesInchiKey.csv', index=False)

# %%
#find match for names
listNamesDB=[]
print("total",len(df[df.columns[1]]))

for item in range(len(df[df.columns[1]])):
    if str(df[df.columns[1]][item]) != 'nan':
        name = str(df[df.columns[1]][item]).lower()
        listNamesDB.append(name)

print('nonempty count',len(listNamesDB))


dfChemblNames =pd.read_csv('chembl24prefnames.csv',delimiter='\t',encoding='utf-8')
print(dfChemblNames.shape)
listChemblNames=dfChemblNames.values.tolist()
print(len(listChemblNames))

print(type(listChemblNames))
listExactMatchNames=[]
for item in listChemblNames: 
    if item[0] != 'NULL' :
        cname=str(item[0]).lower()
        if cname in listNamesDB:        
            listExactMatchNames.append(cname)

print(len(listExactMatchNames))
# Out:
# total 2236
# nonempty count 2236
# (1828820, 1)
# 1828820
# <class 'list'>
# 1409

# %%
')


                arr2.append(item)

                #

                for item in arr2:

                    val = item.split('::')

                    listSMILESOnlyDB.append(val[1])

      

​

        

             

    print(item)

    if count==10:    

        break;

​

print(len(listSMILESOnlyDB))

print(listSMILESOnlyDB)

calculated_properties_kind_value_source
ctMatchesNames.csv', index=False)

# %%
#check smiles from drugbank drug and compare against chembl
#sample
f = open("samplesmilesinDB.txt", "r")
samplesmi = f.readline()
arr = samplesmi.split('||')
arr2=[]
for item in arr:
    if 'SMILE' in item:
        arr2.append(item)

listSMILESDB=[]
for item in arr2:
    val = item.split('::')
    listSMILESDB.append(val[1])
      
print("listSMILESDB",listSMILESDB)
# Out:
# listSMILESDB ['CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@@H](CC1=CN=CC=C1)NC(=O)[C@@H](CC1=CC=C(Cl)C=C1)NC(=O)[C@@H](CC1=CC2=CC=CC=C2C=C1)NC(C)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N1CCC[C@H]1C(=O)N[C@H](C)C(N)=O', 'CC(=O)NC(Cc1ccc2ccccc2c1)C(=O)NC(Cc1ccc(Cl)cc1)C(=O)NC(Cc1cccnc1)C(=O)NC(CO)C(=O)NC(Cc1ccc(O)cc1)C(=O)NC(CCCNC(N)=O)C(=O)NC(CC(C)C)C(=O)NC(CCCNC(=N)N)C(=O)N1CCCC1C(=O)NC(C)C(N)=O']

# %%
#get smiles from drugbank-drug
import pandas as pd
dfdb2 =pd.read_csv('drugbank_drug.tsv',delimiter='\t',encoding='utf-8')

print(dfdb2.columns[44])
listSMILESdrugsDB=[]
listSMILESOnlyDB=[]
listSMILESdrugsDB.append(dfdb2[dfdb2.columns[44]])
count=0

for item in listSMILESdrugsDB[0]:
    count = count+1
    item=str(item)
    if item != 'nan':
        arr = item.split('||')
        arr2=[]
        for item in arr:
            if 'SMILE' in item:
                arr2.append(item)
                for item in arr2:
                    val = item.split('::')
                    listSMILESOnlyDB.append(val[1])
print(len(listSMILESOnlyDB))
# Out:
# calculated_properties_kind_value_source
# 31046

# %%
dfChemblsmiles =pd.read_csv('chembl24smiles.csv',delimiter='\t',encoding='utf-8')
print(dfChemblsmiles.shape)
# Out:
# (1820035, 1)

# %%
listChemblSmiles=dfChemblsmiles.values.tolist()
listExactMatchSmiles=[]
for item in listChemblSmiles:
    
    if item[0] in listSMILESOnlyDB:
        
        listExactMatchSmiles.append(item[0])

print(len(listExactMatchSmiles))
# Out:
# 1272

# %%
dfExactMatchSmiles = pd.DataFrame(listExactMatchSmiles)
dfExactMatchSmiles.to_csv('ExactMatchesSmiles.csv', index=False)

# %%
import pandas as pd
dfdb2 =pd.read_csv('drugbank_drug.tsv',delimiter='\t',encoding='utf-8')
# Out:
# (13339, 55)

# %%
print(dfdb2.columns)
print(dfdb2.iloc[:3])
# Out:
# Index(['drugbank_id', 'alternative_drugbank_ids', 'name', 'cas_number', 'unii',
#        'state', 'groups', 'general_references_links_title_url',
#        'general_references_textbooks_isbn_citation',
#        'general_references_articles_pubmed_citation', 'synthesis_reference',
#        'indication', 'pharmacodynamics', 'mechanism_of_action', 'toxicity',
#        'metabolism', 'absorption', 'half_life', 'protein_binding',
#        'route_of_elimination', 'volume_of_distribution', 'clearance',
#        'classification_subclass', 'classification_class',
#        'classification_superclass', 'classification_kingdom',
#        'classification_direct_parent', 'classification_description',
#        'synonyms', 'international_brands_name_company',
#        'mixtures_name_ingredients', 'packagers_name_url', 'manufacturers',
#        'prices_description_cost_unit', 'affected_organisms',
#        'dosages_form_route_strength', 'atc_code_levels', 'ahfs_codes',
#        'pdb_entries', 'fda_label', 'msds',
#        'patents_number_country_approved_expires_pediatric_extension',
#        'food_interaction', 'sequences',
#        'calculated_properties_kind_value_source',
#        'experimental_properties_kind_value_source', 'external_identifiers',
#        'external_links_resource_url', 'type',
#        'classification_alternative_parent', 'classification_substituent',
#        'inchi', 'inchikey', 'description', 'ChEMBL'],
#       dtype='object')
#   drugbank_id alternative_drugbank_ids          name   cas_number        unii  \
# 0     DB00001      BTD00024||BIOD00024     Lepirudin  138068-37-8  Y43GF64R34
# 1     DB00002      BTD00071||BIOD00071     Cetuximab  205923-56-4  PQX0D8J21J
# 2     DB00003      BTD00001||BIOD00001  Dornase alfa  143831-71-4  953A26OA1Y
#
#     state    groups                 general_references_links_title_url  \
# 0  liquid  approved  Google books::http://books.google.com/books?id...
# 1  liquid  approved                                                NaN
# 2  liquid  approved                                                NaN
#
#   general_references_textbooks_isbn_citation  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#          general_references_articles_pubmed_citation  ...  \
# 0  16244762::Smythe MA, Stephens JL, Koerber JM, ...  ...
# 1  10480573::Hosokawa N, Yamamoto S, Uehara Y, Ho...  ...
# 2  8792953::Cramer GW, Bosso JA: The role of dorn...  ...
#
#            experimental_properties_kind_value_source  \
# 0  Melting Point::65 °C::Otto, A. & Seckler, R. E...
# 1  Melting Point::61 °C (FAB fragment), 71 °C (wh...
# 2  Melting Point::67 °C::Chan, H.K. et al., Pharm...
#
#                                 external_identifiers  \
# 0  Drugs Product Database (DPD):11916||PubChem Su...
# 1  Drugs Product Database (DPD):13175||PubChem Su...
# 2  Drugs Product Database (DPD):650||PubChem Subs...
#
#                          external_links_resource_url     type  \
# 0  RxList::http://www.rxlist.com/cgi/generic/lepi...  biotech
# 1  RxList::http://www.rxlist.com/cgi/generic3/erb...  biotech
# 2  RxList::http://www.rxlist.com/cgi/generic/pulm...  biotech
#
#   classification_alternative_parent classification_substituent inchi inchikey  \
# 0                               NaN                        NaN   NaN      NaN
# 1                               NaN                        NaN   NaN      NaN
# 2                               NaN                        NaN   NaN      NaN
#
#                                          description         ChEMBL
# 0  Lepirudin is identical to natural hirudin exce...  CHEMBL1201666
# 1  Cetuximab is an epidermal growth factor recept...  CHEMBL1201577
# 2  Dornase alfa is a biosynthetic form of human d...  CHEMBL1201431
#
# [3 rows x 55 columns]

# %%
listInchikeydrugsDB=[]
listInchikeydrugsDB.append(dfdb2[dfdb2.columns[52]])
print('nonempty count',len(listInchikeydrugsDB))
print(listInchikeydrugsDB[0])
# Out:
# nonempty count 1
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5        OIRCOABEOLEUMC-GEJPAHFPSA-N
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13       BLCLNMBMMGCOAS-URPVMXJPSA-N
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25       NDAYQJDHGXTBJL-MWWSRJDJSA-N
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
#                     ...
# 13309                            NaN
# 13310                            NaN
# 13311    KGERZPVQIRYWRK-GDLZYMKVSA-N
# 13312    GMMLNKINDDUDCF-JRWRFYLSSA-N
# 13313    GBHPDJQHZADVAA-SOKVYYICSA-N
# 13314                            NaN
# 13315    YGACXVRLDHEXKY-WXRXAMBDSA-N
# 13316    AFDPFLDWOXXHQM-NRFANRHFSA-N
# 13317                            NaN
# 13318    PDGKHKMBHVFCMG-UHFFFAOYSA-N
# 13319                            NaN
# 13320    MVRHVFSOIWFBTE-INIZCTEOSA-N
# 13321    CORFWQGVBFFZHF-UHFFFAOYSA-N
# 13322    XPRDUGXOWVXZLL-UHFFFAOYSA-N
# 13323    PEGQOIGYZLJMIB-UHFFFAOYSA-N
# 13324    VGUSQKZDZHAAEE-UHFFFAOYSA-N
# 13325    VLIUIBXPEDFJRF-UHFFFAOYSA-N
# 13326    BXNMZRPTQFVRFA-QGZVFWFLSA-N
# 13327                            NaN
# 13328                            NaN
# 13329                            NaN
# 13330                            NaN
# 13331    QZFHIXARHDBPBY-UHFFFAOYSA-N
# 13332    QLWFXLJVGCECSV-HUYCHCPVSA-N
# 13333    LRQKBLKVPFOOQJ-YFKPBYRVSA-N
# 13334    JWQMTWCFNZSLNR-DEOSSOPVSA-N
# 13335                            NaN
# 13336                            NaN
# 13337                            NaN
# 13338    RIUPLDUFZCXCHM-UHFFFAOYSA-N
# Name: inchikey, Length: 13339, dtype: object

# %%
#exact matches inchikey
listExactMatch=[]
for item in listInchikeydrugsDB[0]:
    item=str(item)
    if item != 'nan':
        splitarr = item.split('-')
        if splitarr[0] in listChemblInchiKey:
            listExactMatch.append(item)
        elif splitarr[1] in listChemblInchiKey:
            listExactMatch.append(item)
        else:
            s='do none'
print(len(listExactMatch))
# Out:
# 0

# %%
print(listChemblInchiKey[0])
# Out:
# ['AAAAEENPAALFRN-UHFFFAOYSA-N']

# %%
#exact matches inchikey
listExactMatch=[]
for item in listChemblInchiKey:
    item=str(item)
    if item != 'nan':
        splitarr = item.split('-')
        if splitarr[0] in listInchikeydrugsDB[0]:
            listExactMatch.append(item)
        elif splitarr[1] in listInchikeydrugsDB[0]:
            listExactMatch.append(item)
        else:
            s='do none'
        #break
        

print(len(listExactMatch))
# Out:
# 0

# %%
print(listInchikeydrugsDB[0][25])
# Out:
# NDAYQJDHGXTBJL-MWWSRJDJSA-N
